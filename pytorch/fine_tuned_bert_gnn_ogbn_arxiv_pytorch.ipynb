# %% [markdown]
# <a href="https://colab.research.google.com/github/joshchang1112/bert_gnn_arxiv/blob/master/pytorch/fine_tuned_bert_gnn_ogbn_arxiv_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-class Classification with fine-tuned BERT & GNN (Pytorch)

# %% [markdown]
# ## Overview
#
# BERT is the most powerful neural networks model in NLP area. Graph Neural Networks(GNN) is also one of the most popular model now. Therefore, we want to bring the advantages in BERT to the citation network, and evaluate that how much improvement can BERT help GNN models work.
#
# In this colab notebook, we will explore the use of fine-tuned BERT, how to encode node features using BERT model, and using citation graph and node features to train GNN models.
#
# The step is as follows:
#
# 1.  Download `ogbn-arxiv` dataset from [Open Graph Benchmark](https://ogb.stanford.edu/).
# 2.  Fine-tuned BERT with arxiv dataset and select the model which has the best accuracy in validation set as encoder.
# 3.  Encode the node features using fine-tuned BERT.
# 4.  Train and evaluate the `GNN` model.

# %% [markdown]
# ## Setup

# %% [markdown]
# Install the **Open Graph Benchmark**, **pytorch_geometric** and **transformers(huggingface)** package.

# %%
# Install package
# !pip install ogb
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install torch-geometric
# !pip install transformers
# Out:
# Collecting ogb
#   Downloading https://files.pythonhosted.org/packages/1a/27/fa0cdde0be085d3b82807e210e0f2dfd75c9c01d4c587be0d05b02a0618b/ogb-1.2.4-py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.2MB/s
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (4.41.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (1.19.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (1.15.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (0.22.2.post1)
# Collecting outdated>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/86/70/2f166266438a30e94140f00c99c0eac1c45807981052a1d4c123660e1323/outdated-0.2.0.tar.gz
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (1.24.3)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from ogb) (1.7.0+cu101)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->ogb) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->ogb) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->ogb) (1.0.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->ogb) (1.4.1)
# Collecting littleutils
#   Downloading https://files.pythonhosted.org/packages/4e/b1/bb4e06f010947d67349f863b6a2ad71577f85590180a935f60543f622652/littleutils-0.2.2.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from outdated>=0.2.0->ogb) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.2.0->ogb) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.2.0->ogb) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.2.0->ogb) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->outdated>=0.2.0->ogb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->outdated>=0.2.0->ogb) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->outdated>=0.2.0->ogb) (2.10)
# Building wheels for collected packages: outdated, littleutils
#   Building wheel for outdated (setup.py) ... done
#   Created wheel for outdated: filename=outdated-0.2.0-cp36-none-any.whl size=4961 sha256=6ae456b5cb0c27398c5ac79a005047ced2600a4c77e08112e1946794e2e6a368
#   Stored in directory: /root/.cache/pip/wheels/fd/7c/ef/814f514d31197310872b5abf353feb8fef9d67ee658e1e7e39
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-cp36-none-any.whl size=7051 sha256=413f7d89299bc55ec57cffad33c7464dc22de18e0b5cb60bd94e1a3e2440cbd9
#   Stored in directory: /root/.cache/pip/wheels/53/16/9f/ac67d15c40243754fd73f620e1b9b6dedc20492ecc19a2bae1
# Successfully built outdated littleutils
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.2 ogb-1.2.4 outdated-0.2.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# Collecting torch-scatter
#   Downloading https://pytorch-geometric.com/whl/torch-1.7.0%2Bcu101/torch_scatter-2.0.5-cp36-cp36m-linux_x86_64.whl (11.9MB)
#      |████████████████████████████████| 11.9MB 13.7MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.5
# Looking in links: https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# Collecting torch-sparse
#   Downloading https://pytorch-geometric.com/whl/torch-1.7.0%2Bcu101/torch_sparse-0.6.8-cp36-cp36m-linux_x86_64.whl (24.3MB)
#      |████████████████████████████████| 24.3MB 1.2MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->torch-sparse) (1.19.5)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.8
# Looking in links: https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# Collecting torch-cluster
#   Downloading https://pytorch-geometric.com/whl/torch-1.7.0%2Bcu101/torch_cluster-1.5.8-cp36-cp36m-linux_x86_64.whl (21.5MB)
#      |████████████████████████████████| 21.5MB 327kB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.5.8
# Looking in links: https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# Collecting torch-spline-conv
#   Downloading https://pytorch-geometric.com/whl/torch-1.7.0%2Bcu101/torch_spline_conv-1.2.0-cp36-cp36m-linux_x86_64.whl (6.4MB)
#      |████████████████████████████████| 6.4MB 6.6MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.0
# Collecting torch-geometric
#   Downloading https://files.pythonhosted.org/packages/59/5c/3e95b76321fb14f24cc2ace392075717f645c4632e796ee0db1bc7d17231/torch_geometric-1.6.3.tar.gz (186kB)
#      |████████████████████████████████| 194kB 12.2MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.5)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.15)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.22.2.post1)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.48.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.1.5)
# Collecting rdflib
#   Downloading https://files.pythonhosted.org/packages/d0/6b/6454aa1db753c0f8bc265a5bd5c10b5721a4bb24160fb4faf758cf6be8a1/rdflib-5.0.0-py3-none-any.whl (231kB)
#      |████████████████████████████████| 235kB 21.5MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.10.0)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.4)
# Collecting ase
#   Downloading https://files.pythonhosted.org/packages/f6/ad/5de9c50e7e4346f18f9020b6a5cf3ed3d4a47520a3bf6a6b0e5ae6b7d315/ase-3.21.0-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 26.7MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.11.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->torch-geometric) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torch-geometric) (0.16.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->torch-geometric) (0.8)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->torch-geometric) (4.4.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->torch-geometric) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->torch-geometric) (51.3.3)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->torch-geometric) (0.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->torch-geometric) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rdflib->torch-geometric) (1.15.0)
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.9MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib->torch-geometric) (2.4.7)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from ase->torch-geometric) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->torch-geometric) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->ase->torch-geometric) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->ase->torch-geometric) (0.10.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.6.3-cp36-none-any.whl size=322720 sha256=7805f324019ac0f3b47a20a298b90850e5e579037767b3481255d0f8031e0622
#   Stored in directory: /root/.cache/pip/wheels/6d/47/1e/0af8ce3e21783c3e584c22502011a3367c091694eebc50a971
# Successfully built torch-geometric
# Installing collected packages: isodate, rdflib, ase, torch-geometric
# Successfully installed ase-3.21.0 isodate-0.6.0 rdflib-5.0.0 torch-geometric-1.6.3
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/88/b1/41130a228dd656a1a31ba281598a968320283f48d42782845f6ba567f00b/transformers-4.2.2-py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 12.5MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 63.7MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from transformers) (3.3.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 60.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=319cbcfbf85e3da5ab53fb083f679c5184beee845fde43e28c7421c223607c56
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.2.2

# %% [markdown]
# ## Dependencies and imports

# %%
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T
import transformers
import numpy as np
import pandas as pd
import csv
from torch_geometric.nn import GCNConv, SAGEConv, GATConv
from ogb.nodeproppred.dataset_pyg import PygNodePropPredDataset
from ogb.nodeproppred import Evaluator
from tqdm.notebook import tqdm

print("Pytorch Version: ",  torch.__version__)
if torch.cuda.is_available():
  print("GPU {} is available!".format(torch.cuda.current_device()))
else:
  print("Only CPU is available!")
# Out:
# Pytorch Version:  1.7.0+cu101
# GPU 0 is available!

# %% [markdown]
# ## Ogbn-arxiv dataset
# The `ogbn-arxiv` dataset is a directed graph, representing the citation network between all Computer Science (CS) arXiv papers indexed by Microsoft academic graph (MAG). Each node is an arXiv paper and each directed edge indicates that one paper cites another one. The dataset also provide the mapping from MAG paper IDs into the raw texts of titles and abstracts here.
#
# The task involved is document classification where the goal is to categorize each paper into one of 40 subject areas of arXiv CS papers. In other words, this is a multi-class classification problem with 40 classes.
#
# ### Features
# Each paper comes with a 128-dimensional feature vector obtained by averaging the embeddings of words in its title and abstract. The embeddings of individual words are computed by running the skip-gram model over the MAG corpus.
#
# In this colab notebook, we will also compare the results with features provided by OGB and the features encoded by our fine-tuned BERT.

# %% [markdown]
# ### Download the ogbn-arxiv dataset

# %%
# Downloads ogbn_arxiv dataset and its raw titles and abstracts
from ogb.nodeproppred.dataset_pyg import PygNodePropPredDataset
import torch_geometric.transforms as T
# !wget https://snap.stanford.edu/ogb/data/misc/ogbn_arxiv/titleabs.tsv.gz
# !gunzip titleabs.tsv.gz
dataset = PygNodePropPredDataset(name='ogbn-arxiv', 
                                 transform=T.ToSparseTensor())
# Out:
# --2021-01-23 08:48:21--  https://snap.stanford.edu/ogb/data/misc/ogbn_arxiv/titleabs.tsv.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70213527 (67M) [application/x-gzip]
# Saving to: ‘titleabs.tsv.gz’
#
# titleabs.tsv.gz     100%[===================>]  66.96M  18.3MB/s    in 6.9s
#
# 2021-01-23 08:48:28 (9.76 MB/s) - ‘titleabs.tsv.gz’ saved [70213527/70213527]
#
# Downloading https://snap.stanford.edu/ogb/data/nodeproppred/arxiv.zip
# Downloaded 0.08 GB: 100%|██████████| 81/81 [00:08<00:00, 10.09it/s]
# Extracting dataset/arxiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# 100%|██████████| 1/1 [00:00<00:00, 1136.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.95it/s]
# Processing graphs...
# Converting graphs into PyG objects...
# Saving...
# Done!

# %% [markdown]
# ## Global variables

# %%
### File path
TRAIN_ID_PATH = 'dataset/ogbn_arxiv/split/time/train.csv.gz'
VALID_ID_PATH = 'dataset/ogbn_arxiv/split/time/valid.csv.gz'
TEST_ID_PATH = 'dataset/ogbn_arxiv/split/time/test.csv.gz'
LABEL_PATH = 'dataset/ogbn_arxiv/raw/node-label.csv.gz'
NODE2PAPER_PATH = 'dataset/ogbn_arxiv/mapping/nodeidx2paperid.csv.gz'
RAW_DATA_PATH = 'titleabs.tsv'

# %% [markdown]
# ## Fine-tuned BERT

# %% [markdown]
# ### Load data & preprocess

# %%
raw_data = pd.read_csv(RAW_DATA_PATH, sep='\t', header=None)
raw_data.columns = ['Id', 'Title', 'Abstract']
raw_data.iloc[0, 0] = 200971
raw_data = raw_data.drop(len(raw_data)-1)

node2paper = pd.read_csv(NODE2PAPER_PATH)
train_idx = pd.read_csv(TRAIN_ID_PATH, header=None)
val_idx = pd.read_csv(VALID_ID_PATH, header=None)
test_idx = pd.read_csv(TEST_ID_PATH, header=None)
label = pd.read_csv(LABEL_PATH, header=None)

train_idx = train_idx.iloc[:, 0].tolist()
val_idx = val_idx.iloc[:, 0].tolist()
test_idx = test_idx.iloc[:, 0].tolist()
label = label.iloc[:, 0].tolist()

paper2node_dict = {}
node2paper_dict = {}

for i, row in tqdm(node2paper.iterrows()):
    paper2node_dict[int(row[1])] = int(row[0])
    node2paper_dict[int(row[0])] = int(row[1])
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ### Tokenize and split dataset
#
# ---

# %%
from transformers import BertTokenizer
train = []
val = []
test = []
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
for i, row in tqdm(raw_data.iterrows()):
    if int(row['Id']) not in paper2node_dict:
        continue
    processed = {}
    processed['context'] = tokenizer.tokenize(text=row['Title']+row['Abstract'])
    processed['context'] = tokenizer.convert_tokens_to_ids(processed['context'])
    processed['length'] = len(processed['context'])
    processed['id'] = paper2node_dict[int(row['Id'])]
    processed['label'] = label[int(paper2node_dict[int(row['Id'])])]
    
    if processed['id'] in train_idx:
        train.append(processed)
    elif processed['id'] in val_idx:
        val.append(processed)
    elif processed['id'] in test_idx:
        test.append(processed)
    else:
        print("NOT MATCH!!!!!")
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ### Hyperparameters
#
# We will use an instance of `Args` to include various hyperparameters and constants used for training and evaluation in BERT. We briefly describe each of them below:
#
#
# -   **num_classes**: There are a total 40 different classes
#
# -   **max_seq_length**: This is the max length of document tokens in training and evaluation.
#
# -   **train_epochs**: The number of training epochs.
#
# -   **batch_size**: Batch size used for training and evaluation.
#
# -   **learning_rate**: Learning rate in training.
#
# -   **dropout_rate**: Controls the rate of dropout following each layer.
#
# -   **eval_steps**: The number of batches to process before evaluation.

# %%
class Args(object):
  """Hyperparameters used for training BERT."""
  def __init__(self):
    ### dataset parameters
    self.num_classes = 40
    self.max_seq_length = 500
    ### training parameters
    self.train_epochs = 2
    self.batch_size = 8
    self.learning_rate = 2e-5
    self.dropout_rate = 0.5
    ### eval parameters
    self.eval_steps = 4000

args = Args()

# %% [markdown]
# ### Make dataset

# %%
from torch.utils.data import Dataset, DataLoader

def pad_to_len(arr, padded_len, padding=0):
    length_arr = len(arr)
    new_arr = arr
    if length_arr < padded_len:
        for i in range(padded_len - length_arr):
            new_arr.append(padding)
    else:
        for i in range(length_arr - padded_len):
            del new_arr[-2]
    return new_arr

class CitationDataset(Dataset):

    def __init__(self, data, max_seq_len, padding=0):
        self.data = data
        self.max_seq_len = max_seq_len
        self.padding = padding

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        data = dict(self.data[index])
        if len(data['context']) > self.max_seq_len:
            data['context'] = data['context'][:self.max_seq_len]
        return data

    def collate_fn(self, datas):
        batch = {}
        batch['length'] = torch.LongTensor([data['length'] for data in datas])
        padded_len = min(self.max_seq_len, max(batch['length']))
        batch['context'] = torch.tensor(
            [pad_to_len(data['context'], padded_len, self.padding)
             for data in datas]
        )
        batch['label'] = torch.LongTensor([data['label'] for data in datas])
        return batch

train_dataset = CitationDataset(train, max_seq_len=args.max_seq_length)
valid_dataset = CitationDataset(val, max_seq_len=args.max_seq_length)

train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True, 
    collate_fn=train_dataset.collate_fn)
valid_loader = DataLoader(valid_dataset, batch_size=args.batch_size, shuffle=False,
    collate_fn=valid_dataset.collate_fn)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import accuracy_score
class Metrics:
    def __init__(self):
        self.name = 'Metric Name'

    def reset(self):
        pass

    def update(self, predicts, batch):
        pass

    def get_score(self):
        pass

class Accuracy(Metrics):
    """
    Args:
         ats (int): @ to eval.
         rank_na (bool): whether to consider no answer.
    """
    def __init__(self):
        self.n = 0
        self.name = 'Accuracy'
        self.match = 0

    def reset(self):
        self.n = 0
        self.match = 0
        
    def update(self, predicts, label):
        """
        Args:
            predicts (FloatTensor): with size (batch, n_samples).
            batch (dict): batch.
        """
        predicts, label = predicts.cpu(), label.cpu()
        batch_size = list(predicts.size())[0]
        _, y_pred = torch.max(predicts, dim=1)
        self.match += accuracy_score(label, y_pred, normalize=False)
        self.n += batch_size
    
    def print_score(self):
        acc = self.match / self.n
        #self.get_category_f1()
        return '{:.4f}'.format(acc)

# %% [markdown]
# ### Train and Evaluate BERT model on multi-classification task

# %%
def run_iter(batch, model, device, training):
    context, context_lens = batch['context'].to(device), batch['length'].to(device)
    batch_size = context.size()[0]
    max_context_len = context.size()[1]
    padding_mask = []
    for j in range(batch_size):
        if context_lens[j] < max_context_len:
            tmp = [1] * context_lens[j] + [0] * (max_context_len - context_lens[j])
        else:
            tmp = [1] * max_context_len
        padding_mask.append(tmp)

    padding_mask = torch.Tensor(padding_mask).to(device)
    if training:
        prob = model(context, attention_mask=padding_mask)[0]
    else:
        with torch.no_grad():
            prob = model(context, attention_mask=padding_mask)[0]
    return prob

# %%
def training(train_loader, valid_loader, model, optimizer, epochs, eval_steps, device):
    train_metrics = Accuracy()
    best_valid_acc = 0
    total_iter = 0
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in range(epochs):
        train_trange = tqdm(enumerate(train_loader), total=len(train_loader), desc='training')
        train_loss = 0
        train_metrics.reset()
        for i, batch in train_trange:
            model.train()
            prob = run_iter(batch, model, device, training=True)
            answer = batch['label'].to(device)
            loss = criterion(prob, answer)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_iter += 1
            train_loss += loss.item()
            train_metrics.update(prob, answer)
            train_trange.set_postfix(loss= train_loss/(i+1),
                                     **{train_metrics.name: train_metrics.print_score()})
            
            if total_iter % eval_steps == 0:
                valid_acc = testing(valid_loader, model, device, valid=True)
                if valid_acc > best_valid_acc:
                    best_valid_acc = valid_acc
                    torch.save(model, 'best_val.pkl')

# %%
def testing(dataloader, model, device, valid):
    metrics = Accuracy()
    criterion = torch.nn.CrossEntropyLoss()
    trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='validation' if valid else 'testing')
    model.eval()
    total_loss = 0
    metrics.reset()
    for k, batch in trange:
        model.eval()
        prob = run_iter(batch, model, device, training=False)
        answer = batch['label'].to(device)
        loss = criterion(prob, batch['label'].to(device))
        total_loss += loss.item()
        metrics.update(prob, answer)
        trange.set_postfix(loss= total_loss/(k+1),
                           **{metrics.name: metrics.print_score()})
    acc = metrics.match / metrics.n
    return acc

# %%
from transformers import BertForSequenceClassification
from torch.optim import Adam
device = torch.device('cuda:{}'.format(torch.cuda.current_device()) 
                       if torch.cuda.is_available() else 'cpu')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', 
                                                      num_labels=args.num_classes).to(device)
optimizer = Adam(model.parameters(), lr=args.learning_rate)
training(train_loader, valid_loader, model, optimizer, args.train_epochs, args.eval_steps, device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='training', max=11368.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='validation', max=3725.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='validation', max=3725.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='training', max=11368.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='validation', max=3725.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='validation', max=3725.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='validation', max=3725.0, style=ProgressStyle(description_…

# %% [markdown]
# ### Predict test set using fine-tuned BERT model

# %%
test_dataset = CitationDataset(test, max_seq_len=args.max_seq_length)
test_loader = DataLoader(test_dataset, batch_size=args.batch_size, shuffle=False,
                         collate_fn=test_dataset.collate_fn)
model = torch.load('best_val.pkl').to(device)
test_acc = testing(test_loader, model, device, valid=False)
print("Test Accuracy:{}".format(test_acc))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='testing', max=6076.0, style=ProgressStyle(description_wid…
# Test Accuracy:0.7237619077011707

# %%
# !ls
# Out:
# best_val.pkl  dataset  sample_data  titleabs.tsv

# %% [markdown]
# ## Encode node features using fine-tuned BERT

# %%
node_feats = torch.zeros((len(node2paper_dict), 768)).to(device)
model = torch.load('best_val.pkl').to(device)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

### Freeze all fine-tuned BERT layers
freeze_layers = 12
for p in model.bert.embeddings.parameters():
    p.requires_grad = False
model.bert.embeddings.dropout.p = 0.0
for p in model.bert.pooler.parameters():
    p.requires_grad = False
for idx in range(freeze_layers):
    for p in model.bert.encoder.layer[idx].parameters():
        p.requires_grad = False
    model.bert.encoder.layer[idx].attention.self.dropout.p = 0.0
    model.bert.encoder.layer[idx].attention.output.dropout.p = 0.0
    model.bert.encoder.layer[idx].output.dropout.p = 0.0

for i, row in tqdm(raw_data.iterrows()):
    if int(row['Id']) not in paper2node_dict:
        continue
    context = row['Title'] + row['Abstract']
    tokenize_context = tokenizer.tokenize(context)
    context_len = len(tokenize_context)
    if context_len > 512:
        tokenize_context = tokenize_context[:512]
        
    context_id = tokenizer.convert_tokens_to_ids(tokenize_context)
    context_id = torch.LongTensor(context_id).unsqueeze(0).cuda()
    feat = model.bert(context_id)[1]
    node_id = paper2node_dict[int(row['Id'])]
    node_feats[node_id, :] = feat
    torch.cuda.empty_cache()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ## Graph Neural Networks (GNN)

# %% [markdown]
# ### Load citation graph data

# %%
dataset = PygNodePropPredDataset(name='ogbn-arxiv',
                                     transform=T.ToSparseTensor())
data = dataset[0]
data.adj_t = data.adj_t.to_symmetric()
data = data.to(device)
split_idx = dataset.get_idx_split()
train_idx = split_idx['train'].to(device)

# %% [markdown]
# ### GNN Models

# %% [markdown]
# #### Graph Convolution Network (GCN)

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout):
        super(GCN, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels, cached=True))
        self.bns = torch.nn.ModuleList()
        self.bns.append(torch.nn.BatchNorm1d(hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(
                GCNConv(hidden_channels, hidden_channels, cached=True))
            self.bns.append(torch.nn.BatchNorm1d(hidden_channels))
        self.convs.append(GCNConv(hidden_channels, out_channels, cached=True))
        self.dropout = dropout

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()

    def forward(self, x, adj_t):
        for i, conv in enumerate(self.convs[:-1]):
            x = conv(x, adj_t)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.convs[-1](x, adj_t)
        return x.log_softmax(dim=-1)

# %% [markdown]
# #### Graph Attention Network (GAT)

# %%
from torch_geometric.nn import GATConv

class GAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout):
        super(GAT, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.convs.append(GATConv(in_channels, hidden_channels, heads=4))
        self.bns = torch.nn.ModuleList()
        self.bns.append(torch.nn.BatchNorm1d(hidden_channels*4))
        for _ in range(num_layers - 2):
            self.convs.append(
                GATConv(hidden_channels*4, hidden_channels, heads=4))
            self.bns.append(torch.nn.BatchNorm1d(hidden_channels*4))
        self.convs.append(GATConv(hidden_channels*4, out_channels, heads=4, concat=False))
        self.dropout = dropout

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()

    def forward(self, x, adj_t):
        for i, conv in enumerate(self.convs[:-1]):
            x = conv(x, adj_t)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.convs[-1](x, adj_t)
        return x.log_softmax(dim=-1)

# %% [markdown]
# ### Metrics

# %%
class Logger(object):
    def __init__(self, runs, info=None):
        self.info = info
        self.results = [[] for _ in range(runs)]

    def add_result(self, run, result):
        assert len(result) == 3
        assert run >= 0 and run < len(self.results)
        self.results[run].append(result)

    def print_statistics(self, run=None):
        if run is not None:
            result = 100 * torch.tensor(self.results[run])
            argmax = result[:, 1].argmax().item()
            print(f'Run {run + 1:02d}:')
            print(f'Highest Train: {result[:, 0].max():.2f}')
            print(f'Highest Valid: {result[:, 1].max():.2f}')
            print(f'  Final Train: {result[argmax, 0]:.2f}')
            print(f'   Final Test: {result[argmax, 2]:.2f}')
        else:
            result = 100 * torch.tensor(self.results)

            best_results = []
            for r in result:
                train1 = r[:, 0].max().item()
                valid = r[:, 1].max().item()
                train2 = r[r[:, 1].argmax(), 0].item()
                test = r[r[:, 1].argmax(), 2].item()
                best_results.append((train1, valid, train2, test))

            best_result = torch.tensor(best_results)

            print(f'All runs:')
            r = best_result[:, 0]
            print(f'Highest Train: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 1]
            print(f'Highest Valid: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 2]
            print(f'  Final Train: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 3]
            print(f'   Final Test: {r.mean():.2f} ± {r.std():.2f}')

# %% [markdown]
# ### Hyperparameters

# %%
class GNN_Args(object):
  """Hyperparameters used for training GNN."""
  def __init__(self):
    self.log_steps = 1
    self.num_layers = 3
    self.hidden_channels = 256
    self.dropout = 0.5
    self.epochs = 500
    self.lr = 5e-3
    self.runs = 10

args = GNN_Args()

# %% [markdown]
# ### Train and Evaluate GNN model on word2vec node features

# %%
def train(model, data, train_idx, optimizer):
    model.train()

    optimizer.zero_grad()
    out = model(data.x, data.adj_t)[train_idx]
    loss = F.nll_loss(out, data.y.squeeze(1)[train_idx])
    loss.backward()
    optimizer.step()

    return loss.item()

@torch.no_grad()
def test(model, data, split_idx, evaluator):
    model.eval()

    out = model(data.x, data.adj_t)
    y_pred = out.argmax(dim=-1, keepdim=True)

    train_acc = evaluator.eval({
        'y_true': data.y[split_idx['train']],
        'y_pred': y_pred[split_idx['train']],
    })['acc']
    valid_acc = evaluator.eval({
        'y_true': data.y[split_idx['valid']],
        'y_pred': y_pred[split_idx['valid']],
    })['acc']
    test_acc = evaluator.eval({
        'y_true': data.y[split_idx['test']],
        'y_pred': y_pred[split_idx['test']],
    })['acc']

    return train_acc, valid_acc, test_acc

# %%
from ogb.nodeproppred import Evaluator
evaluator = Evaluator(name='ogbn-arxiv')
logger = Logger(args.runs, args)
model = GCN(data.num_features, args.hidden_channels,
            dataset.num_classes, args.num_layers,
            args.dropout).to(device)
# model = GAT(data.num_features, args.hidden_channels,
#             dataset.num_classes, args.num_layers,
#             args.dropout).to(device)

for run in range(args.runs):
  model.reset_parameters()
  optimizer = Adam(model.parameters(), lr=args.lr)
  for epoch in range(1, 1 + args.epochs):
    loss = train(model, data, train_idx, optimizer)
    result = test(model, data, split_idx, evaluator)
    logger.add_result(run, result)

    if epoch % args.log_steps == 0:
      train_acc, valid_acc, test_acc = result
      print(f'Run: {run + 1:02d}, '
            f'Epoch: {epoch:02d}, '
            f'Loss: {loss:.4f}, '
            f'Train: {100 * train_acc:.2f}%, '
            f'Valid: {100 * valid_acc:.2f}% '
            f'Test: {100 * test_acc:.2f}%')
  logger.print_statistics(run)
logger.print_statistics()
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Run: 01, Epoch: 56, Loss: 1.0187, Train: 71.19%, Valid: 70.62% Test: 70.29%
# Run: 01, Epoch: 57, Loss: 1.0201, Train: 71.31%, Valid: 70.63% Test: 70.26%
# Run: 01, Epoch: 58, Loss: 1.0160, Train: 71.36%, Valid: 70.63% Test: 70.12%
# Run: 01, Epoch: 59, Loss: 1.0126, Train: 71.35%, Valid: 70.55% Test: 69.93%
# Run: 01, Epoch: 60, Loss: 1.0099, Train: 71.41%, Valid: 70.48% Test: 69.78%
# Run: 01, Epoch: 61, Loss: 1.0060, Train: 71.46%, Valid: 70.56% Test: 69.58%
# Run: 01, Epoch: 62, Loss: 1.0047, Train: 71.56%, Valid: 70.63% Test: 69.63%
# Run: 01, Epoch: 63, Loss: 1.0044, Train: 71.68%, Valid: 70.75% Test: 69.63%
# Run: 01, Epoch: 64, Loss: 0.9998, Train: 71.77%, Valid: 71.03% Test: 70.02%
# Run: 01, Epoch: 65, Loss: 0.9969, Train: 71.86%, Valid: 71.18% Test: 70.51%
# Run: 01, Epoch: 66, Loss: 0.9938, Train: 71.75%, Valid: 71.03% Test: 70.64%
# Run: 01, Epoch: 67, Loss: 0.9938, Train: 71.84%, Valid: 71.17% Test: 70.68%
# Run: 01, Epoch: 68, Loss: 0.9919, Train: 71.99%, Valid: 71.29% Test: 70.52%
# Run: 01, Epoch: 69, Loss: 0.9905, Train: 72.12%, Valid: 71.22% Test: 70.16%
# Run: 01, Epoch: 70, Loss: 0.9896, Train: 72.17%, Valid: 71.08% Test: 69.77%
# Run: 01, Epoch: 71, Loss: 0.9854, Train: 72.14%, Valid: 70.88% Test: 69.52%
# Run: 01, Epoch: 72, Loss: 0.9816, Train: 72.15%, Valid: 70.88% Test: 69.63%
# Run: 01, Epoch: 73, Loss: 0.9837, Train: 72.24%, Valid: 71.03% Test: 69.93%
# Run: 01, Epoch: 74, Loss: 0.9803, Train: 72.30%, Valid: 71.19% Test: 70.06%
# Run: 01, Epoch: 75, Loss: 0.9754, Train: 72.40%, Valid: 71.31% Test: 70.26%
# Run: 01, Epoch: 76, Loss: 0.9745, Train: 72.44%, Valid: 71.42% Test: 70.44%
# Run: 01, Epoch: 77, Loss: 0.9728, Train: 72.50%, Valid: 71.40% Test: 70.58%
# Run: 01, Epoch: 78, Loss: 0.9730, Train: 72.59%, Valid: 71.46% Test: 70.65%
# Run: 01, Epoch: 79, Loss: 0.9701, Train: 72.72%, Valid: 71.46% Test: 70.55%
# Run: 01, Epoch: 80, Loss: 0.9665, Train: 72.76%, Valid: 71.42% Test: 70.31%
# Run: 01, Epoch: 81, Loss: 0.9674, Train: 72.76%, Valid: 71.38% Test: 70.38%
# Run: 01, Epoch: 82, Loss: 0.9651, Train: 72.74%, Valid: 71.50% Test: 70.59%
# Run: 01, Epoch: 83, Loss: 0.9636, Train: 72.71%, Valid: 71.47% Test: 70.71%
# Run: 01, Epoch: 84, Loss: 0.9600, Train: 72.76%, Valid: 71.45% Test: 70.75%
# Run: 01, Epoch: 85, Loss: 0.9616, Train: 72.93%, Valid: 71.37% Test: 70.56%
# Run: 01, Epoch: 86, Loss: 0.9603, Train: 72.96%, Valid: 71.46% Test: 70.61%
# Run: 01, Epoch: 87, Loss: 0.9573, Train: 73.01%, Valid: 71.61% Test: 70.95%
# Run: 01, Epoch: 88, Loss: 0.9552, Train: 73.01%, Valid: 71.67% Test: 71.23%
# Run: 01, Epoch: 89, Loss: 0.9533, Train: 72.97%, Valid: 71.61% Test: 71.44%
# Run: 01, Epoch: 90, Loss: 0.9494, Train: 73.06%, Valid: 71.62% Test: 71.40%
# Run: 01, Epoch: 91, Loss: 0.9504, Train: 73.19%, Valid: 71.67% Test: 71.04%
# Run: 01, Epoch: 92, Loss: 0.9452, Train: 73.13%, Valid: 71.53% Test: 70.31%
# Run: 01, Epoch: 93, Loss: 0.9479, Train: 73.11%, Valid: 71.39% Test: 70.10%
# Run: 01, Epoch: 94, Loss: 0.9454, Train: 73.17%, Valid: 71.42% Test: 70.31%
# Run: 01, Epoch: 95, Loss: 0.9433, Train: 73.20%, Valid: 71.51% Test: 70.50%
# Run: 01, Epoch: 96, Loss: 0.9430, Train: 73.25%, Valid: 71.68% Test: 70.77%
# Run: 01, Epoch: 97, Loss: 0.9434, Train: 73.30%, Valid: 71.76% Test: 70.92%
# Run: 01, Epoch: 98, Loss: 0.9418, Train: 73.33%, Valid: 71.79% Test: 71.18%
# Run: 01, Epoch: 99, Loss: 0.9387, Train: 73.44%, Valid: 71.82% Test: 71.01%
# Run: 01, Epoch: 100, Loss: 0.9367, Train: 73.52%, Valid: 71.71% Test: 70.67%
# Run: 01, Epoch: 101, Loss: 0.9373, Train: 73.52%, Valid: 71.60% Test: 70.49%
# Run: 01, Epoch: 102, Loss: 0.9368, Train: 73.53%, Valid: 71.55% Test: 70.23%
# Run: 01, Epoch: 103, Loss: 0.9348, Train: 73.47%, Valid: 71.57% Test: 70.24%
# Run: 01, Epoch: 104, Loss: 0.9344, Train: 73.54%, Valid: 71.83% Test: 70.91%
# Run: 01, Epoch: 105, Loss: 0.9322, Train: 73.60%, Valid: 71.88% Test: 71.29%
# Run: 01, Epoch: 106, Loss: 0.9301, Train: 73.68%, Valid: 71.97% Test: 71.47%
# Run: 01, Epoch: 107, Loss: 0.9301, Train: 73.71%, Valid: 71.88% Test: 71.06%
# Run: 01, Epoch: 108, Loss: 0.9276, Train: 73.61%, Valid: 71.69% Test: 70.42%
# Run: 01, Epoch: 109, Loss: 0.9283, Train: 73.76%, Valid: 71.80% Test: 70.61%
# Run: 01, Epoch: 110, Loss: 0.9253, Train: 73.75%, Valid: 71.90% Test: 71.14%
# Run: 01, Epoch: 111, Loss: 0.9265, Train: 73.62%, Valid: 71.84% Test: 71.19%
# Run: 01, Epoch: 112, Loss: 0.9231, Train: 73.60%, Valid: 71.78% Test: 71.19%
# Run: 01, Epoch: 113, Loss: 0.9210, Train: 73.77%, Valid: 71.85% Test: 71.12%
# Run: 01, Epoch: 114, Loss: 0.9204, Train: 73.90%, Valid: 71.77% Test: 70.74%
# Run: 01, Epoch: 115, Loss: 0.9204, Train: 73.94%, Valid: 71.42% Test: 70.12%
# Run: 01, Epoch: 116, Loss: 0.9184, Train: 73.89%, Valid: 71.45% Test: 70.16%
# Run: 01, Epoch: 117, Loss: 0.9157, Train: 73.94%, Valid: 71.85% Test: 71.04%
# Run: 01, Epoch: 118, Loss: 0.9152, Train: 73.96%, Valid: 72.06% Test: 71.24%
# Run: 01, Epoch: 119, Loss: 0.9147, Train: 73.95%, Valid: 71.99% Test: 71.36%
# Run: 01, Epoch: 120, Loss: 0.9133, Train: 74.01%, Valid: 72.06% Test: 71.32%
# Run: 01, Epoch: 121, Loss: 0.9125, Train: 74.09%, Valid: 72.00% Test: 70.80%
# Run: 01, Epoch: 122, Loss: 0.9105, Train: 74.07%, Valid: 71.49% Test: 69.97%
# Run: 01, Epoch: 123, Loss: 0.9129, Train: 74.14%, Valid: 71.59% Test: 70.31%
# Run: 01, Epoch: 124, Loss: 0.9070, Train: 74.23%, Valid: 71.77% Test: 70.93%
# Run: 01, Epoch: 125, Loss: 0.9084, Train: 74.25%, Valid: 72.03% Test: 71.32%
# Run: 01, Epoch: 126, Loss: 0.9068, Train: 74.29%, Valid: 72.00% Test: 71.18%
# Run: 01, Epoch: 127, Loss: 0.9026, Train: 74.35%, Valid: 72.05% Test: 71.13%
# Run: 01, Epoch: 128, Loss: 0.9053, Train: 74.32%, Valid: 72.02% Test: 71.14%
# Run: 01, Epoch: 129, Loss: 0.9067, Train: 74.28%, Valid: 72.07% Test: 71.19%
# Run: 01, Epoch: 130, Loss: 0.9022, Train: 74.29%, Valid: 72.06% Test: 70.94%
# Run: 01, Epoch: 131, Loss: 0.9033, Train: 74.27%, Valid: 71.78% Test: 70.31%
# Run: 01, Epoch: 132, Loss: 0.9020, Train: 74.39%, Valid: 71.60% Test: 69.81%
# Run: 01, Epoch: 133, Loss: 0.9024, Train: 74.54%, Valid: 72.12% Test: 70.92%
# Run: 01, Epoch: 134, Loss: 0.8968, Train: 74.60%, Valid: 71.97% Test: 70.98%
# Run: 01, Epoch: 135, Loss: 0.8975, Train: 74.59%, Valid: 71.91% Test: 70.70%
# Run: 01, Epoch: 136, Loss: 0.8955, Train: 74.62%, Valid: 71.89% Test: 70.72%
# Run: 01, Epoch: 137, Loss: 0.8971, Train: 74.63%, Valid: 72.18% Test: 71.10%
# Run: 01, Epoch: 138, Loss: 0.8923, Train: 74.66%, Valid: 72.18% Test: 71.23%
# Run: 01, Epoch: 139, Loss: 0.8944, Train: 74.70%, Valid: 72.13% Test: 70.91%
# Run: 01, Epoch: 140, Loss: 0.8919, Train: 74.52%, Valid: 71.88% Test: 70.63%
# Run: 01, Epoch: 141, Loss: 0.8904, Train: 74.57%, Valid: 72.07% Test: 71.29%
# Run: 01, Epoch: 142, Loss: 0.8916, Train: 74.67%, Valid: 72.28% Test: 71.57%
# Run: 01, Epoch: 143, Loss: 0.8889, Train: 74.67%, Valid: 72.30% Test: 71.58%
# Run: 01, Epoch: 144, Loss: 0.8875, Train: 74.72%, Valid: 72.30% Test: 71.56%
# Run: 01, Epoch: 145, Loss: 0.8868, Train: 74.71%, Valid: 72.22% Test: 71.48%
# Run: 01, Epoch: 146, Loss: 0.8860, Train: 74.69%, Valid: 72.04% Test: 70.71%
# Run: 01, Epoch: 147, Loss: 0.8871, Train: 74.73%, Valid: 71.97% Test: 70.50%
# Run: 01, Epoch: 148, Loss: 0.8857, Train: 74.90%, Valid: 72.32% Test: 71.51%
# Run: 01, Epoch: 149, Loss: 0.8839, Train: 74.90%, Valid: 72.26% Test: 71.82%
# Run: 01, Epoch: 150, Loss: 0.8845, Train: 74.91%, Valid: 72.06% Test: 70.98%
# Run: 01, Epoch: 151, Loss: 0.8825, Train: 74.82%, Valid: 71.13% Test: 69.39%
# Run: 01, Epoch: 152, Loss: 0.8805, Train: 74.86%, Valid: 71.48% Test: 69.88%
# Run: 01, Epoch: 153, Loss: 0.8804, Train: 74.96%, Valid: 72.17% Test: 71.41%
# Run: 01, Epoch: 154, Loss: 0.8798, Train: 74.97%, Valid: 72.29% Test: 71.62%
# Run: 01, Epoch: 155, Loss: 0.8803, Train: 75.09%, Valid: 72.11% Test: 70.88%
# Run: 01, Epoch: 156, Loss: 0.8757, Train: 74.89%, Valid: 71.71% Test: 69.99%
# Run: 01, Epoch: 157, Loss: 0.8763, Train: 74.96%, Valid: 71.88% Test: 70.29%
# Run: 01, Epoch: 158, Loss: 0.8739, Train: 75.07%, Valid: 72.04% Test: 70.93%
# Run: 01, Epoch: 159, Loss: 0.8745, Train: 75.14%, Valid: 72.17% Test: 71.34%
# Run: 01, Epoch: 160, Loss: 0.8729, Train: 75.17%, Valid: 72.28% Test: 71.49%
# Run: 01, Epoch: 161, Loss: 0.8718, Train: 75.18%, Valid: 72.23% Test: 71.32%
# Run: 01, Epoch: 162, Loss: 0.8723, Train: 75.21%, Valid: 72.19% Test: 71.25%
# Run: 01, Epoch: 163, Loss: 0.8747, Train: 75.20%, Valid: 71.59% Test: 69.96%
# Run: 01, Epoch: 164, Loss: 0.8703, Train: 75.16%, Valid: 71.58% Test: 70.07%
# Run: 01, Epoch: 165, Loss: 0.8685, Train: 75.26%, Valid: 72.01% Test: 70.75%
# Run: 01, Epoch: 166, Loss: 0.8664, Train: 75.36%, Valid: 72.04% Test: 70.66%
# Run: 01, Epoch: 167, Loss: 0.8684, Train: 75.40%, Valid: 72.10% Test: 70.73%
# Run: 01, Epoch: 168, Loss: 0.8678, Train: 75.30%, Valid: 71.85% Test: 70.37%
# Run: 01, Epoch: 169, Loss: 0.8672, Train: 75.39%, Valid: 71.95% Test: 70.52%
# Run: 01, Epoch: 170, Loss: 0.8672, Train: 75.41%, Valid: 72.48% Test: 71.33%
# Run: 01, Epoch: 171, Loss: 0.8657, Train: 75.26%, Valid: 72.21% Test: 71.28%
# Run: 01, Epoch: 172, Loss: 0.8655, Train: 75.30%, Valid: 71.98% Test: 70.45%
# Run: 01, Epoch: 173, Loss: 0.8625, Train: 75.30%, Valid: 71.73% Test: 69.98%
# Run: 01, Epoch: 174, Loss: 0.8624, Train: 75.35%, Valid: 71.95% Test: 70.41%
# Run: 01, Epoch: 175, Loss: 0.8606, Train: 75.39%, Valid: 72.46% Test: 71.65%
# Run: 01, Epoch: 176, Loss: 0.8624, Train: 75.40%, Valid: 72.43% Test: 71.78%
# Run: 01, Epoch: 177, Loss: 0.8607, Train: 75.61%, Valid: 72.32% Test: 71.39%
# Run: 01, Epoch: 178, Loss: 0.8612, Train: 75.58%, Valid: 72.04% Test: 70.61%
# Run: 01, Epoch: 179, Loss: 0.8581, Train: 75.59%, Valid: 72.03% Test: 70.82%
# Run: 01, Epoch: 180, Loss: 0.8576, Train: 75.61%, Valid: 72.17% Test: 70.88%
# Run: 01, Epoch: 181, Loss: 0.8570, Train: 75.60%, Valid: 71.77% Test: 69.80%
# Run: 01, Epoch: 182, Loss: 0.8545, Train: 75.54%, Valid: 72.31% Test: 70.92%
# Run: 01, Epoch: 183, Loss: 0.8565, Train: 75.47%, Valid: 72.37% Test: 71.71%
# Run: 01, Epoch: 184, Loss: 0.8572, Train: 75.60%, Valid: 72.47% Test: 71.67%
# Run: 01, Epoch: 185, Loss: 0.8555, Train: 75.73%, Valid: 72.42% Test: 71.20%
# Run: 01, Epoch: 186, Loss: 0.8524, Train: 75.66%, Valid: 72.58% Test: 71.77%
# Run: 01, Epoch: 187, Loss: 0.8526, Train: 75.73%, Valid: 72.43% Test: 71.54%
# Run: 01, Epoch: 188, Loss: 0.8492, Train: 75.75%, Valid: 71.67% Test: 69.81%
# Run: 01, Epoch: 189, Loss: 0.8494, Train: 75.75%, Valid: 71.58% Test: 70.04%
# Run: 01, Epoch: 190, Loss: 0.8498, Train: 75.57%, Valid: 72.17% Test: 71.59%
# Run: 01, Epoch: 191, Loss: 0.8533, Train: 75.74%, Valid: 72.55% Test: 71.85%
# Run: 01, Epoch: 192, Loss: 0.8498, Train: 75.87%, Valid: 72.50% Test: 71.24%
# Run: 01, Epoch: 193, Loss: 0.8499, Train: 75.78%, Valid: 72.21% Test: 71.08%
# Run: 01, Epoch: 194, Loss: 0.8477, Train: 75.93%, Valid: 72.20% Test: 71.06%
# Run: 01, Epoch: 195, Loss: 0.8451, Train: 75.74%, Valid: 71.86% Test: 70.27%
# Run: 01, Epoch: 196, Loss: 0.8475, Train: 75.52%, Valid: 72.41% Test: 71.81%
# Run: 01, Epoch: 197, Loss: 0.8467, Train: 75.52%, Valid: 72.26% Test: 71.85%
# Run: 01, Epoch: 198, Loss: 0.8433, Train: 75.95%, Valid: 72.30% Test: 70.84%
# Run: 01, Epoch: 199, Loss: 0.8416, Train: 75.82%, Valid: 71.76% Test: 69.74%
# Run: 01, Epoch: 200, Loss: 0.8428, Train: 75.91%, Valid: 72.05% Test: 70.61%
# Run: 01, Epoch: 201, Loss: 0.8409, Train: 76.02%, Valid: 72.30% Test: 71.37%
# Run: 01, Epoch: 202, Loss: 0.8444, Train: 75.99%, Valid: 72.33% Test: 71.14%
# Run: 01, Epoch: 203, Loss: 0.8402, Train: 75.89%, Valid: 72.65% Test: 71.56%
# Run: 01, Epoch: 204, Loss: 0.8400, Train: 75.88%, Valid: 72.59% Test: 71.97%
# Run: 01, Epoch: 205, Loss: 0.8387, Train: 76.04%, Valid: 72.52% Test: 71.57%
# Run: 01, Epoch: 206, Loss: 0.8406, Train: 75.97%, Valid: 71.91% Test: 70.49%
# Run: 01, Epoch: 207, Loss: 0.8381, Train: 76.06%, Valid: 71.87% Test: 70.37%
# Run: 01, Epoch: 208, Loss: 0.8369, Train: 76.07%, Valid: 72.54% Test: 71.75%
# Run: 01, Epoch: 209, Loss: 0.8383, Train: 75.81%, Valid: 72.43% Test: 72.24%
# Run: 01, Epoch: 210, Loss: 0.8369, Train: 75.94%, Valid: 72.76% Test: 71.91%
# Run: 01, Epoch: 211, Loss: 0.8345, Train: 76.12%, Valid: 72.36% Test: 70.51%
# Run: 01, Epoch: 212, Loss: 0.8390, Train: 76.05%, Valid: 72.26% Test: 70.22%
# Run: 01, Epoch: 213, Loss: 0.8325, Train: 76.26%, Valid: 72.40% Test: 70.66%
# Run: 01, Epoch: 214, Loss: 0.8328, Train: 76.13%, Valid: 72.18% Test: 70.44%
# Run: 01, Epoch: 215, Loss: 0.8333, Train: 76.19%, Valid: 72.40% Test: 71.02%
# Run: 01, Epoch: 216, Loss: 0.8321, Train: 76.17%, Valid: 72.41% Test: 71.27%
# Run: 01, Epoch: 217, Loss: 0.8282, Train: 76.40%, Valid: 71.67% Test: 69.57%
# Run: 01, Epoch: 218, Loss: 0.8327, Train: 76.26%, Valid: 71.66% Test: 69.94%
# Run: 01, Epoch: 219, Loss: 0.8306, Train: 76.40%, Valid: 72.61% Test: 71.34%
# Run: 01, Epoch: 220, Loss: 0.8304, Train: 76.37%, Valid: 72.67% Test: 71.72%
# Run: 01, Epoch: 221, Loss: 0.8271, Train: 76.40%, Valid: 72.42% Test: 71.06%
# Run: 01, Epoch: 222, Loss: 0.8288, Train: 76.44%, Valid: 72.49% Test: 71.22%
# Run: 01, Epoch: 223, Loss: 0.8275, Train: 76.44%, Valid: 72.32% Test: 71.09%
# Run: 01, Epoch: 224, Loss: 0.8263, Train: 76.37%, Valid: 72.21% Test: 70.91%
# Run: 01, Epoch: 225, Loss: 0.8271, Train: 76.26%, Valid: 72.03% Test: 70.69%
# Run: 01, Epoch: 226, Loss: 0.8242, Train: 76.18%, Valid: 72.22% Test: 71.41%
# Run: 01, Epoch: 227, Loss: 0.8264, Train: 76.63%, Valid: 72.40% Test: 71.13%
# Run: 01, Epoch: 228, Loss: 0.8235, Train: 76.39%, Valid: 72.60% Test: 71.63%
# Run: 01, Epoch: 229, Loss: 0.8251, Train: 76.45%, Valid: 72.49% Test: 71.16%
# Run: 01, Epoch: 230, Loss: 0.8234, Train: 76.60%, Valid: 72.54% Test: 71.53%
# Run: 01, Epoch: 231, Loss: 0.8195, Train: 76.75%, Valid: 72.47% Test: 71.36%
# Run: 01, Epoch: 232, Loss: 0.8211, Train: 76.63%, Valid: 72.57% Test: 71.48%
# Run: 01, Epoch: 233, Loss: 0.8214, Train: 76.74%, Valid: 72.56% Test: 71.50%
# Run: 01, Epoch: 234, Loss: 0.8209, Train: 76.67%, Valid: 72.50% Test: 71.32%
# Run: 01, Epoch: 235, Loss: 0.8193, Train: 76.76%, Valid: 72.70% Test: 71.49%
# Run: 01, Epoch: 236, Loss: 0.8203, Train: 76.60%, Valid: 72.77% Test: 71.61%
# Run: 01, Epoch: 237, Loss: 0.8191, Train: 76.57%, Valid: 72.77% Test: 71.70%
# Run: 01, Epoch: 238, Loss: 0.8176, Train: 76.68%, Valid: 72.59% Test: 71.30%
# Run: 01, Epoch: 239, Loss: 0.8190, Train: 76.44%, Valid: 72.43% Test: 71.65%
# Run: 01, Epoch: 240, Loss: 0.8176, Train: 76.69%, Valid: 71.95% Test: 70.10%
# Run: 01, Epoch: 241, Loss: 0.8184, Train: 76.71%, Valid: 71.92% Test: 70.06%
# Run: 01, Epoch: 242, Loss: 0.8162, Train: 76.88%, Valid: 72.45% Test: 71.20%
# Run: 01, Epoch: 243, Loss: 0.8159, Train: 76.80%, Valid: 71.99% Test: 70.56%
# Run: 01, Epoch: 244, Loss: 0.8134, Train: 76.79%, Valid: 72.45% Test: 71.29%
# Run: 01, Epoch: 245, Loss: 0.8130, Train: 76.77%, Valid: 72.31% Test: 71.48%
# Run: 01, Epoch: 246, Loss: 0.8141, Train: 76.48%, Valid: 71.56% Test: 69.66%
# Run: 01, Epoch: 247, Loss: 0.8142, Train: 76.72%, Valid: 72.78% Test: 71.85%
# Run: 01, Epoch: 248, Loss: 0.8112, Train: 76.71%, Valid: 72.75% Test: 71.69%
# Run: 01, Epoch: 249, Loss: 0.8112, Train: 76.30%, Valid: 71.31% Test: 68.81%
# Run: 01, Epoch: 250, Loss: 0.8153, Train: 76.72%, Valid: 72.02% Test: 70.25%
# Run: 01, Epoch: 251, Loss: 0.8109, Train: 76.46%, Valid: 71.91% Test: 71.01%
# Run: 01, Epoch: 252, Loss: 0.8073, Train: 77.01%, Valid: 72.08% Test: 70.60%
# Run: 01, Epoch: 253, Loss: 0.8085, Train: 76.75%, Valid: 71.49% Test: 69.71%
# Run: 01, Epoch: 254, Loss: 0.8096, Train: 77.04%, Valid: 72.92% Test: 72.39%
# Run: 01, Epoch: 255, Loss: 0.8072, Train: 76.46%, Valid: 72.40% Test: 72.13%
# Run: 01, Epoch: 256, Loss: 0.8115, Train: 76.87%, Valid: 72.77% Test: 71.78%
# Run: 01, Epoch: 257, Loss: 0.8077, Train: 76.97%, Valid: 72.68% Test: 71.49%
# Run: 01, Epoch: 258, Loss: 0.8083, Train: 76.94%, Valid: 72.73% Test: 71.79%
# Run: 01, Epoch: 259, Loss: 0.8072, Train: 76.79%, Valid: 71.81% Test: 70.36%
# Run: 01, Epoch: 260, Loss: 0.8034, Train: 76.69%, Valid: 71.45% Test: 69.62%
# Run: 01, Epoch: 261, Loss: 0.8032, Train: 76.87%, Valid: 72.58% Test: 71.49%
# Run: 01, Epoch: 262, Loss: 0.8044, Train: 76.83%, Valid: 72.83% Test: 72.31%
# Run: 01, Epoch: 263, Loss: 0.8042, Train: 77.00%, Valid: 72.56% Test: 71.64%
# Run: 01, Epoch: 264, Loss: 0.8019, Train: 77.16%, Valid: 72.63% Test: 71.64%
# Run: 01, Epoch: 265, Loss: 0.8038, Train: 77.08%, Valid: 72.62% Test: 71.56%
# Run: 01, Epoch: 266, Loss: 0.8019, Train: 77.12%, Valid: 72.59% Test: 71.63%
# Run: 01, Epoch: 267, Loss: 0.8033, Train: 77.11%, Valid: 72.23% Test: 70.81%
# Run: 01, Epoch: 268, Loss: 0.8011, Train: 77.11%, Valid: 72.79% Test: 72.23%
# Run: 01, Epoch: 269, Loss: 0.8003, Train: 77.02%, Valid: 72.66% Test: 72.24%
# Run: 01, Epoch: 270, Loss: 0.8002, Train: 77.10%, Valid: 72.57% Test: 71.77%
# Run: 01, Epoch: 271, Loss: 0.8006, Train: 77.21%, Valid: 72.83% Test: 71.81%
# Run: 01, Epoch: 272, Loss: 0.8006, Train: 77.16%, Valid: 72.79% Test: 72.06%
# Run: 01, Epoch: 273, Loss: 0.7977, Train: 77.21%, Valid: 72.45% Test: 71.10%
# Run: 01, Epoch: 274, Loss: 0.7951, Train: 77.22%, Valid: 72.46% Test: 71.02%
# Run: 01, Epoch: 275, Loss: 0.7984, Train: 77.25%, Valid: 72.71% Test: 71.23%
# Run: 01, Epoch: 276, Loss: 0.7979, Train: 77.26%, Valid: 72.05% Test: 69.88%
# Run: 01, Epoch: 277, Loss: 0.7965, Train: 77.20%, Valid: 71.85% Test: 69.47%
# Run: 01, Epoch: 278, Loss: 0.7944, Train: 77.24%, Valid: 72.91% Test: 71.97%
# Run: 01, Epoch: 279, Loss: 0.7946, Train: 77.29%, Valid: 73.04% Test: 72.14%
# Run: 01, Epoch: 280, Loss: 0.7951, Train: 77.26%, Valid: 72.44% Test: 71.10%
# Run: 01, Epoch: 281, Loss: 0.7933, Train: 77.17%, Valid: 72.51% Test: 71.68%
# Run: 01, Epoch: 282, Loss: 0.7939, Train: 77.33%, Valid: 72.78% Test: 71.97%
# Run: 01, Epoch: 283, Loss: 0.7929, Train: 77.36%, Valid: 72.18% Test: 70.81%
# Run: 01, Epoch: 284, Loss: 0.7911, Train: 77.47%, Valid: 72.47% Test: 71.21%
# Run: 01, Epoch: 285, Loss: 0.7893, Train: 77.45%, Valid: 72.38% Test: 71.13%
# Run: 01, Epoch: 286, Loss: 0.7897, Train: 77.48%, Valid: 72.16% Test: 70.38%
# Run: 01, Epoch: 287, Loss: 0.7905, Train: 77.57%, Valid: 72.81% Test: 71.83%
# Run: 01, Epoch: 288, Loss: 0.7941, Train: 77.43%, Valid: 72.99% Test: 72.34%
# Run: 01, Epoch: 289, Loss: 0.7883, Train: 77.39%, Valid: 72.62% Test: 71.85%
# Run: 01, Epoch: 290, Loss: 0.7894, Train: 77.38%, Valid: 72.71% Test: 72.03%
# Run: 01, Epoch: 291, Loss: 0.7914, Train: 77.55%, Valid: 72.47% Test: 70.87%
# Run: 01, Epoch: 292, Loss: 0.7903, Train: 77.45%, Valid: 71.88% Test: 69.36%
# Run: 01, Epoch: 293, Loss: 0.7907, Train: 77.42%, Valid: 72.50% Test: 71.10%
# Run: 01, Epoch: 294, Loss: 0.7886, Train: 77.44%, Valid: 72.23% Test: 70.81%
# Run: 01, Epoch: 295, Loss: 0.7902, Train: 77.72%, Valid: 72.76% Test: 71.63%
# Run: 01, Epoch: 296, Loss: 0.7862, Train: 77.67%, Valid: 72.62% Test: 71.53%
# Run: 01, Epoch: 297, Loss: 0.7869, Train: 77.77%, Valid: 72.71% Test: 71.52%
# Run: 01, Epoch: 298, Loss: 0.7850, Train: 77.39%, Valid: 72.78% Test: 72.24%
# Run: 01, Epoch: 299, Loss: 0.7877, Train: 77.13%, Valid: 71.24% Test: 68.88%
# Run: 01, Epoch: 300, Loss: 0.7891, Train: 77.63%, Valid: 72.30% Test: 70.82%
# Run: 01, Epoch: 301, Loss: 0.7860, Train: 77.14%, Valid: 72.10% Test: 71.08%
# Run: 01, Epoch: 302, Loss: 0.7860, Train: 77.52%, Valid: 72.35% Test: 70.85%
# Run: 01, Epoch: 303, Loss: 0.7873, Train: 77.37%, Valid: 72.73% Test: 72.21%
# Run: 01, Epoch: 304, Loss: 0.7841, Train: 76.91%, Valid: 71.97% Test: 71.83%
# Run: 01, Epoch: 305, Loss: 0.7865, Train: 77.57%, Valid: 72.11% Test: 70.46%
# Run: 01, Epoch: 306, Loss: 0.7857, Train: 77.65%, Valid: 72.06% Test: 69.93%
# Run: 01, Epoch: 307, Loss: 0.7822, Train: 77.30%, Valid: 72.67% Test: 71.67%
# Run: 01, Epoch: 308, Loss: 0.7818, Train: 77.41%, Valid: 72.49% Test: 71.37%
# Run: 01, Epoch: 309, Loss: 0.7833, Train: 77.50%, Valid: 71.94% Test: 70.28%
# Run: 01, Epoch: 310, Loss: 0.7853, Train: 77.39%, Valid: 72.31% Test: 71.30%
# Run: 01, Epoch: 311, Loss: 0.7805, Train: 77.60%, Valid: 72.47% Test: 71.38%
# Run: 01, Epoch: 312, Loss: 0.7812, Train: 77.68%, Valid: 71.58% Test: 69.44%
# Run: 01, Epoch: 313, Loss: 0.7792, Train: 77.71%, Valid: 72.66% Test: 71.31%
# Run: 01, Epoch: 314, Loss: 0.7797, Train: 77.84%, Valid: 73.30% Test: 72.44%
# Run: 01, Epoch: 315, Loss: 0.7797, Train: 77.80%, Valid: 73.20% Test: 72.48%
# Run: 01, Epoch: 316, Loss: 0.7778, Train: 77.48%, Valid: 72.58% Test: 72.37%
# Run: 01, Epoch: 317, Loss: 0.7765, Train: 77.79%, Valid: 72.76% Test: 71.65%
# Run: 01, Epoch: 318, Loss: 0.7786, Train: 77.87%, Valid: 72.49% Test: 70.99%
# Run: 01, Epoch: 319, Loss: 0.7760, Train: 77.63%, Valid: 72.29% Test: 71.03%
# Run: 01, Epoch: 320, Loss: 0.7767, Train: 77.43%, Valid: 72.05% Test: 70.61%
# Run: 01, Epoch: 321, Loss: 0.7766, Train: 77.38%, Valid: 71.72% Test: 69.76%
# Run: 01, Epoch: 322, Loss: 0.7762, Train: 77.93%, Valid: 72.40% Test: 70.60%
# Run: 01, Epoch: 323, Loss: 0.7755, Train: 77.85%, Valid: 72.52% Test: 70.96%
# Run: 01, Epoch: 324, Loss: 0.7751, Train: 77.69%, Valid: 72.91% Test: 72.58%
# Run: 01, Epoch: 325, Loss: 0.7747, Train: 77.54%, Valid: 72.99% Test: 72.62%
# Run: 01, Epoch: 326, Loss: 0.7762, Train: 77.91%, Valid: 72.79% Test: 72.53%
# Run: 01, Epoch: 327, Loss: 0.7714, Train: 78.05%, Valid: 72.71% Test: 72.03%
# Run: 01, Epoch: 328, Loss: 0.7727, Train: 78.12%, Valid: 72.73% Test: 71.53%
# Run: 01, Epoch: 329, Loss: 0.7725, Train: 77.90%, Valid: 72.03% Test: 70.25%
# Run: 01, Epoch: 330, Loss: 0.7724, Train: 78.01%, Valid: 72.67% Test: 71.14%
# Run: 01, Epoch: 331, Loss: 0.7692, Train: 77.88%, Valid: 71.98% Test: 69.76%
# Run: 01, Epoch: 332, Loss: 0.7709, Train: 78.08%, Valid: 72.93% Test: 71.53%
# Run: 01, Epoch: 333, Loss: 0.7688, Train: 78.11%, Valid: 72.84% Test: 72.13%
# Run: 01, Epoch: 334, Loss: 0.7683, Train: 78.25%, Valid: 72.58% Test: 71.30%
# Run: 01, Epoch: 335, Loss: 0.7692, Train: 78.19%, Valid: 72.88% Test: 71.99%
# Run: 01, Epoch: 336, Loss: 0.7685, Train: 78.13%, Valid: 72.05% Test: 70.93%
# Run: 01, Epoch: 337, Loss: 0.7677, Train: 77.90%, Valid: 71.44% Test: 70.13%
# Run: 01, Epoch: 338, Loss: 0.7698, Train: 77.91%, Valid: 72.45% Test: 71.59%
# Run: 01, Epoch: 339, Loss: 0.7703, Train: 77.84%, Valid: 72.66% Test: 72.38%
# Run: 01, Epoch: 340, Loss: 0.7683, Train: 78.12%, Valid: 72.76% Test: 71.81%
# Run: 01, Epoch: 341, Loss: 0.7679, Train: 78.06%, Valid: 72.67% Test: 71.66%
# Run: 01, Epoch: 342, Loss: 0.7658, Train: 77.91%, Valid: 72.17% Test: 70.32%
# Run: 01, Epoch: 343, Loss: 0.7675, Train: 78.30%, Valid: 71.69% Test: 69.69%
# Run: 01, Epoch: 344, Loss: 0.7663, Train: 77.82%, Valid: 71.72% Test: 70.21%
# Run: 01, Epoch: 345, Loss: 0.7686, Train: 78.19%, Valid: 72.54% Test: 70.95%
# Run: 01, Epoch: 346, Loss: 0.7646, Train: 78.28%, Valid: 72.72% Test: 71.41%
# Run: 01, Epoch: 347, Loss: 0.7663, Train: 78.22%, Valid: 72.83% Test: 72.04%
# Run: 01, Epoch: 348, Loss: 0.7658, Train: 78.30%, Valid: 72.61% Test: 71.44%
# Run: 01, Epoch: 349, Loss: 0.7662, Train: 78.22%, Valid: 72.08% Test: 70.14%
# Run: 01, Epoch: 350, Loss: 0.7634, Train: 77.60%, Valid: 71.67% Test: 70.23%
# Run: 01, Epoch: 351, Loss: 0.7606, Train: 78.17%, Valid: 72.14% Test: 70.52%
# Run: 01, Epoch: 352, Loss: 0.7604, Train: 77.96%, Valid: 72.19% Test: 70.53%
# Run: 01, Epoch: 353, Loss: 0.7633, Train: 78.03%, Valid: 72.70% Test: 71.91%
# Run: 01, Epoch: 354, Loss: 0.7629, Train: 78.29%, Valid: 72.84% Test: 71.97%
# Run: 01, Epoch: 355, Loss: 0.7601, Train: 77.89%, Valid: 72.68% Test: 71.84%
# Run: 01, Epoch: 356, Loss: 0.7610, Train: 78.11%, Valid: 72.84% Test: 72.01%
# Run: 01, Epoch: 357, Loss: 0.7604, Train: 78.32%, Valid: 72.61% Test: 71.22%
# Run: 01, Epoch: 358, Loss: 0.7609, Train: 78.34%, Valid: 72.31% Test: 71.08%
# Run: 01, Epoch: 359, Loss: 0.7611, Train: 78.24%, Valid: 72.69% Test: 72.07%
# Run: 01, Epoch: 360, Loss: 0.7607, Train: 78.24%, Valid: 72.42% Test: 71.74%
# Run: 01, Epoch: 361, Loss: 0.7599, Train: 78.40%, Valid: 71.85% Test: 70.32%
# Run: 01, Epoch: 362, Loss: 0.7594, Train: 78.30%, Valid: 71.89% Test: 70.10%
# Run: 01, Epoch: 363, Loss: 0.7587, Train: 78.50%, Valid: 72.25% Test: 70.21%
# Run: 01, Epoch: 364, Loss: 0.7589, Train: 78.41%, Valid: 72.18% Test: 69.87%
# Run: 01, Epoch: 365, Loss: 0.7635, Train: 78.17%, Valid: 72.70% Test: 71.72%
# Run: 01, Epoch: 366, Loss: 0.7573, Train: 78.36%, Valid: 72.00% Test: 69.96%
# Run: 01, Epoch: 367, Loss: 0.7574, Train: 78.44%, Valid: 72.72% Test: 71.43%
# Run: 01, Epoch: 368, Loss: 0.7579, Train: 78.43%, Valid: 72.75% Test: 71.77%
# Run: 01, Epoch: 369, Loss: 0.7561, Train: 78.35%, Valid: 72.62% Test: 71.87%
# Run: 01, Epoch: 370, Loss: 0.7555, Train: 78.35%, Valid: 72.69% Test: 72.02%
# Run: 01, Epoch: 371, Loss: 0.7561, Train: 78.34%, Valid: 72.59% Test: 71.87%
# Run: 01, Epoch: 372, Loss: 0.7573, Train: 78.45%, Valid: 72.05% Test: 70.36%
# Run: 01, Epoch: 373, Loss: 0.7575, Train: 78.54%, Valid: 72.62% Test: 71.46%
# Run: 01, Epoch: 374, Loss: 0.7556, Train: 78.63%, Valid: 72.78% Test: 71.14%
# Run: 01, Epoch: 375, Loss: 0.7555, Train: 78.58%, Valid: 72.87% Test: 71.54%
# Run: 01, Epoch: 376, Loss: 0.7560, Train: 78.22%, Valid: 72.58% Test: 71.62%
# Run: 01, Epoch: 377, Loss: 0.7531, Train: 78.57%, Valid: 71.87% Test: 69.81%
# Run: 01, Epoch: 378, Loss: 0.7558, Train: 78.41%, Valid: 71.80% Test: 69.64%
# Run: 01, Epoch: 379, Loss: 0.7562, Train: 78.86%, Valid: 72.52% Test: 70.83%
# Run: 01, Epoch: 380, Loss: 0.7539, Train: 78.61%, Valid: 72.53% Test: 70.81%
# Run: 01, Epoch: 381, Loss: 0.7526, Train: 78.43%, Valid: 72.94% Test: 71.99%
# Run: 01, Epoch: 382, Loss: 0.7535, Train: 78.55%, Valid: 73.07% Test: 72.02%
# Run: 01, Epoch: 383, Loss: 0.7517, Train: 78.60%, Valid: 72.99% Test: 71.85%
# Run: 01, Epoch: 384, Loss: 0.7507, Train: 78.21%, Valid: 72.15% Test: 71.05%
# Run: 01, Epoch: 385, Loss: 0.7540, Train: 78.63%, Valid: 72.01% Test: 69.68%
# Run: 01, Epoch: 386, Loss: 0.7511, Train: 78.54%, Valid: 71.63% Test: 69.37%
# Run: 01, Epoch: 387, Loss: 0.7499, Train: 78.53%, Valid: 72.16% Test: 70.46%
# Run: 01, Epoch: 388, Loss: 0.7525, Train: 78.69%, Valid: 72.95% Test: 71.66%
# Run: 01, Epoch: 389, Loss: 0.7506, Train: 78.55%, Valid: 72.93% Test: 72.14%
# Run: 01, Epoch: 390, Loss: 0.7510, Train: 78.80%, Valid: 72.82% Test: 71.18%
# Run: 01, Epoch: 391, Loss: 0.7503, Train: 78.53%, Valid: 71.57% Test: 69.32%
# Run: 01, Epoch: 392, Loss: 0.7491, Train: 78.51%, Valid: 72.54% Test: 71.56%
# Run: 01, Epoch: 393, Loss: 0.7473, Train: 78.66%, Valid: 72.93% Test: 71.90%
# Run: 01, Epoch: 394, Loss: 0.7491, Train: 78.72%, Valid: 72.89% Test: 71.71%
# Run: 01, Epoch: 395, Loss: 0.7483, Train: 78.72%, Valid: 72.60% Test: 71.48%
# Run: 01, Epoch: 396, Loss: 0.7485, Train: 78.69%, Valid: 72.64% Test: 71.26%
# Run: 01, Epoch: 397, Loss: 0.7485, Train: 78.58%, Valid: 72.58% Test: 71.07%
# Run: 01, Epoch: 398, Loss: 0.7456, Train: 77.68%, Valid: 71.09% Test: 70.65%
# Run: 01, Epoch: 399, Loss: 0.7458, Train: 78.49%, Valid: 72.62% Test: 71.47%
# Run: 01, Epoch: 400, Loss: 0.7489, Train: 78.71%, Valid: 72.71% Test: 71.58%
# Run: 01, Epoch: 401, Loss: 0.7475, Train: 78.82%, Valid: 73.03% Test: 71.89%
# Run: 01, Epoch: 402, Loss: 0.7459, Train: 78.83%, Valid: 72.64% Test: 71.07%
# Run: 01, Epoch: 403, Loss: 0.7464, Train: 78.55%, Valid: 72.67% Test: 71.75%
# Run: 01, Epoch: 404, Loss: 0.7440, Train: 78.55%, Valid: 72.69% Test: 72.18%
# Run: 01, Epoch: 405, Loss: 0.7470, Train: 78.78%, Valid: 72.82% Test: 71.91%
# Run: 01, Epoch: 406, Loss: 0.7458, Train: 78.70%, Valid: 73.10% Test: 72.43%
# Run: 01, Epoch: 407, Loss: 0.7421, Train: 78.51%, Valid: 72.74% Test: 72.02%
# Run: 01, Epoch: 408, Loss: 0.7461, Train: 78.44%, Valid: 71.32% Test: 68.86%
# Run: 01, Epoch: 409, Loss: 0.7473, Train: 78.05%, Valid: 70.84% Test: 67.72%
# Run: 01, Epoch: 410, Loss: 0.7451, Train: 78.76%, Valid: 72.50% Test: 70.95%
# Run: 01, Epoch: 411, Loss: 0.7480, Train: 78.59%, Valid: 72.40% Test: 70.79%
# Run: 01, Epoch: 412, Loss: 0.7452, Train: 78.56%, Valid: 72.22% Test: 71.37%
# Run: 01, Epoch: 413, Loss: 0.7419, Train: 78.74%, Valid: 72.76% Test: 71.53%
# Run: 01, Epoch: 414, Loss: 0.7426, Train: 78.80%, Valid: 72.31% Test: 70.37%
# Run: 01, Epoch: 415, Loss: 0.7452, Train: 78.99%, Valid: 72.76% Test: 71.06%
# Run: 01, Epoch: 416, Loss: 0.7434, Train: 78.97%, Valid: 72.87% Test: 71.53%
# Run: 01, Epoch: 417, Loss: 0.7409, Train: 78.97%, Valid: 72.58% Test: 71.21%
# Run: 01, Epoch: 418, Loss: 0.7376, Train: 78.86%, Valid: 72.30% Test: 70.92%
# Run: 01, Epoch: 419, Loss: 0.7424, Train: 78.83%, Valid: 72.47% Test: 71.32%
# Run: 01, Epoch: 420, Loss: 0.7382, Train: 78.76%, Valid: 72.26% Test: 70.44%
# Run: 01, Epoch: 421, Loss: 0.7395, Train: 78.86%, Valid: 72.86% Test: 71.70%
# Run: 01, Epoch: 422, Loss: 0.7378, Train: 78.94%, Valid: 72.87% Test: 71.55%
# Run: 01, Epoch: 423, Loss: 0.7402, Train: 78.84%, Valid: 73.01% Test: 72.02%
# Run: 01, Epoch: 424, Loss: 0.7427, Train: 78.58%, Valid: 72.76% Test: 72.01%
# Run: 01, Epoch: 425, Loss: 0.7410, Train: 78.88%, Valid: 72.57% Test: 71.52%
# Run: 01, Epoch: 426, Loss: 0.7434, Train: 78.93%, Valid: 72.68% Test: 72.13%
# Run: 01, Epoch: 427, Loss: 0.7391, Train: 78.92%, Valid: 72.43% Test: 71.09%
# Run: 01, Epoch: 428, Loss: 0.7375, Train: 78.91%, Valid: 72.42% Test: 71.01%
# Run: 01, Epoch: 429, Loss: 0.7395, Train: 78.85%, Valid: 72.61% Test: 71.52%
# Run: 01, Epoch: 430, Loss: 0.7387, Train: 78.81%, Valid: 72.35% Test: 70.96%
# Run: 01, Epoch: 431, Loss: 0.7383, Train: 79.15%, Valid: 72.35% Test: 70.50%
# Run: 01, Epoch: 432, Loss: 0.7362, Train: 78.92%, Valid: 72.86% Test: 71.98%
# Run: 01, Epoch: 433, Loss: 0.7379, Train: 79.05%, Valid: 72.85% Test: 71.42%
# Run: 01, Epoch: 434, Loss: 0.7363, Train: 78.99%, Valid: 72.58% Test: 71.11%
# Run: 01, Epoch: 435, Loss: 0.7396, Train: 78.92%, Valid: 72.59% Test: 71.34%
# Run: 01, Epoch: 436, Loss: 0.7374, Train: 79.18%, Valid: 73.10% Test: 71.88%
# Run: 01, Epoch: 437, Loss: 0.7364, Train: 78.82%, Valid: 72.78% Test: 71.87%
# Run: 01, Epoch: 438, Loss: 0.7363, Train: 78.61%, Valid: 72.63% Test: 71.50%
# Run: 01, Epoch: 439, Loss: 0.7375, Train: 78.69%, Valid: 72.10% Test: 70.36%
# Run: 01, Epoch: 440, Loss: 0.7393, Train: 78.91%, Valid: 72.86% Test: 71.64%
# Run: 01, Epoch: 441, Loss: 0.7362, Train: 79.11%, Valid: 72.15% Test: 70.23%
# Run: 01, Epoch: 442, Loss: 0.7350, Train: 79.06%, Valid: 72.51% Test: 71.04%
# Run: 01, Epoch: 443, Loss: 0.7377, Train: 78.91%, Valid: 72.61% Test: 72.08%
# Run: 01, Epoch: 444, Loss: 0.7353, Train: 79.13%, Valid: 72.56% Test: 71.68%
# Run: 01, Epoch: 445, Loss: 0.7320, Train: 78.94%, Valid: 72.11% Test: 70.80%
# Run: 01, Epoch: 446, Loss: 0.7343, Train: 79.16%, Valid: 71.99% Test: 69.62%
# Run: 01, Epoch: 447, Loss: 0.7315, Train: 78.90%, Valid: 71.50% Test: 68.92%
# Run: 01, Epoch: 448, Loss: 0.7329, Train: 78.85%, Valid: 71.49% Test: 68.68%
# Run: 01, Epoch: 449, Loss: 0.7326, Train: 79.03%, Valid: 71.90% Test: 69.53%
# Run: 01, Epoch: 450, Loss: 0.7329, Train: 79.10%, Valid: 72.33% Test: 71.05%
# Run: 01, Epoch: 451, Loss: 0.7314, Train: 79.26%, Valid: 72.85% Test: 71.35%
# Run: 01, Epoch: 452, Loss: 0.7325, Train: 79.31%, Valid: 72.74% Test: 70.96%
# Run: 01, Epoch: 453, Loss: 0.7301, Train: 79.20%, Valid: 72.82% Test: 71.73%
# Run: 01, Epoch: 454, Loss: 0.7312, Train: 79.08%, Valid: 72.59% Test: 71.26%
# Run: 01, Epoch: 455, Loss: 0.7295, Train: 79.34%, Valid: 72.87% Test: 71.36%
# Run: 01, Epoch: 456, Loss: 0.7299, Train: 79.27%, Valid: 72.60% Test: 70.71%
# Run: 01, Epoch: 457, Loss: 0.7319, Train: 79.28%, Valid: 72.34% Test: 70.16%
# Run: 01, Epoch: 458, Loss: 0.7280, Train: 79.28%, Valid: 72.38% Test: 70.24%
# Run: 01, Epoch: 459, Loss: 0.7304, Train: 79.27%, Valid: 72.21% Test: 69.80%
# Run: 01, Epoch: 460, Loss: 0.7318, Train: 79.00%, Valid: 71.61% Test: 69.11%
# Run: 01, Epoch: 461, Loss: 0.7289, Train: 79.22%, Valid: 72.97% Test: 71.91%
# Run: 01, Epoch: 462, Loss: 0.7259, Train: 78.92%, Valid: 72.83% Test: 72.00%
# Run: 01, Epoch: 463, Loss: 0.7291, Train: 79.18%, Valid: 73.09% Test: 72.11%
# Run: 01, Epoch: 464, Loss: 0.7294, Train: 79.06%, Valid: 72.74% Test: 71.18%
# Run: 01, Epoch: 465, Loss: 0.7277, Train: 79.19%, Valid: 72.29% Test: 70.52%
# Run: 01, Epoch: 466, Loss: 0.7279, Train: 79.14%, Valid: 72.70% Test: 71.53%
# Run: 01, Epoch: 467, Loss: 0.7295, Train: 79.30%, Valid: 72.19% Test: 70.08%
# Run: 01, Epoch: 468, Loss: 0.7277, Train: 79.42%, Valid: 72.90% Test: 70.88%
# Run: 01, Epoch: 469, Loss: 0.7253, Train: 79.36%, Valid: 72.60% Test: 71.26%
# Run: 01, Epoch: 470, Loss: 0.7281, Train: 79.22%, Valid: 72.13% Test: 70.16%
# Run: 01, Epoch: 471, Loss: 0.7258, Train: 79.27%, Valid: 72.59% Test: 70.91%
# Run: 01, Epoch: 472, Loss: 0.7242, Train: 79.24%, Valid: 72.35% Test: 70.03%
# Run: 01, Epoch: 473, Loss: 0.7231, Train: 79.36%, Valid: 72.92% Test: 71.31%
# Run: 01, Epoch: 474, Loss: 0.7261, Train: 78.74%, Valid: 71.23% Test: 68.52%
# Run: 01, Epoch: 475, Loss: 0.7274, Train: 78.92%, Valid: 72.73% Test: 71.75%
# Run: 01, Epoch: 476, Loss: 0.7254, Train: 79.29%, Valid: 72.83% Test: 72.05%
# Run: 01, Epoch: 477, Loss: 0.7247, Train: 79.24%, Valid: 72.60% Test: 70.99%
# Run: 01, Epoch: 478, Loss: 0.7270, Train: 79.14%, Valid: 72.95% Test: 72.02%
# Run: 01, Epoch: 479, Loss: 0.7268, Train: 79.23%, Valid: 72.63% Test: 71.38%
# Run: 01, Epoch: 480, Loss: 0.7264, Train: 79.32%, Valid: 72.34% Test: 70.47%
# Run: 01, Epoch: 481, Loss: 0.7239, Train: 79.13%, Valid: 72.90% Test: 71.70%
# Run: 01, Epoch: 482, Loss: 0.7279, Train: 79.28%, Valid: 72.55% Test: 71.06%
# Run: 01, Epoch: 483, Loss: 0.7236, Train: 79.33%, Valid: 73.01% Test: 71.95%
# Run: 01, Epoch: 484, Loss: 0.7225, Train: 79.40%, Valid: 72.77% Test: 71.41%
# Run: 01, Epoch: 485, Loss: 0.7230, Train: 79.56%, Valid: 72.68% Test: 70.71%
# Run: 01, Epoch: 486, Loss: 0.7256, Train: 79.35%, Valid: 72.62% Test: 70.86%
# Run: 01, Epoch: 487, Loss: 0.7212, Train: 79.40%, Valid: 72.05% Test: 69.61%
# Run: 01, Epoch: 488, Loss: 0.7236, Train: 79.18%, Valid: 72.64% Test: 70.67%
# Run: 01, Epoch: 489, Loss: 0.7238, Train: 79.28%, Valid: 72.90% Test: 71.63%
# Run: 01, Epoch: 490, Loss: 0.7225, Train: 79.30%, Valid: 72.95% Test: 72.07%
# Run: 01, Epoch: 491, Loss: 0.7234, Train: 79.49%, Valid: 72.91% Test: 71.77%
# Run: 01, Epoch: 492, Loss: 0.7218, Train: 79.21%, Valid: 72.70% Test: 71.11%
# Run: 01, Epoch: 493, Loss: 0.7216, Train: 79.48%, Valid: 72.85% Test: 71.52%
# Run: 01, Epoch: 494, Loss: 0.7188, Train: 79.48%, Valid: 72.28% Test: 70.21%
# Run: 01, Epoch: 495, Loss: 0.7254, Train: 79.43%, Valid: 72.25% Test: 70.56%
# Run: 01, Epoch: 496, Loss: 0.7198, Train: 79.64%, Valid: 72.88% Test: 71.49%
# Run: 01, Epoch: 497, Loss: 0.7202, Train: 79.49%, Valid: 71.87% Test: 69.91%
# Run: 01, Epoch: 498, Loss: 0.7216, Train: 79.44%, Valid: 71.48% Test: 69.37%
# Run: 01, Epoch: 499, Loss: 0.7201, Train: 79.66%, Valid: 72.41% Test: 70.27%
# Run: 01, Epoch: 500, Loss: 0.7190, Train: 79.59%, Valid: 72.27% Test: 69.96%
# Run 01:
# Highest Train: 79.66
# Highest Valid: 73.30
#   Final Train: 77.84
#    Final Test: 72.44
# Run: 02, Epoch: 01, Loss: 4.1358, Train: 22.47%, Valid: 27.71% Test: 24.78%
# Run: 02, Epoch: 02, Loss: 2.6321, Train: 35.16%, Valid: 37.28% Test: 33.72%
# Run: 02, Epoch: 03, Loss: 2.1637, Train: 34.84%, Valid: 37.43% Test: 43.22%
# Run: 02, Epoch: 04, Loss: 1.9196, Train: 41.77%, Valid: 47.36% Test: 51.96%
# Run: 02, Epoch: 05, Loss: 1.7809, Train: 47.48%, Valid: 53.14% Test: 55.27%
# Run: 02, Epoch: 06, Loss: 1.6930, Train: 45.61%, Valid: 49.60% Test: 49.59%
# Run: 02, Epoch: 07, Loss: 1.6193, Train: 41.68%, Valid: 44.04% Test: 44.69%
# Run: 02, Epoch: 08, Loss: 1.5534, Train: 39.09%, Valid: 39.52% Test: 42.08%
# Run: 02, Epoch: 09, Loss: 1.5005, Train: 38.21%, Valid: 36.45% Test: 40.34%
# Run: 02, Epoch: 10, Loss: 1.4555, Train: 38.84%, Valid: 36.41% Test: 40.98%
# Run: 02, Epoch: 11, Loss: 1.4194, Train: 40.14%, Valid: 38.81% Test: 44.45%
# Run: 02, Epoch: 12, Loss: 1.3857, Train: 41.18%, Valid: 42.00% Test: 48.53%
# Run: 02, Epoch: 13, Loss: 1.3606, Train: 41.82%, Valid: 44.69% Test: 51.54%
# Run: 02, Epoch: 14, Loss: 1.3297, Train: 42.01%, Valid: 45.94% Test: 52.59%
# Run: 02, Epoch: 15, Loss: 1.3123, Train: 42.63%, Valid: 46.77% Test: 52.96%
# Run: 02, Epoch: 16, Loss: 1.2877, Train: 43.45%, Valid: 46.96% Test: 52.82%
# Run: 02, Epoch: 17, Loss: 1.2690, Train: 44.94%, Valid: 47.77% Test: 53.26%
# Run: 02, Epoch: 18, Loss: 1.2535, Train: 46.72%, Valid: 49.19% Test: 54.20%
# Run: 02, Epoch: 19, Loss: 1.2387, Train: 48.96%, Valid: 51.33% Test: 55.57%
# Run: 02, Epoch: 20, Loss: 1.2277, Train: 50.98%, Valid: 53.44% Test: 56.38%
# Run: 02, Epoch: 21, Loss: 1.2141, Train: 52.59%, Valid: 54.64% Test: 56.93%
# Run: 02, Epoch: 22, Loss: 1.2025, Train: 54.14%, Valid: 56.05% Test: 58.12%
# Run: 02, Epoch: 23, Loss: 1.1932, Train: 55.70%, Valid: 57.51% Test: 59.60%
# Run: 02, Epoch: 24, Loss: 1.1784, Train: 56.88%, Valid: 58.70% Test: 61.00%
# Run: 02, Epoch: 25, Loss: 1.1688, Train: 57.72%, Valid: 59.10% Test: 61.68%
# Run: 02, Epoch: 26, Loss: 1.1581, Train: 58.70%, Valid: 59.59% Test: 62.13%
# Run: 02, Epoch: 27, Loss: 1.1545, Train: 59.77%, Valid: 60.33% Test: 62.56%
# Run: 02, Epoch: 28, Loss: 1.1445, Train: 60.87%, Valid: 61.03% Test: 62.83%
# Run: 02, Epoch: 29, Loss: 1.1359, Train: 61.81%, Valid: 61.61% Test: 63.21%
# Run: 02, Epoch: 30, Loss: 1.1280, Train: 62.95%, Valid: 62.26% Test: 63.79%
# Run: 02, Epoch: 31, Loss: 1.1181, Train: 64.16%, Valid: 63.60% Test: 64.62%
# Run: 02, Epoch: 32, Loss: 1.1169, Train: 65.24%, Valid: 64.65% Test: 65.62%
# Run: 02, Epoch: 33, Loss: 1.1081, Train: 66.28%, Valid: 65.77% Test: 66.47%
# Run: 02, Epoch: 34, Loss: 1.1054, Train: 67.05%, Valid: 66.62% Test: 67.07%
# Run: 02, Epoch: 35, Loss: 1.0991, Train: 67.55%, Valid: 67.36% Test: 67.45%
# Run: 02, Epoch: 36, Loss: 1.0909, Train: 67.95%, Valid: 67.79% Test: 67.78%
# Run: 02, Epoch: 37, Loss: 1.0866, Train: 68.29%, Valid: 68.10% Test: 68.12%
# Run: 02, Epoch: 38, Loss: 1.0818, Train: 68.59%, Valid: 68.35% Test: 68.37%
# Run: 02, Epoch: 39, Loss: 1.0793, Train: 68.72%, Valid: 68.46% Test: 68.63%
# Run: 02, Epoch: 40, Loss: 1.0724, Train: 68.86%, Valid: 68.57% Test: 68.85%
# Run: 02, Epoch: 41, Loss: 1.0704, Train: 68.84%, Valid: 68.37% Test: 68.99%
# Run: 02, Epoch: 42, Loss: 1.0640, Train: 68.80%, Valid: 68.32% Test: 68.99%
# Run: 02, Epoch: 43, Loss: 1.0594, Train: 68.93%, Valid: 68.38% Test: 69.05%
# Run: 02, Epoch: 44, Loss: 1.0576, Train: 69.40%, Valid: 68.88% Test: 69.28%
# Run: 02, Epoch: 45, Loss: 1.0531, Train: 69.87%, Valid: 69.40% Test: 69.57%
# Run: 02, Epoch: 46, Loss: 1.0485, Train: 70.16%, Valid: 69.67% Test: 69.50%
# Run: 02, Epoch: 47, Loss: 1.0466, Train: 70.35%, Valid: 69.81% Test: 69.43%
# Run: 02, Epoch: 48, Loss: 1.0405, Train: 70.44%, Valid: 69.89% Test: 69.44%
# Run: 02, Epoch: 49, Loss: 1.0395, Train: 70.51%, Valid: 69.87% Test: 69.60%
# Run: 02, Epoch: 50, Loss: 1.0380, Train: 70.55%, Valid: 69.92% Test: 69.77%
# Run: 02, Epoch: 51, Loss: 1.0330, Train: 70.67%, Valid: 70.11% Test: 69.94%
# Run: 02, Epoch: 52, Loss: 1.0300, Train: 70.82%, Valid: 70.18% Test: 69.92%
# Run: 02, Epoch: 53, Loss: 1.0261, Train: 70.92%, Valid: 70.27% Test: 69.88%
# Run: 02, Epoch: 54, Loss: 1.0208, Train: 71.03%, Valid: 70.41% Test: 69.78%
# Run: 02, Epoch: 55, Loss: 1.0234, Train: 71.02%, Valid: 70.44% Test: 69.63%
# Run: 02, Epoch: 56, Loss: 1.0170, Train: 71.03%, Valid: 70.44% Test: 69.56%
# Run: 02, Epoch: 57, Loss: 1.0162, Train: 71.16%, Valid: 70.51% Test: 69.58%
# Run: 02, Epoch: 58, Loss: 1.0119, Train: 71.36%, Valid: 70.59% Test: 69.57%
# Run: 02, Epoch: 59, Loss: 1.0112, Train: 71.58%, Valid: 70.62% Test: 69.51%
# Run: 02, Epoch: 60, Loss: 1.0099, Train: 71.74%, Valid: 70.58% Test: 69.36%
# Run: 02, Epoch: 61, Loss: 1.0044, Train: 71.77%, Valid: 70.55% Test: 69.32%
# Run: 02, Epoch: 62, Loss: 1.0022, Train: 71.78%, Valid: 70.51% Test: 69.19%
# Run: 02, Epoch: 63, Loss: 1.0010, Train: 71.84%, Valid: 70.40% Test: 68.80%
# Run: 02, Epoch: 64, Loss: 0.9967, Train: 71.92%, Valid: 70.17% Test: 68.41%
# Run: 02, Epoch: 65, Loss: 0.9961, Train: 72.02%, Valid: 70.07% Test: 68.39%
# Run: 02, Epoch: 66, Loss: 0.9920, Train: 72.10%, Valid: 70.19% Test: 68.57%
# Run: 02, Epoch: 67, Loss: 0.9934, Train: 72.17%, Valid: 70.35% Test: 68.72%
# Run: 02, Epoch: 68, Loss: 0.9902, Train: 72.21%, Valid: 70.32% Test: 68.68%
# Run: 02, Epoch: 69, Loss: 0.9907, Train: 72.24%, Valid: 70.30% Test: 68.60%
# Run: 02, Epoch: 70, Loss: 0.9882, Train: 72.25%, Valid: 70.18% Test: 68.30%
# Run: 02, Epoch: 71, Loss: 0.9850, Train: 72.26%, Valid: 70.18% Test: 68.28%
# Run: 02, Epoch: 72, Loss: 0.9842, Train: 72.36%, Valid: 70.36% Test: 68.82%
# Run: 02, Epoch: 73, Loss: 0.9806, Train: 72.39%, Valid: 70.61% Test: 69.17%
# Run: 02, Epoch: 74, Loss: 0.9792, Train: 72.45%, Valid: 70.77% Test: 69.36%
# Run: 02, Epoch: 75, Loss: 0.9782, Train: 72.54%, Valid: 70.83% Test: 69.34%
# Run: 02, Epoch: 76, Loss: 0.9739, Train: 72.55%, Valid: 70.87% Test: 69.22%
# Run: 02, Epoch: 77, Loss: 0.9723, Train: 72.61%, Valid: 71.00% Test: 69.42%
# Run: 02, Epoch: 78, Loss: 0.9719, Train: 72.63%, Valid: 71.36% Test: 69.99%
# Run: 02, Epoch: 79, Loss: 0.9696, Train: 72.68%, Valid: 71.40% Test: 70.42%
# Run: 02, Epoch: 80, Loss: 0.9685, Train: 72.75%, Valid: 71.41% Test: 70.51%
# Run: 02, Epoch: 81, Loss: 0.9619, Train: 72.84%, Valid: 71.36% Test: 70.31%
# Run: 02, Epoch: 82, Loss: 0.9603, Train: 72.94%, Valid: 71.20% Test: 69.79%
# Run: 02, Epoch: 83, Loss: 0.9628, Train: 72.94%, Valid: 70.82% Test: 69.16%
# Run: 02, Epoch: 84, Loss: 0.9609, Train: 73.00%, Valid: 71.00% Test: 69.44%
# Run: 02, Epoch: 85, Loss: 0.9564, Train: 73.01%, Valid: 71.45% Test: 70.34%
# Run: 02, Epoch: 86, Loss: 0.9572, Train: 73.09%, Valid: 71.41% Test: 70.28%
# Run: 02, Epoch: 87, Loss: 0.9532, Train: 73.12%, Valid: 71.42% Test: 70.18%
# Run: 02, Epoch: 88, Loss: 0.9500, Train: 73.05%, Valid: 71.32% Test: 70.03%
# Run: 02, Epoch: 89, Loss: 0.9528, Train: 73.05%, Valid: 71.16% Test: 69.78%
# Run: 02, Epoch: 90, Loss: 0.9506, Train: 73.07%, Valid: 71.04% Test: 69.54%
# Run: 02, Epoch: 91, Loss: 0.9490, Train: 73.16%, Valid: 71.24% Test: 69.91%
# Run: 02, Epoch: 92, Loss: 0.9499, Train: 73.16%, Valid: 71.34% Test: 70.25%
# Run: 02, Epoch: 93, Loss: 0.9448, Train: 73.13%, Valid: 71.28% Test: 70.26%
# Run: 02, Epoch: 94, Loss: 0.9438, Train: 73.15%, Valid: 71.30% Test: 70.20%
# Run: 02, Epoch: 95, Loss: 0.9443, Train: 73.24%, Valid: 71.25% Test: 70.10%
# Run: 02, Epoch: 96, Loss: 0.9432, Train: 73.34%, Valid: 71.27% Test: 69.88%
# Run: 02, Epoch: 97, Loss: 0.9395, Train: 73.48%, Valid: 71.29% Test: 69.90%
# Run: 02, Epoch: 98, Loss: 0.9382, Train: 73.50%, Valid: 71.51% Test: 70.26%
# Run: 02, Epoch: 99, Loss: 0.9416, Train: 73.60%, Valid: 71.53% Test: 70.38%
# Run: 02, Epoch: 100, Loss: 0.9373, Train: 73.58%, Valid: 71.64% Test: 70.51%
# Run: 02, Epoch: 101, Loss: 0.9363, Train: 73.57%, Valid: 71.63% Test: 70.49%
# Run: 02, Epoch: 102, Loss: 0.9342, Train: 73.66%, Valid: 71.70% Test: 70.71%
# Run: 02, Epoch: 103, Loss: 0.9337, Train: 73.69%, Valid: 71.67% Test: 70.87%
# Run: 02, Epoch: 104, Loss: 0.9310, Train: 73.74%, Valid: 71.55% Test: 70.60%
# Run: 02, Epoch: 105, Loss: 0.9303, Train: 73.76%, Valid: 71.51% Test: 70.51%
# Run: 02, Epoch: 106, Loss: 0.9294, Train: 73.66%, Valid: 71.55% Test: 70.57%
# Run: 02, Epoch: 107, Loss: 0.9291, Train: 73.70%, Valid: 71.63% Test: 70.79%
# Run: 02, Epoch: 108, Loss: 0.9248, Train: 73.78%, Valid: 71.64% Test: 70.82%
# Run: 02, Epoch: 109, Loss: 0.9261, Train: 73.88%, Valid: 71.87% Test: 71.08%
# Run: 02, Epoch: 110, Loss: 0.9234, Train: 73.96%, Valid: 71.94% Test: 70.93%
# Run: 02, Epoch: 111, Loss: 0.9207, Train: 73.89%, Valid: 71.72% Test: 70.60%
# Run: 02, Epoch: 112, Loss: 0.9213, Train: 73.85%, Valid: 71.63% Test: 70.75%
# Run: 02, Epoch: 113, Loss: 0.9187, Train: 73.91%, Valid: 71.84% Test: 71.22%
# Run: 02, Epoch: 114, Loss: 0.9205, Train: 74.04%, Valid: 71.81% Test: 71.02%
# Run: 02, Epoch: 115, Loss: 0.9174, Train: 74.13%, Valid: 71.62% Test: 70.47%
# Run: 02, Epoch: 116, Loss: 0.9183, Train: 74.18%, Valid: 71.46% Test: 70.08%
# Run: 02, Epoch: 117, Loss: 0.9156, Train: 74.24%, Valid: 71.72% Test: 70.66%
# Run: 02, Epoch: 118, Loss: 0.9132, Train: 74.22%, Valid: 71.76% Test: 71.17%
# Run: 02, Epoch: 119, Loss: 0.9116, Train: 74.16%, Valid: 71.79% Test: 71.24%
# Run: 02, Epoch: 120, Loss: 0.9117, Train: 74.13%, Valid: 71.56% Test: 70.51%
# Run: 02, Epoch: 121, Loss: 0.9097, Train: 74.07%, Valid: 71.65% Test: 70.44%
# Run: 02, Epoch: 122, Loss: 0.9074, Train: 74.10%, Valid: 71.94% Test: 70.96%
# Run: 02, Epoch: 123, Loss: 0.9079, Train: 74.11%, Valid: 71.94% Test: 71.15%
# Run: 02, Epoch: 124, Loss: 0.9082, Train: 74.19%, Valid: 71.96% Test: 70.55%
# Run: 02, Epoch: 125, Loss: 0.9067, Train: 74.19%, Valid: 71.59% Test: 70.02%
# Run: 02, Epoch: 126, Loss: 0.9033, Train: 74.21%, Valid: 71.79% Test: 70.74%
# Run: 02, Epoch: 127, Loss: 0.9039, Train: 74.47%, Valid: 72.04% Test: 71.20%
# Run: 02, Epoch: 128, Loss: 0.9010, Train: 74.54%, Valid: 72.02% Test: 71.44%
# Run: 02, Epoch: 129, Loss: 0.9032, Train: 74.60%, Valid: 71.92% Test: 71.36%
# Run: 02, Epoch: 130, Loss: 0.9008, Train: 74.59%, Valid: 71.97% Test: 71.52%
# Run: 02, Epoch: 131, Loss: 0.9008, Train: 74.64%, Valid: 72.09% Test: 70.97%
# Run: 02, Epoch: 132, Loss: 0.8983, Train: 74.68%, Valid: 71.72% Test: 70.32%
# Run: 02, Epoch: 133, Loss: 0.9004, Train: 74.56%, Valid: 71.51% Test: 70.22%
# Run: 02, Epoch: 134, Loss: 0.8988, Train: 74.42%, Valid: 71.56% Test: 70.51%
# Run: 02, Epoch: 135, Loss: 0.8966, Train: 74.45%, Valid: 71.96% Test: 70.93%
# Run: 02, Epoch: 136, Loss: 0.8926, Train: 74.38%, Valid: 71.87% Test: 70.64%
# Run: 02, Epoch: 137, Loss: 0.8938, Train: 74.57%, Valid: 72.21% Test: 71.39%
# Run: 02, Epoch: 138, Loss: 0.8924, Train: 74.54%, Valid: 72.09% Test: 71.80%
# Run: 02, Epoch: 139, Loss: 0.8934, Train: 74.60%, Valid: 72.03% Test: 71.51%
# Run: 02, Epoch: 140, Loss: 0.8894, Train: 74.68%, Valid: 71.75% Test: 70.42%
# Run: 02, Epoch: 141, Loss: 0.8918, Train: 74.74%, Valid: 71.68% Test: 70.37%
# Run: 02, Epoch: 142, Loss: 0.8870, Train: 74.85%, Valid: 71.97% Test: 70.59%
# Run: 02, Epoch: 143, Loss: 0.8869, Train: 74.90%, Valid: 71.98% Test: 70.49%
# Run: 02, Epoch: 144, Loss: 0.8851, Train: 74.90%, Valid: 71.86% Test: 70.39%
# Run: 02, Epoch: 145, Loss: 0.8875, Train: 74.87%, Valid: 71.96% Test: 70.58%
# Run: 02, Epoch: 146, Loss: 0.8854, Train: 74.75%, Valid: 72.26% Test: 71.32%
# Run: 02, Epoch: 147, Loss: 0.8850, Train: 74.44%, Valid: 72.16% Test: 71.59%
# Run: 02, Epoch: 148, Loss: 0.8822, Train: 74.64%, Valid: 72.31% Test: 71.60%
# Run: 02, Epoch: 149, Loss: 0.8820, Train: 74.89%, Valid: 72.44% Test: 71.43%
# Run: 02, Epoch: 150, Loss: 0.8779, Train: 75.03%, Valid: 72.08% Test: 70.79%
# Run: 02, Epoch: 151, Loss: 0.8795, Train: 75.23%, Valid: 71.96% Test: 70.76%
# Run: 02, Epoch: 152, Loss: 0.8803, Train: 75.13%, Valid: 71.89% Test: 70.74%
# Run: 02, Epoch: 153, Loss: 0.8788, Train: 75.01%, Valid: 71.69% Test: 70.70%
# Run: 02, Epoch: 154, Loss: 0.8768, Train: 75.06%, Valid: 72.08% Test: 71.08%
# Run: 02, Epoch: 155, Loss: 0.8768, Train: 75.06%, Valid: 72.33% Test: 71.42%
# Run: 02, Epoch: 156, Loss: 0.8738, Train: 75.03%, Valid: 72.35% Test: 71.56%
# Run: 02, Epoch: 157, Loss: 0.8741, Train: 75.13%, Valid: 72.50% Test: 71.52%
# Run: 02, Epoch: 158, Loss: 0.8716, Train: 75.20%, Valid: 72.38% Test: 71.22%
# Run: 02, Epoch: 159, Loss: 0.8721, Train: 75.26%, Valid: 72.19% Test: 71.04%
# Run: 02, Epoch: 160, Loss: 0.8701, Train: 75.23%, Valid: 71.71% Test: 69.94%
# Run: 02, Epoch: 161, Loss: 0.8681, Train: 75.13%, Valid: 71.29% Test: 69.30%
# Run: 02, Epoch: 162, Loss: 0.8702, Train: 75.36%, Valid: 71.85% Test: 70.26%
# Run: 02, Epoch: 163, Loss: 0.8675, Train: 75.43%, Valid: 72.21% Test: 70.86%
# Run: 02, Epoch: 164, Loss: 0.8702, Train: 75.49%, Valid: 71.97% Test: 70.59%
# Run: 02, Epoch: 165, Loss: 0.8658, Train: 75.28%, Valid: 71.45% Test: 69.51%
# Run: 02, Epoch: 166, Loss: 0.8649, Train: 75.48%, Valid: 71.68% Test: 70.21%
# Run: 02, Epoch: 167, Loss: 0.8661, Train: 75.37%, Valid: 72.03% Test: 71.24%
# Run: 02, Epoch: 168, Loss: 0.8647, Train: 75.25%, Valid: 72.17% Test: 71.48%
# Run: 02, Epoch: 169, Loss: 0.8640, Train: 75.41%, Valid: 72.05% Test: 70.82%
# Run: 02, Epoch: 170, Loss: 0.8635, Train: 75.48%, Valid: 72.04% Test: 70.94%
# Run: 02, Epoch: 171, Loss: 0.8641, Train: 75.58%, Valid: 72.23% Test: 71.29%
# Run: 02, Epoch: 172, Loss: 0.8656, Train: 75.49%, Valid: 72.32% Test: 71.11%
# Run: 02, Epoch: 173, Loss: 0.8614, Train: 75.34%, Valid: 72.47% Test: 71.40%
# Run: 02, Epoch: 174, Loss: 0.8631, Train: 74.98%, Valid: 72.16% Test: 71.74%
# Run: 02, Epoch: 175, Loss: 0.8593, Train: 75.42%, Valid: 72.47% Test: 71.56%
# Run: 02, Epoch: 176, Loss: 0.8572, Train: 75.36%, Valid: 71.35% Test: 69.30%
# Run: 02, Epoch: 177, Loss: 0.8571, Train: 75.60%, Valid: 71.64% Test: 69.82%
# Run: 02, Epoch: 178, Loss: 0.8581, Train: 75.76%, Valid: 72.49% Test: 71.48%
# ...
# Run: 10, Epoch: 296, Loss: 0.7835, Train: 77.38%, Valid: 71.62% Test: 69.68%
# Run: 10, Epoch: 297, Loss: 0.7819, Train: 77.68%, Valid: 72.42% Test: 71.01%
# Run: 10, Epoch: 298, Loss: 0.7762, Train: 77.72%, Valid: 72.61% Test: 71.79%
# Run: 10, Epoch: 299, Loss: 0.7792, Train: 77.65%, Valid: 72.22% Test: 71.20%
# Run: 10, Epoch: 300, Loss: 0.7807, Train: 77.60%, Valid: 72.64% Test: 71.52%
# Run: 10, Epoch: 301, Loss: 0.7812, Train: 77.23%, Valid: 72.36% Test: 71.52%
# Run: 10, Epoch: 302, Loss: 0.7800, Train: 77.75%, Valid: 72.73% Test: 71.35%
# Run: 10, Epoch: 303, Loss: 0.7780, Train: 77.75%, Valid: 72.62% Test: 71.41%
# Run: 10, Epoch: 304, Loss: 0.7787, Train: 77.49%, Valid: 72.07% Test: 70.38%
# Run: 10, Epoch: 305, Loss: 0.7764, Train: 77.62%, Valid: 71.58% Test: 69.33%
# Run: 10, Epoch: 306, Loss: 0.7775, Train: 77.92%, Valid: 72.75% Test: 71.49%
# Run: 10, Epoch: 307, Loss: 0.7759, Train: 77.87%, Valid: 72.92% Test: 72.19%
# Run: 10, Epoch: 308, Loss: 0.7784, Train: 77.90%, Valid: 72.73% Test: 71.31%
# Run: 10, Epoch: 309, Loss: 0.7742, Train: 77.71%, Valid: 71.86% Test: 70.16%
# Run: 10, Epoch: 310, Loss: 0.7740, Train: 77.81%, Valid: 72.73% Test: 71.93%
# Run: 10, Epoch: 311, Loss: 0.7747, Train: 78.00%, Valid: 72.76% Test: 71.63%
# Run: 10, Epoch: 312, Loss: 0.7729, Train: 77.88%, Valid: 72.41% Test: 70.88%
# Run: 10, Epoch: 313, Loss: 0.7738, Train: 77.88%, Valid: 72.32% Test: 70.80%
# Run: 10, Epoch: 314, Loss: 0.7751, Train: 78.10%, Valid: 72.54% Test: 71.17%
# Run: 10, Epoch: 315, Loss: 0.7724, Train: 78.04%, Valid: 72.62% Test: 71.75%
# Run: 10, Epoch: 316, Loss: 0.7727, Train: 77.66%, Valid: 72.42% Test: 70.94%
# Run: 10, Epoch: 317, Loss: 0.7722, Train: 77.88%, Valid: 72.24% Test: 70.59%
# Run: 10, Epoch: 318, Loss: 0.7735, Train: 77.80%, Valid: 72.68% Test: 71.89%
# Run: 10, Epoch: 319, Loss: 0.7693, Train: 77.91%, Valid: 72.68% Test: 71.85%
# Run: 10, Epoch: 320, Loss: 0.7728, Train: 77.88%, Valid: 72.59% Test: 72.00%
# Run: 10, Epoch: 321, Loss: 0.7698, Train: 77.90%, Valid: 72.69% Test: 71.48%
# Run: 10, Epoch: 322, Loss: 0.7673, Train: 77.95%, Valid: 72.49% Test: 71.54%
# Run: 10, Epoch: 323, Loss: 0.7709, Train: 78.11%, Valid: 72.42% Test: 70.57%
# Run: 10, Epoch: 324, Loss: 0.7700, Train: 77.88%, Valid: 71.44% Test: 69.15%
# Run: 10, Epoch: 325, Loss: 0.7661, Train: 77.91%, Valid: 72.79% Test: 71.65%
# Run: 10, Epoch: 326, Loss: 0.7682, Train: 78.00%, Valid: 72.90% Test: 71.87%
# Run: 10, Epoch: 327, Loss: 0.7677, Train: 78.29%, Valid: 72.28% Test: 70.71%
# Run: 10, Epoch: 328, Loss: 0.7676, Train: 77.78%, Valid: 72.49% Test: 71.72%
# Run: 10, Epoch: 329, Loss: 0.7694, Train: 78.24%, Valid: 72.93% Test: 72.04%
# Run: 10, Epoch: 330, Loss: 0.7681, Train: 77.91%, Valid: 71.39% Test: 69.36%
# Run: 10, Epoch: 331, Loss: 0.7685, Train: 78.07%, Valid: 72.35% Test: 71.18%
# Run: 10, Epoch: 332, Loss: 0.7650, Train: 77.63%, Valid: 72.43% Test: 71.75%
# Run: 10, Epoch: 333, Loss: 0.7671, Train: 77.73%, Valid: 72.60% Test: 71.29%
# Run: 10, Epoch: 334, Loss: 0.7652, Train: 78.06%, Valid: 72.61% Test: 71.00%
# Run: 10, Epoch: 335, Loss: 0.7645, Train: 78.02%, Valid: 72.50% Test: 71.07%
# Run: 10, Epoch: 336, Loss: 0.7657, Train: 78.18%, Valid: 72.42% Test: 70.36%
# Run: 10, Epoch: 337, Loss: 0.7653, Train: 78.15%, Valid: 72.00% Test: 70.08%
# Run: 10, Epoch: 338, Loss: 0.7622, Train: 78.05%, Valid: 72.35% Test: 71.34%
# Run: 10, Epoch: 339, Loss: 0.7634, Train: 78.39%, Valid: 72.55% Test: 71.04%
# Run: 10, Epoch: 340, Loss: 0.7640, Train: 78.31%, Valid: 72.54% Test: 70.87%
# Run: 10, Epoch: 341, Loss: 0.7624, Train: 78.31%, Valid: 72.83% Test: 71.67%
# Run: 10, Epoch: 342, Loss: 0.7630, Train: 78.15%, Valid: 72.70% Test: 71.37%
# Run: 10, Epoch: 343, Loss: 0.7627, Train: 78.42%, Valid: 72.61% Test: 71.43%
# Run: 10, Epoch: 344, Loss: 0.7610, Train: 78.62%, Valid: 72.52% Test: 71.32%
# Run: 10, Epoch: 345, Loss: 0.7614, Train: 78.46%, Valid: 72.06% Test: 70.81%
# Run: 10, Epoch: 346, Loss: 0.7586, Train: 78.17%, Valid: 72.03% Test: 70.82%
# Run: 10, Epoch: 347, Loss: 0.7595, Train: 78.30%, Valid: 72.57% Test: 71.81%
# Run: 10, Epoch: 348, Loss: 0.7592, Train: 78.26%, Valid: 72.73% Test: 71.72%
# Run: 10, Epoch: 349, Loss: 0.7572, Train: 78.49%, Valid: 72.49% Test: 70.82%
# Run: 10, Epoch: 350, Loss: 0.7579, Train: 78.27%, Valid: 71.34% Test: 68.92%
# Run: 10, Epoch: 351, Loss: 0.7597, Train: 78.24%, Valid: 72.27% Test: 70.65%
# Run: 10, Epoch: 352, Loss: 0.7588, Train: 78.14%, Valid: 72.21% Test: 70.74%
# Run: 10, Epoch: 353, Loss: 0.7565, Train: 78.02%, Valid: 71.01% Test: 68.61%
# Run: 10, Epoch: 354, Loss: 0.7604, Train: 78.22%, Valid: 72.53% Test: 70.68%
# Run: 10, Epoch: 355, Loss: 0.7577, Train: 78.19%, Valid: 72.84% Test: 71.80%
# Run: 10, Epoch: 356, Loss: 0.7584, Train: 78.42%, Valid: 73.09% Test: 71.95%
# Run: 10, Epoch: 357, Loss: 0.7544, Train: 78.33%, Valid: 72.61% Test: 70.97%
# Run: 10, Epoch: 358, Loss: 0.7553, Train: 78.35%, Valid: 72.34% Test: 70.76%
# Run: 10, Epoch: 359, Loss: 0.7577, Train: 78.23%, Valid: 72.40% Test: 71.21%
# Run: 10, Epoch: 360, Loss: 0.7576, Train: 78.18%, Valid: 71.99% Test: 70.21%
# Run: 10, Epoch: 361, Loss: 0.7568, Train: 78.20%, Valid: 71.86% Test: 70.33%
# Run: 10, Epoch: 362, Loss: 0.7560, Train: 78.48%, Valid: 72.52% Test: 71.38%
# Run: 10, Epoch: 363, Loss: 0.7562, Train: 78.50%, Valid: 72.70% Test: 71.35%
# Run: 10, Epoch: 364, Loss: 0.7544, Train: 78.37%, Valid: 71.61% Test: 69.51%
# Run: 10, Epoch: 365, Loss: 0.7538, Train: 78.41%, Valid: 72.31% Test: 70.85%
# Run: 10, Epoch: 366, Loss: 0.7556, Train: 78.69%, Valid: 72.85% Test: 71.49%
# Run: 10, Epoch: 367, Loss: 0.7518, Train: 78.66%, Valid: 72.74% Test: 70.85%
# Run: 10, Epoch: 368, Loss: 0.7522, Train: 78.36%, Valid: 72.45% Test: 70.63%
# Run: 10, Epoch: 369, Loss: 0.7512, Train: 78.56%, Valid: 72.44% Test: 70.80%
# Run: 10, Epoch: 370, Loss: 0.7529, Train: 78.43%, Valid: 71.43% Test: 68.89%
# Run: 10, Epoch: 371, Loss: 0.7539, Train: 78.68%, Valid: 72.77% Test: 71.34%
# Run: 10, Epoch: 372, Loss: 0.7492, Train: 78.76%, Valid: 72.94% Test: 71.74%
# Run: 10, Epoch: 373, Loss: 0.7524, Train: 78.71%, Valid: 72.65% Test: 71.25%
# Run: 10, Epoch: 374, Loss: 0.7486, Train: 78.49%, Valid: 72.06% Test: 70.55%
# Run: 10, Epoch: 375, Loss: 0.7504, Train: 78.53%, Valid: 72.55% Test: 71.46%
# Run: 10, Epoch: 376, Loss: 0.7508, Train: 78.70%, Valid: 72.59% Test: 71.59%
# Run: 10, Epoch: 377, Loss: 0.7482, Train: 78.61%, Valid: 72.48% Test: 70.56%
# Run: 10, Epoch: 378, Loss: 0.7529, Train: 78.61%, Valid: 72.50% Test: 70.79%
# Run: 10, Epoch: 379, Loss: 0.7500, Train: 78.51%, Valid: 72.60% Test: 70.98%
# Run: 10, Epoch: 380, Loss: 0.7501, Train: 78.35%, Valid: 71.27% Test: 68.95%
# Run: 10, Epoch: 381, Loss: 0.7498, Train: 78.66%, Valid: 72.65% Test: 71.26%
# Run: 10, Epoch: 382, Loss: 0.7504, Train: 78.75%, Valid: 72.30% Test: 70.44%
# Run: 10, Epoch: 383, Loss: 0.7481, Train: 78.84%, Valid: 72.02% Test: 69.75%
# Run: 10, Epoch: 384, Loss: 0.7482, Train: 78.68%, Valid: 72.35% Test: 70.82%
# Run: 10, Epoch: 385, Loss: 0.7488, Train: 78.78%, Valid: 72.41% Test: 70.88%
# Run: 10, Epoch: 386, Loss: 0.7498, Train: 78.68%, Valid: 72.93% Test: 71.74%
# Run: 10, Epoch: 387, Loss: 0.7457, Train: 78.66%, Valid: 72.69% Test: 71.83%
# Run: 10, Epoch: 388, Loss: 0.7458, Train: 78.64%, Valid: 72.53% Test: 70.90%
# Run: 10, Epoch: 389, Loss: 0.7477, Train: 78.72%, Valid: 72.01% Test: 69.74%
# Run: 10, Epoch: 390, Loss: 0.7436, Train: 78.85%, Valid: 72.84% Test: 71.64%
# Run: 10, Epoch: 391, Loss: 0.7456, Train: 78.73%, Valid: 72.40% Test: 70.90%
# Run: 10, Epoch: 392, Loss: 0.7455, Train: 78.75%, Valid: 72.58% Test: 71.43%
# Run: 10, Epoch: 393, Loss: 0.7454, Train: 78.60%, Valid: 72.72% Test: 71.81%
# Run: 10, Epoch: 394, Loss: 0.7477, Train: 78.59%, Valid: 72.28% Test: 70.98%
# Run: 10, Epoch: 395, Loss: 0.7461, Train: 78.36%, Valid: 72.87% Test: 72.12%
# Run: 10, Epoch: 396, Loss: 0.7470, Train: 78.72%, Valid: 73.07% Test: 72.28%
# Run: 10, Epoch: 397, Loss: 0.7451, Train: 78.55%, Valid: 71.34% Test: 69.18%
# Run: 10, Epoch: 398, Loss: 0.7468, Train: 78.66%, Valid: 72.26% Test: 70.44%
# Run: 10, Epoch: 399, Loss: 0.7442, Train: 78.57%, Valid: 72.23% Test: 70.70%
# Run: 10, Epoch: 400, Loss: 0.7421, Train: 78.38%, Valid: 71.41% Test: 69.04%
# Run: 10, Epoch: 401, Loss: 0.7467, Train: 78.59%, Valid: 72.18% Test: 70.04%
# Run: 10, Epoch: 402, Loss: 0.7422, Train: 78.60%, Valid: 72.71% Test: 71.16%
# Run: 10, Epoch: 403, Loss: 0.7449, Train: 78.64%, Valid: 71.98% Test: 69.78%
# Run: 10, Epoch: 404, Loss: 0.7408, Train: 78.67%, Valid: 72.47% Test: 70.78%
# Run: 10, Epoch: 405, Loss: 0.7429, Train: 78.80%, Valid: 72.83% Test: 71.38%
# Run: 10, Epoch: 406, Loss: 0.7390, Train: 78.96%, Valid: 72.68% Test: 71.34%
# Run: 10, Epoch: 407, Loss: 0.7441, Train: 78.76%, Valid: 72.61% Test: 71.61%
# Run: 10, Epoch: 408, Loss: 0.7404, Train: 78.86%, Valid: 72.43% Test: 71.67%
# Run: 10, Epoch: 409, Loss: 0.7408, Train: 79.02%, Valid: 72.58% Test: 71.18%
# Run: 10, Epoch: 410, Loss: 0.7406, Train: 78.65%, Valid: 72.07% Test: 70.43%
# Run: 10, Epoch: 411, Loss: 0.7447, Train: 78.76%, Valid: 72.74% Test: 71.42%
# Run: 10, Epoch: 412, Loss: 0.7404, Train: 78.67%, Valid: 72.88% Test: 71.88%
# Run: 10, Epoch: 413, Loss: 0.7401, Train: 78.88%, Valid: 72.19% Test: 69.85%
# Run: 10, Epoch: 414, Loss: 0.7408, Train: 78.77%, Valid: 72.02% Test: 69.89%
# Run: 10, Epoch: 415, Loss: 0.7352, Train: 78.60%, Valid: 72.16% Test: 70.52%
# Run: 10, Epoch: 416, Loss: 0.7422, Train: 78.69%, Valid: 71.60% Test: 69.51%
# Run: 10, Epoch: 417, Loss: 0.7389, Train: 79.01%, Valid: 72.05% Test: 69.96%
# Run: 10, Epoch: 418, Loss: 0.7374, Train: 79.06%, Valid: 72.58% Test: 71.31%
# Run: 10, Epoch: 419, Loss: 0.7373, Train: 78.90%, Valid: 72.59% Test: 71.53%
# Run: 10, Epoch: 420, Loss: 0.7390, Train: 78.89%, Valid: 72.53% Test: 70.92%
# Run: 10, Epoch: 421, Loss: 0.7363, Train: 78.73%, Valid: 72.62% Test: 71.87%
# Run: 10, Epoch: 422, Loss: 0.7339, Train: 78.94%, Valid: 72.72% Test: 71.96%
# Run: 10, Epoch: 423, Loss: 0.7371, Train: 78.93%, Valid: 72.79% Test: 71.61%
# Run: 10, Epoch: 424, Loss: 0.7362, Train: 78.75%, Valid: 72.68% Test: 71.22%
# Run: 10, Epoch: 425, Loss: 0.7362, Train: 78.65%, Valid: 71.56% Test: 69.12%
# Run: 10, Epoch: 426, Loss: 0.7352, Train: 78.84%, Valid: 72.26% Test: 70.19%
# Run: 10, Epoch: 427, Loss: 0.7357, Train: 78.60%, Valid: 72.57% Test: 71.79%
# Run: 10, Epoch: 428, Loss: 0.7354, Train: 78.94%, Valid: 72.59% Test: 71.33%
# Run: 10, Epoch: 429, Loss: 0.7348, Train: 78.97%, Valid: 72.83% Test: 71.46%
# Run: 10, Epoch: 430, Loss: 0.7350, Train: 79.14%, Valid: 72.94% Test: 71.69%
# Run: 10, Epoch: 431, Loss: 0.7340, Train: 79.21%, Valid: 73.12% Test: 71.84%
# Run: 10, Epoch: 432, Loss: 0.7324, Train: 79.13%, Valid: 72.61% Test: 70.88%
# Run: 10, Epoch: 433, Loss: 0.7337, Train: 78.98%, Valid: 72.42% Test: 71.13%
# Run: 10, Epoch: 434, Loss: 0.7311, Train: 79.29%, Valid: 72.97% Test: 71.88%
# Run: 10, Epoch: 435, Loss: 0.7352, Train: 79.26%, Valid: 72.37% Test: 70.74%
# Run: 10, Epoch: 436, Loss: 0.7306, Train: 78.93%, Valid: 71.54% Test: 69.42%
# Run: 10, Epoch: 437, Loss: 0.7310, Train: 78.88%, Valid: 71.95% Test: 70.25%
# Run: 10, Epoch: 438, Loss: 0.7326, Train: 79.20%, Valid: 72.71% Test: 70.96%
# Run: 10, Epoch: 439, Loss: 0.7321, Train: 79.24%, Valid: 72.87% Test: 71.51%
# Run: 10, Epoch: 440, Loss: 0.7314, Train: 79.15%, Valid: 72.52% Test: 71.37%
# Run: 10, Epoch: 441, Loss: 0.7314, Train: 79.05%, Valid: 72.11% Test: 70.79%
# Run: 10, Epoch: 442, Loss: 0.7304, Train: 79.06%, Valid: 72.34% Test: 70.76%
# Run: 10, Epoch: 443, Loss: 0.7296, Train: 79.02%, Valid: 72.65% Test: 71.83%
# Run: 10, Epoch: 444, Loss: 0.7307, Train: 79.01%, Valid: 72.50% Test: 71.16%
# Run: 10, Epoch: 445, Loss: 0.7327, Train: 78.94%, Valid: 72.53% Test: 71.32%
# Run: 10, Epoch: 446, Loss: 0.7301, Train: 79.19%, Valid: 72.90% Test: 71.28%
# Run: 10, Epoch: 447, Loss: 0.7292, Train: 79.22%, Valid: 72.26% Test: 70.05%
# Run: 10, Epoch: 448, Loss: 0.7299, Train: 79.23%, Valid: 72.22% Test: 70.38%
# Run: 10, Epoch: 449, Loss: 0.7307, Train: 79.12%, Valid: 72.00% Test: 70.18%
# Run: 10, Epoch: 450, Loss: 0.7277, Train: 79.25%, Valid: 72.58% Test: 71.02%
# Run: 10, Epoch: 451, Loss: 0.7275, Train: 79.36%, Valid: 72.66% Test: 71.42%
# Run: 10, Epoch: 452, Loss: 0.7269, Train: 79.38%, Valid: 72.60% Test: 70.76%
# Run: 10, Epoch: 453, Loss: 0.7258, Train: 79.46%, Valid: 72.46% Test: 70.50%
# Run: 10, Epoch: 454, Loss: 0.7280, Train: 79.36%, Valid: 72.22% Test: 70.21%
# Run: 10, Epoch: 455, Loss: 0.7269, Train: 79.17%, Valid: 72.11% Test: 70.29%
# Run: 10, Epoch: 456, Loss: 0.7296, Train: 79.05%, Valid: 72.46% Test: 71.55%
# Run: 10, Epoch: 457, Loss: 0.7252, Train: 79.27%, Valid: 72.71% Test: 71.56%
# Run: 10, Epoch: 458, Loss: 0.7257, Train: 79.31%, Valid: 72.79% Test: 71.56%
# Run: 10, Epoch: 459, Loss: 0.7255, Train: 79.18%, Valid: 72.59% Test: 70.92%
# Run: 10, Epoch: 460, Loss: 0.7236, Train: 79.18%, Valid: 72.04% Test: 70.35%
# Run: 10, Epoch: 461, Loss: 0.7252, Train: 79.39%, Valid: 72.80% Test: 71.38%
# Run: 10, Epoch: 462, Loss: 0.7250, Train: 79.41%, Valid: 72.83% Test: 71.46%
# Run: 10, Epoch: 463, Loss: 0.7266, Train: 79.12%, Valid: 72.71% Test: 71.32%
# Run: 10, Epoch: 464, Loss: 0.7242, Train: 79.46%, Valid: 72.90% Test: 71.25%
# Run: 10, Epoch: 465, Loss: 0.7254, Train: 79.42%, Valid: 72.68% Test: 70.87%
# Run: 10, Epoch: 466, Loss: 0.7242, Train: 79.33%, Valid: 72.98% Test: 71.40%
# Run: 10, Epoch: 467, Loss: 0.7268, Train: 79.26%, Valid: 72.80% Test: 72.06%
# Run: 10, Epoch: 468, Loss: 0.7258, Train: 79.39%, Valid: 72.42% Test: 70.81%
# Run: 10, Epoch: 469, Loss: 0.7223, Train: 79.49%, Valid: 72.33% Test: 70.63%
# Run: 10, Epoch: 470, Loss: 0.7239, Train: 79.56%, Valid: 72.46% Test: 70.61%
# Run: 10, Epoch: 471, Loss: 0.7242, Train: 79.48%, Valid: 71.99% Test: 69.83%
# Run: 10, Epoch: 472, Loss: 0.7224, Train: 79.40%, Valid: 72.67% Test: 70.60%
# Run: 10, Epoch: 473, Loss: 0.7240, Train: 79.41%, Valid: 73.04% Test: 71.58%
# Run: 10, Epoch: 474, Loss: 0.7211, Train: 79.33%, Valid: 72.81% Test: 71.51%
# Run: 10, Epoch: 475, Loss: 0.7229, Train: 79.28%, Valid: 72.57% Test: 71.97%
# Run: 10, Epoch: 476, Loss: 0.7219, Train: 79.56%, Valid: 72.90% Test: 71.62%
# Run: 10, Epoch: 477, Loss: 0.7223, Train: 79.46%, Valid: 72.81% Test: 71.35%
# Run: 10, Epoch: 478, Loss: 0.7237, Train: 79.59%, Valid: 72.76% Test: 71.43%
# Run: 10, Epoch: 479, Loss: 0.7225, Train: 79.58%, Valid: 72.40% Test: 70.68%
# Run: 10, Epoch: 480, Loss: 0.7264, Train: 79.51%, Valid: 72.63% Test: 71.46%
# Run: 10, Epoch: 481, Loss: 0.7262, Train: 79.56%, Valid: 73.05% Test: 71.93%
# Run: 10, Epoch: 482, Loss: 0.7222, Train: 79.44%, Valid: 72.51% Test: 70.85%
# Run: 10, Epoch: 483, Loss: 0.7208, Train: 79.25%, Valid: 72.60% Test: 71.01%
# Run: 10, Epoch: 484, Loss: 0.7190, Train: 79.53%, Valid: 72.72% Test: 71.32%
# Run: 10, Epoch: 485, Loss: 0.7211, Train: 79.37%, Valid: 72.16% Test: 70.28%
# Run: 10, Epoch: 486, Loss: 0.7216, Train: 79.39%, Valid: 72.48% Test: 71.16%
# Run: 10, Epoch: 487, Loss: 0.7156, Train: 79.12%, Valid: 72.43% Test: 71.61%
# Run: 10, Epoch: 488, Loss: 0.7209, Train: 79.68%, Valid: 72.83% Test: 71.48%
# Run: 10, Epoch: 489, Loss: 0.7198, Train: 79.59%, Valid: 73.02% Test: 71.38%
# Run: 10, Epoch: 490, Loss: 0.7237, Train: 79.15%, Valid: 71.90% Test: 70.00%
# Run: 10, Epoch: 491, Loss: 0.7219, Train: 79.15%, Valid: 72.15% Test: 70.57%
# Run: 10, Epoch: 492, Loss: 0.7190, Train: 79.20%, Valid: 72.96% Test: 71.81%
# Run: 10, Epoch: 493, Loss: 0.7187, Train: 79.39%, Valid: 72.75% Test: 71.39%
# Run: 10, Epoch: 494, Loss: 0.7196, Train: 79.63%, Valid: 72.42% Test: 70.47%
# Run: 10, Epoch: 495, Loss: 0.7225, Train: 79.27%, Valid: 71.59% Test: 69.64%
# Run: 10, Epoch: 496, Loss: 0.7153, Train: 79.28%, Valid: 71.71% Test: 69.74%
# Run: 10, Epoch: 497, Loss: 0.7222, Train: 79.63%, Valid: 72.98% Test: 71.35%
# Run: 10, Epoch: 498, Loss: 0.7163, Train: 79.53%, Valid: 72.90% Test: 71.39%
# Run: 10, Epoch: 499, Loss: 0.7167, Train: 79.60%, Valid: 72.81% Test: 71.74%
# Run: 10, Epoch: 500, Loss: 0.7206, Train: 79.17%, Valid: 72.98% Test: 72.29%
# Run 10:
# Highest Train: 79.68
# Highest Valid: 73.12
#   Final Train: 79.21
#    Final Test: 71.84
# All runs:
# Highest Train: 79.65 ± 0.05
# Highest Valid: 73.19 ± 0.10
#   Final Train: 78.94 ± 0.60
#    Final Test: 71.94 ± 0.30

# %% [markdown]
# ### Train and Evaluate GNN model on fine-tuned BERT node features

# %%
args.num_layers = 2
evaluator = Evaluator(name='ogbn-arxiv')
logger = Logger(args.runs, args)
data.x = node_feats
model = GCN(data.num_features, args.hidden_channels,
            dataset.num_classes, args.num_layers,
            args.dropout).to(device)
# model = GAT(data.num_features, args.hidden_channels,
#             dataset.num_classes, args.num_layers,
#             args.dropout).to(device)

for run in range(args.runs):
  model.reset_parameters()
  optimizer = Adam(model.parameters(), lr=args.lr)
  for epoch in range(1, 1 + args.epochs):
    loss = train(model, data, train_idx, optimizer)
    result = test(model, data, split_idx, evaluator)
    logger.add_result(run, result)

    if epoch % args.log_steps == 0:
      train_acc, valid_acc, test_acc = result
      print(f'Run: {run + 1:02d}, '
            f'Epoch: {epoch:02d}, '
            f'Loss: {loss:.4f}, '
            f'Train: {100 * train_acc:.2f}%, '
            f'Valid: {100 * valid_acc:.2f}% '
            f'Test: {100 * test_acc:.2f}%')
  logger.print_statistics(run)
logger.print_statistics()
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Run: 01, Epoch: 56, Loss: 0.7760, Train: 77.68%, Valid: 74.64% Test: 73.14%
# Run: 01, Epoch: 57, Loss: 0.7742, Train: 77.70%, Valid: 74.67% Test: 73.11%
# Run: 01, Epoch: 58, Loss: 0.7744, Train: 77.73%, Valid: 74.68% Test: 73.11%
# Run: 01, Epoch: 59, Loss: 0.7732, Train: 77.73%, Valid: 74.75% Test: 73.17%
# Run: 01, Epoch: 60, Loss: 0.7728, Train: 77.76%, Valid: 74.77% Test: 73.32%
# Run: 01, Epoch: 61, Loss: 0.7716, Train: 77.77%, Valid: 74.78% Test: 73.40%
# Run: 01, Epoch: 62, Loss: 0.7704, Train: 77.76%, Valid: 74.81% Test: 73.45%
# Run: 01, Epoch: 63, Loss: 0.7694, Train: 77.78%, Valid: 74.86% Test: 73.49%
# Run: 01, Epoch: 64, Loss: 0.7687, Train: 77.81%, Valid: 74.86% Test: 73.48%
# Run: 01, Epoch: 65, Loss: 0.7675, Train: 77.83%, Valid: 74.86% Test: 73.44%
# Run: 01, Epoch: 66, Loss: 0.7680, Train: 77.82%, Valid: 74.85% Test: 73.45%
# Run: 01, Epoch: 67, Loss: 0.7665, Train: 77.84%, Valid: 74.89% Test: 73.44%
# Run: 01, Epoch: 68, Loss: 0.7654, Train: 77.84%, Valid: 74.89% Test: 73.42%
# Run: 01, Epoch: 69, Loss: 0.7664, Train: 77.84%, Valid: 74.91% Test: 73.45%
# Run: 01, Epoch: 70, Loss: 0.7636, Train: 77.82%, Valid: 74.96% Test: 73.47%
# Run: 01, Epoch: 71, Loss: 0.7638, Train: 77.84%, Valid: 74.98% Test: 73.49%
# Run: 01, Epoch: 72, Loss: 0.7616, Train: 77.84%, Valid: 74.98% Test: 73.50%
# Run: 01, Epoch: 73, Loss: 0.7633, Train: 77.85%, Valid: 75.00% Test: 73.49%
# Run: 01, Epoch: 74, Loss: 0.7624, Train: 77.87%, Valid: 75.00% Test: 73.47%
# Run: 01, Epoch: 75, Loss: 0.7605, Train: 77.89%, Valid: 74.98% Test: 73.46%
# Run: 01, Epoch: 76, Loss: 0.7618, Train: 77.91%, Valid: 74.97% Test: 73.47%
# Run: 01, Epoch: 77, Loss: 0.7617, Train: 77.91%, Valid: 74.97% Test: 73.51%
# Run: 01, Epoch: 78, Loss: 0.7576, Train: 77.95%, Valid: 74.99% Test: 73.53%
# Run: 01, Epoch: 79, Loss: 0.7591, Train: 77.97%, Valid: 74.99% Test: 73.58%
# Run: 01, Epoch: 80, Loss: 0.7567, Train: 77.97%, Valid: 75.00% Test: 73.61%
# Run: 01, Epoch: 81, Loss: 0.7581, Train: 77.98%, Valid: 75.00% Test: 73.60%
# Run: 01, Epoch: 82, Loss: 0.7559, Train: 77.98%, Valid: 75.04% Test: 73.55%
# Run: 01, Epoch: 83, Loss: 0.7564, Train: 77.99%, Valid: 75.02% Test: 73.50%
# Run: 01, Epoch: 84, Loss: 0.7549, Train: 77.99%, Valid: 75.05% Test: 73.54%
# Run: 01, Epoch: 85, Loss: 0.7538, Train: 78.02%, Valid: 75.05% Test: 73.56%
# Run: 01, Epoch: 86, Loss: 0.7538, Train: 78.03%, Valid: 75.05% Test: 73.57%
# Run: 01, Epoch: 87, Loss: 0.7540, Train: 78.03%, Valid: 75.04% Test: 73.54%
# Run: 01, Epoch: 88, Loss: 0.7532, Train: 78.05%, Valid: 75.00% Test: 73.54%
# Run: 01, Epoch: 89, Loss: 0.7519, Train: 78.06%, Valid: 75.03% Test: 73.54%
# Run: 01, Epoch: 90, Loss: 0.7510, Train: 78.07%, Valid: 75.03% Test: 73.54%
# Run: 01, Epoch: 91, Loss: 0.7507, Train: 78.07%, Valid: 75.05% Test: 73.60%
# Run: 01, Epoch: 92, Loss: 0.7507, Train: 78.08%, Valid: 75.04% Test: 73.65%
# Run: 01, Epoch: 93, Loss: 0.7490, Train: 78.08%, Valid: 75.06% Test: 73.66%
# Run: 01, Epoch: 94, Loss: 0.7490, Train: 78.10%, Valid: 75.06% Test: 73.63%
# Run: 01, Epoch: 95, Loss: 0.7487, Train: 78.11%, Valid: 75.07% Test: 73.56%
# Run: 01, Epoch: 96, Loss: 0.7488, Train: 78.12%, Valid: 75.14% Test: 73.50%
# Run: 01, Epoch: 97, Loss: 0.7482, Train: 78.12%, Valid: 75.14% Test: 73.48%
# Run: 01, Epoch: 98, Loss: 0.7478, Train: 78.13%, Valid: 75.16% Test: 73.46%
# Run: 01, Epoch: 99, Loss: 0.7446, Train: 78.15%, Valid: 75.15% Test: 73.54%
# Run: 01, Epoch: 100, Loss: 0.7464, Train: 78.14%, Valid: 75.19% Test: 73.63%
# Run: 01, Epoch: 101, Loss: 0.7446, Train: 78.14%, Valid: 75.21% Test: 73.67%
# Run: 01, Epoch: 102, Loss: 0.7446, Train: 78.17%, Valid: 75.18% Test: 73.67%
# Run: 01, Epoch: 103, Loss: 0.7444, Train: 78.19%, Valid: 75.18% Test: 73.67%
# Run: 01, Epoch: 104, Loss: 0.7435, Train: 78.19%, Valid: 75.22% Test: 73.64%
# Run: 01, Epoch: 105, Loss: 0.7427, Train: 78.19%, Valid: 75.21% Test: 73.58%
# Run: 01, Epoch: 106, Loss: 0.7437, Train: 78.18%, Valid: 75.23% Test: 73.60%
# Run: 01, Epoch: 107, Loss: 0.7412, Train: 78.18%, Valid: 75.21% Test: 73.61%
# Run: 01, Epoch: 108, Loss: 0.7419, Train: 78.19%, Valid: 75.24% Test: 73.67%
# Run: 01, Epoch: 109, Loss: 0.7420, Train: 78.18%, Valid: 75.26% Test: 73.78%
# Run: 01, Epoch: 110, Loss: 0.7395, Train: 78.19%, Valid: 75.27% Test: 73.76%
# Run: 01, Epoch: 111, Loss: 0.7390, Train: 78.20%, Valid: 75.26% Test: 73.73%
# Run: 01, Epoch: 112, Loss: 0.7406, Train: 78.22%, Valid: 75.27% Test: 73.69%
# Run: 01, Epoch: 113, Loss: 0.7400, Train: 78.21%, Valid: 75.27% Test: 73.66%
# Run: 01, Epoch: 114, Loss: 0.7374, Train: 78.23%, Valid: 75.27% Test: 73.68%
# Run: 01, Epoch: 115, Loss: 0.7384, Train: 78.22%, Valid: 75.30% Test: 73.74%
# Run: 01, Epoch: 116, Loss: 0.7385, Train: 78.21%, Valid: 75.31% Test: 73.82%
# Run: 01, Epoch: 117, Loss: 0.7355, Train: 78.22%, Valid: 75.34% Test: 73.81%
# Run: 01, Epoch: 118, Loss: 0.7377, Train: 78.24%, Valid: 75.30% Test: 73.76%
# Run: 01, Epoch: 119, Loss: 0.7365, Train: 78.26%, Valid: 75.31% Test: 73.69%
# Run: 01, Epoch: 120, Loss: 0.7357, Train: 78.26%, Valid: 75.28% Test: 73.67%
# Run: 01, Epoch: 121, Loss: 0.7344, Train: 78.27%, Valid: 75.27% Test: 73.68%
# Run: 01, Epoch: 122, Loss: 0.7338, Train: 78.29%, Valid: 75.30% Test: 73.69%
# Run: 01, Epoch: 123, Loss: 0.7335, Train: 78.30%, Valid: 75.28% Test: 73.75%
# Run: 01, Epoch: 124, Loss: 0.7331, Train: 78.29%, Valid: 75.32% Test: 73.85%
# Run: 01, Epoch: 125, Loss: 0.7334, Train: 78.30%, Valid: 75.34% Test: 73.86%
# Run: 01, Epoch: 126, Loss: 0.7314, Train: 78.28%, Valid: 75.33% Test: 73.83%
# Run: 01, Epoch: 127, Loss: 0.7323, Train: 78.30%, Valid: 75.30% Test: 73.80%
# Run: 01, Epoch: 128, Loss: 0.7329, Train: 78.32%, Valid: 75.31% Test: 73.72%
# Run: 01, Epoch: 129, Loss: 0.7314, Train: 78.31%, Valid: 75.35% Test: 73.74%
# Run: 01, Epoch: 130, Loss: 0.7308, Train: 78.31%, Valid: 75.36% Test: 73.77%
# Run: 01, Epoch: 131, Loss: 0.7301, Train: 78.32%, Valid: 75.34% Test: 73.87%
# Run: 01, Epoch: 132, Loss: 0.7290, Train: 78.31%, Valid: 75.35% Test: 73.89%
# Run: 01, Epoch: 133, Loss: 0.7296, Train: 78.32%, Valid: 75.37% Test: 73.88%
# Run: 01, Epoch: 134, Loss: 0.7284, Train: 78.34%, Valid: 75.38% Test: 73.81%
# Run: 01, Epoch: 135, Loss: 0.7278, Train: 78.36%, Valid: 75.39% Test: 73.73%
# Run: 01, Epoch: 136, Loss: 0.7284, Train: 78.36%, Valid: 75.39% Test: 73.80%
# Run: 01, Epoch: 137, Loss: 0.7289, Train: 78.38%, Valid: 75.43% Test: 73.84%
# Run: 01, Epoch: 138, Loss: 0.7273, Train: 78.37%, Valid: 75.46% Test: 73.95%
# Run: 01, Epoch: 139, Loss: 0.7275, Train: 78.39%, Valid: 75.48% Test: 73.98%
# Run: 01, Epoch: 140, Loss: 0.7256, Train: 78.36%, Valid: 75.47% Test: 73.89%
# Run: 01, Epoch: 141, Loss: 0.7267, Train: 78.37%, Valid: 75.44% Test: 73.78%
# Run: 01, Epoch: 142, Loss: 0.7256, Train: 78.39%, Valid: 75.40% Test: 73.76%
# Run: 01, Epoch: 143, Loss: 0.7250, Train: 78.40%, Valid: 75.48% Test: 73.81%
# Run: 01, Epoch: 144, Loss: 0.7245, Train: 78.42%, Valid: 75.45% Test: 73.93%
# Run: 01, Epoch: 145, Loss: 0.7237, Train: 78.42%, Valid: 75.46% Test: 73.94%
# Run: 01, Epoch: 146, Loss: 0.7241, Train: 78.42%, Valid: 75.46% Test: 73.91%
# Run: 01, Epoch: 147, Loss: 0.7227, Train: 78.44%, Valid: 75.43% Test: 73.86%
# Run: 01, Epoch: 148, Loss: 0.7241, Train: 78.44%, Valid: 75.40% Test: 73.78%
# Run: 01, Epoch: 149, Loss: 0.7221, Train: 78.45%, Valid: 75.40% Test: 73.75%
# Run: 01, Epoch: 150, Loss: 0.7217, Train: 78.45%, Valid: 75.40% Test: 73.75%
# Run: 01, Epoch: 151, Loss: 0.7212, Train: 78.46%, Valid: 75.43% Test: 73.80%
# Run: 01, Epoch: 152, Loss: 0.7211, Train: 78.47%, Valid: 75.42% Test: 73.80%
# Run: 01, Epoch: 153, Loss: 0.7203, Train: 78.49%, Valid: 75.41% Test: 73.87%
# Run: 01, Epoch: 154, Loss: 0.7207, Train: 78.48%, Valid: 75.42% Test: 73.85%
# Run: 01, Epoch: 155, Loss: 0.7197, Train: 78.48%, Valid: 75.38% Test: 73.81%
# Run: 01, Epoch: 156, Loss: 0.7188, Train: 78.48%, Valid: 75.38% Test: 73.81%
# Run: 01, Epoch: 157, Loss: 0.7178, Train: 78.49%, Valid: 75.41% Test: 73.84%
# Run: 01, Epoch: 158, Loss: 0.7195, Train: 78.50%, Valid: 75.44% Test: 73.85%
# Run: 01, Epoch: 159, Loss: 0.7187, Train: 78.54%, Valid: 75.47% Test: 73.86%
# Run: 01, Epoch: 160, Loss: 0.7181, Train: 78.56%, Valid: 75.49% Test: 73.88%
# Run: 01, Epoch: 161, Loss: 0.7186, Train: 78.54%, Valid: 75.48% Test: 73.84%
# Run: 01, Epoch: 162, Loss: 0.7170, Train: 78.53%, Valid: 75.45% Test: 73.86%
# Run: 01, Epoch: 163, Loss: 0.7173, Train: 78.54%, Valid: 75.44% Test: 73.87%
# Run: 01, Epoch: 164, Loss: 0.7141, Train: 78.53%, Valid: 75.44% Test: 73.88%
# Run: 01, Epoch: 165, Loss: 0.7149, Train: 78.57%, Valid: 75.45% Test: 73.82%
# Run: 01, Epoch: 166, Loss: 0.7151, Train: 78.56%, Valid: 75.44% Test: 73.77%
# Run: 01, Epoch: 167, Loss: 0.7150, Train: 78.56%, Valid: 75.48% Test: 73.81%
# Run: 01, Epoch: 168, Loss: 0.7148, Train: 78.57%, Valid: 75.50% Test: 73.84%
# Run: 01, Epoch: 169, Loss: 0.7151, Train: 78.58%, Valid: 75.49% Test: 73.82%
# Run: 01, Epoch: 170, Loss: 0.7140, Train: 78.58%, Valid: 75.41% Test: 73.81%
# Run: 01, Epoch: 171, Loss: 0.7134, Train: 78.59%, Valid: 75.47% Test: 73.89%
# Run: 01, Epoch: 172, Loss: 0.7119, Train: 78.61%, Valid: 75.50% Test: 73.92%
# Run: 01, Epoch: 173, Loss: 0.7113, Train: 78.62%, Valid: 75.52% Test: 73.88%
# Run: 01, Epoch: 174, Loss: 0.7126, Train: 78.60%, Valid: 75.52% Test: 73.84%
# Run: 01, Epoch: 175, Loss: 0.7112, Train: 78.63%, Valid: 75.50% Test: 73.84%
# Run: 01, Epoch: 176, Loss: 0.7115, Train: 78.65%, Valid: 75.50% Test: 73.85%
# Run: 01, Epoch: 177, Loss: 0.7094, Train: 78.65%, Valid: 75.52% Test: 73.91%
# Run: 01, Epoch: 178, Loss: 0.7100, Train: 78.66%, Valid: 75.50% Test: 73.92%
# Run: 01, Epoch: 179, Loss: 0.7104, Train: 78.64%, Valid: 75.47% Test: 73.88%
# Run: 01, Epoch: 180, Loss: 0.7093, Train: 78.64%, Valid: 75.52% Test: 73.87%
# Run: 01, Epoch: 181, Loss: 0.7087, Train: 78.67%, Valid: 75.56% Test: 73.94%
# Run: 01, Epoch: 182, Loss: 0.7084, Train: 78.66%, Valid: 75.55% Test: 73.95%
# Run: 01, Epoch: 183, Loss: 0.7083, Train: 78.68%, Valid: 75.52% Test: 73.92%
# Run: 01, Epoch: 184, Loss: 0.7084, Train: 78.67%, Valid: 75.55% Test: 73.86%
# Run: 01, Epoch: 185, Loss: 0.7069, Train: 78.67%, Valid: 75.57% Test: 73.88%
# Run: 01, Epoch: 186, Loss: 0.7070, Train: 78.70%, Valid: 75.56% Test: 73.93%
# Run: 01, Epoch: 187, Loss: 0.7050, Train: 78.69%, Valid: 75.52% Test: 74.00%
# Run: 01, Epoch: 188, Loss: 0.7064, Train: 78.68%, Valid: 75.54% Test: 74.01%
# Run: 01, Epoch: 189, Loss: 0.7057, Train: 78.65%, Valid: 75.51% Test: 73.91%
# Run: 01, Epoch: 190, Loss: 0.7059, Train: 78.67%, Valid: 75.54% Test: 73.86%
# Run: 01, Epoch: 191, Loss: 0.7056, Train: 78.69%, Valid: 75.55% Test: 73.92%
# Run: 01, Epoch: 192, Loss: 0.7046, Train: 78.72%, Valid: 75.57% Test: 73.93%
# Run: 01, Epoch: 193, Loss: 0.7038, Train: 78.73%, Valid: 75.57% Test: 73.95%
# Run: 01, Epoch: 194, Loss: 0.7050, Train: 78.74%, Valid: 75.55% Test: 73.86%
# Run: 01, Epoch: 195, Loss: 0.7041, Train: 78.72%, Valid: 75.60% Test: 73.84%
# Run: 01, Epoch: 196, Loss: 0.7047, Train: 78.75%, Valid: 75.63% Test: 73.90%
# Run: 01, Epoch: 197, Loss: 0.7035, Train: 78.76%, Valid: 75.62% Test: 73.97%
# Run: 01, Epoch: 198, Loss: 0.7026, Train: 78.76%, Valid: 75.59% Test: 74.02%
# Run: 01, Epoch: 199, Loss: 0.7032, Train: 78.74%, Valid: 75.60% Test: 73.94%
# Run: 01, Epoch: 200, Loss: 0.7020, Train: 78.75%, Valid: 75.54% Test: 73.90%
# Run: 01, Epoch: 201, Loss: 0.7016, Train: 78.78%, Valid: 75.52% Test: 73.87%
# Run: 01, Epoch: 202, Loss: 0.7010, Train: 78.75%, Valid: 75.60% Test: 73.98%
# Run: 01, Epoch: 203, Loss: 0.7002, Train: 78.79%, Valid: 75.54% Test: 73.99%
# Run: 01, Epoch: 204, Loss: 0.7010, Train: 78.80%, Valid: 75.55% Test: 73.95%
# Run: 01, Epoch: 205, Loss: 0.7008, Train: 78.84%, Valid: 75.58% Test: 73.87%
# Run: 01, Epoch: 206, Loss: 0.6990, Train: 78.82%, Valid: 75.63% Test: 73.91%
# Run: 01, Epoch: 207, Loss: 0.6998, Train: 78.86%, Valid: 75.60% Test: 74.00%
# Run: 01, Epoch: 208, Loss: 0.6984, Train: 78.88%, Valid: 75.62% Test: 74.01%
# Run: 01, Epoch: 209, Loss: 0.6977, Train: 78.90%, Valid: 75.55% Test: 73.96%
# Run: 01, Epoch: 210, Loss: 0.6985, Train: 78.88%, Valid: 75.54% Test: 73.89%
# Run: 01, Epoch: 211, Loss: 0.6973, Train: 78.88%, Valid: 75.55% Test: 73.97%
# Run: 01, Epoch: 212, Loss: 0.6971, Train: 78.88%, Valid: 75.67% Test: 74.03%
# Run: 01, Epoch: 213, Loss: 0.6976, Train: 78.89%, Valid: 75.67% Test: 74.03%
# Run: 01, Epoch: 214, Loss: 0.6981, Train: 78.88%, Valid: 75.63% Test: 73.99%
# Run: 01, Epoch: 215, Loss: 0.6969, Train: 78.86%, Valid: 75.59% Test: 73.94%
# Run: 01, Epoch: 216, Loss: 0.6956, Train: 78.88%, Valid: 75.59% Test: 74.00%
# Run: 01, Epoch: 217, Loss: 0.6963, Train: 78.89%, Valid: 75.62% Test: 74.06%
# Run: 01, Epoch: 218, Loss: 0.6951, Train: 78.90%, Valid: 75.63% Test: 74.06%
# Run: 01, Epoch: 219, Loss: 0.6941, Train: 78.90%, Valid: 75.65% Test: 73.98%
# Run: 01, Epoch: 220, Loss: 0.6948, Train: 78.92%, Valid: 75.63% Test: 73.93%
# Run: 01, Epoch: 221, Loss: 0.6946, Train: 78.92%, Valid: 75.59% Test: 73.92%
# Run: 01, Epoch: 222, Loss: 0.6943, Train: 78.92%, Valid: 75.66% Test: 74.05%
# Run: 01, Epoch: 223, Loss: 0.6922, Train: 78.91%, Valid: 75.69% Test: 74.06%
# Run: 01, Epoch: 224, Loss: 0.6948, Train: 78.94%, Valid: 75.63% Test: 73.99%
# Run: 01, Epoch: 225, Loss: 0.6921, Train: 78.93%, Valid: 75.64% Test: 73.96%
# Run: 01, Epoch: 226, Loss: 0.6935, Train: 78.93%, Valid: 75.72% Test: 74.02%
# Run: 01, Epoch: 227, Loss: 0.6917, Train: 78.97%, Valid: 75.69% Test: 74.07%
# Run: 01, Epoch: 228, Loss: 0.6915, Train: 78.99%, Valid: 75.68% Test: 73.97%
# Run: 01, Epoch: 229, Loss: 0.6922, Train: 79.01%, Valid: 75.64% Test: 73.88%
# Run: 01, Epoch: 230, Loss: 0.6917, Train: 79.00%, Valid: 75.64% Test: 73.92%
# Run: 01, Epoch: 231, Loss: 0.6912, Train: 78.96%, Valid: 75.69% Test: 74.08%
# Run: 01, Epoch: 232, Loss: 0.6901, Train: 78.96%, Valid: 75.65% Test: 74.03%
# Run: 01, Epoch: 233, Loss: 0.6906, Train: 79.03%, Valid: 75.63% Test: 73.77%
# Run: 01, Epoch: 234, Loss: 0.6908, Train: 79.02%, Valid: 75.63% Test: 73.73%
# Run: 01, Epoch: 235, Loss: 0.6896, Train: 79.00%, Valid: 75.65% Test: 74.01%
# Run: 01, Epoch: 236, Loss: 0.6882, Train: 78.99%, Valid: 75.69% Test: 74.08%
# Run: 01, Epoch: 237, Loss: 0.6888, Train: 78.97%, Valid: 75.65% Test: 74.04%
# Run: 01, Epoch: 238, Loss: 0.6889, Train: 79.04%, Valid: 75.66% Test: 73.89%
# Run: 01, Epoch: 239, Loss: 0.6887, Train: 79.04%, Valid: 75.64% Test: 73.99%
# Run: 01, Epoch: 240, Loss: 0.6873, Train: 79.01%, Valid: 75.66% Test: 74.14%
# Run: 01, Epoch: 241, Loss: 0.6880, Train: 79.09%, Valid: 75.62% Test: 73.95%
# Run: 01, Epoch: 242, Loss: 0.6859, Train: 79.10%, Valid: 75.63% Test: 73.80%
# Run: 01, Epoch: 243, Loss: 0.6862, Train: 79.08%, Valid: 75.70% Test: 73.93%
# Run: 01, Epoch: 244, Loss: 0.6866, Train: 79.09%, Valid: 75.72% Test: 74.01%
# Run: 01, Epoch: 245, Loss: 0.6855, Train: 79.10%, Valid: 75.66% Test: 73.90%
# Run: 01, Epoch: 246, Loss: 0.6863, Train: 79.06%, Valid: 75.69% Test: 73.87%
# Run: 01, Epoch: 247, Loss: 0.6841, Train: 79.11%, Valid: 75.66% Test: 73.96%
# Run: 01, Epoch: 248, Loss: 0.6858, Train: 79.08%, Valid: 75.73% Test: 73.99%
# Run: 01, Epoch: 249, Loss: 0.6846, Train: 79.09%, Valid: 75.64% Test: 73.95%
# Run: 01, Epoch: 250, Loss: 0.6852, Train: 79.09%, Valid: 75.65% Test: 74.01%
# Run: 01, Epoch: 251, Loss: 0.6830, Train: 79.17%, Valid: 75.61% Test: 74.04%
# Run: 01, Epoch: 252, Loss: 0.6840, Train: 79.14%, Valid: 75.59% Test: 74.09%
# Run: 01, Epoch: 253, Loss: 0.6836, Train: 79.15%, Valid: 75.60% Test: 74.15%
# Run: 01, Epoch: 254, Loss: 0.6834, Train: 79.14%, Valid: 75.65% Test: 73.99%
# Run: 01, Epoch: 255, Loss: 0.6832, Train: 79.17%, Valid: 75.72% Test: 73.86%
# Run: 01, Epoch: 256, Loss: 0.6824, Train: 79.13%, Valid: 75.67% Test: 74.17%
# Run: 01, Epoch: 257, Loss: 0.6816, Train: 79.14%, Valid: 75.72% Test: 74.09%
# Run: 01, Epoch: 258, Loss: 0.6822, Train: 79.16%, Valid: 75.68% Test: 73.77%
# Run: 01, Epoch: 259, Loss: 0.6819, Train: 79.14%, Valid: 75.76% Test: 74.17%
# Run: 01, Epoch: 260, Loss: 0.6798, Train: 79.16%, Valid: 75.78% Test: 74.33%
# Run: 01, Epoch: 261, Loss: 0.6800, Train: 79.20%, Valid: 75.74% Test: 74.08%
# Run: 01, Epoch: 262, Loss: 0.6795, Train: 79.18%, Valid: 75.63% Test: 74.11%
# Run: 01, Epoch: 263, Loss: 0.6782, Train: 79.22%, Valid: 75.69% Test: 74.25%
# Run: 01, Epoch: 264, Loss: 0.6798, Train: 79.23%, Valid: 75.65% Test: 73.85%
# Run: 01, Epoch: 265, Loss: 0.6787, Train: 79.22%, Valid: 75.60% Test: 73.83%
# Run: 01, Epoch: 266, Loss: 0.6791, Train: 79.21%, Valid: 75.61% Test: 74.02%
# Run: 01, Epoch: 267, Loss: 0.6782, Train: 79.23%, Valid: 75.70% Test: 74.13%
# Run: 01, Epoch: 268, Loss: 0.6777, Train: 79.24%, Valid: 75.61% Test: 73.89%
# Run: 01, Epoch: 269, Loss: 0.6791, Train: 79.22%, Valid: 75.71% Test: 74.15%
# Run: 01, Epoch: 270, Loss: 0.6785, Train: 79.22%, Valid: 75.76% Test: 74.14%
# Run: 01, Epoch: 271, Loss: 0.6774, Train: 79.24%, Valid: 75.71% Test: 74.15%
# Run: 01, Epoch: 272, Loss: 0.6777, Train: 79.27%, Valid: 75.72% Test: 74.12%
# Run: 01, Epoch: 273, Loss: 0.6763, Train: 79.29%, Valid: 75.73% Test: 74.04%
# Run: 01, Epoch: 274, Loss: 0.6773, Train: 79.28%, Valid: 75.77% Test: 74.28%
# Run: 01, Epoch: 275, Loss: 0.6754, Train: 79.29%, Valid: 75.70% Test: 74.14%
# Run: 01, Epoch: 276, Loss: 0.6767, Train: 79.29%, Valid: 75.70% Test: 73.89%
# Run: 01, Epoch: 277, Loss: 0.6749, Train: 79.25%, Valid: 75.74% Test: 74.29%
# Run: 01, Epoch: 278, Loss: 0.6744, Train: 79.31%, Valid: 75.74% Test: 74.04%
# Run: 01, Epoch: 279, Loss: 0.6751, Train: 79.35%, Valid: 75.66% Test: 73.83%
# Run: 01, Epoch: 280, Loss: 0.6741, Train: 79.38%, Valid: 75.71% Test: 74.04%
# Run: 01, Epoch: 281, Loss: 0.6738, Train: 79.35%, Valid: 75.60% Test: 73.89%
# Run: 01, Epoch: 282, Loss: 0.6730, Train: 79.36%, Valid: 75.68% Test: 74.00%
# Run: 01, Epoch: 283, Loss: 0.6721, Train: 79.36%, Valid: 75.80% Test: 73.98%
# Run: 01, Epoch: 284, Loss: 0.6723, Train: 79.30%, Valid: 75.75% Test: 74.21%
# Run: 01, Epoch: 285, Loss: 0.6727, Train: 79.33%, Valid: 75.76% Test: 74.28%
# Run: 01, Epoch: 286, Loss: 0.6722, Train: 79.40%, Valid: 75.74% Test: 73.75%
# Run: 01, Epoch: 287, Loss: 0.6718, Train: 79.38%, Valid: 75.77% Test: 74.15%
# Run: 01, Epoch: 288, Loss: 0.6724, Train: 79.33%, Valid: 75.79% Test: 74.20%
# Run: 01, Epoch: 289, Loss: 0.6723, Train: 79.38%, Valid: 75.67% Test: 74.09%
# Run: 01, Epoch: 290, Loss: 0.6729, Train: 79.40%, Valid: 75.73% Test: 74.01%
# Run: 01, Epoch: 291, Loss: 0.6715, Train: 79.39%, Valid: 75.71% Test: 74.21%
# Run: 01, Epoch: 292, Loss: 0.6695, Train: 79.43%, Valid: 75.71% Test: 74.01%
# Run: 01, Epoch: 293, Loss: 0.6699, Train: 79.39%, Valid: 75.77% Test: 74.02%
# Run: 01, Epoch: 294, Loss: 0.6695, Train: 79.36%, Valid: 75.77% Test: 74.19%
# Run: 01, Epoch: 295, Loss: 0.6700, Train: 79.42%, Valid: 75.85% Test: 74.18%
# Run: 01, Epoch: 296, Loss: 0.6682, Train: 79.45%, Valid: 75.76% Test: 73.95%
# Run: 01, Epoch: 297, Loss: 0.6710, Train: 79.45%, Valid: 75.68% Test: 73.86%
# Run: 01, Epoch: 298, Loss: 0.6690, Train: 79.40%, Valid: 75.85% Test: 74.29%
# Run: 01, Epoch: 299, Loss: 0.6689, Train: 79.44%, Valid: 75.79% Test: 74.17%
# Run: 01, Epoch: 300, Loss: 0.6669, Train: 79.46%, Valid: 75.56% Test: 73.75%
# Run: 01, Epoch: 301, Loss: 0.6660, Train: 79.41%, Valid: 75.75% Test: 74.25%
# Run: 01, Epoch: 302, Loss: 0.6664, Train: 79.49%, Valid: 75.65% Test: 73.84%
# Run: 01, Epoch: 303, Loss: 0.6676, Train: 79.46%, Valid: 75.88% Test: 74.35%
# Run: 01, Epoch: 304, Loss: 0.6671, Train: 79.47%, Valid: 75.82% Test: 74.29%
# Run: 01, Epoch: 305, Loss: 0.6664, Train: 79.47%, Valid: 75.63% Test: 74.14%
# Run: 01, Epoch: 306, Loss: 0.6659, Train: 79.54%, Valid: 75.69% Test: 74.14%
# Run: 01, Epoch: 307, Loss: 0.6646, Train: 79.53%, Valid: 75.80% Test: 74.20%
# Run: 01, Epoch: 308, Loss: 0.6623, Train: 79.49%, Valid: 75.82% Test: 74.11%
# Run: 01, Epoch: 309, Loss: 0.6638, Train: 79.54%, Valid: 75.82% Test: 73.99%
# Run: 01, Epoch: 310, Loss: 0.6641, Train: 79.52%, Valid: 75.74% Test: 74.31%
# Run: 01, Epoch: 311, Loss: 0.6641, Train: 79.53%, Valid: 75.59% Test: 73.74%
# Run: 01, Epoch: 312, Loss: 0.6650, Train: 79.51%, Valid: 75.57% Test: 73.67%
# Run: 01, Epoch: 313, Loss: 0.6649, Train: 79.53%, Valid: 75.83% Test: 74.49%
# Run: 01, Epoch: 314, Loss: 0.6641, Train: 79.57%, Valid: 75.73% Test: 73.90%
# Run: 01, Epoch: 315, Loss: 0.6639, Train: 79.51%, Valid: 75.79% Test: 74.31%
# Run: 01, Epoch: 316, Loss: 0.6640, Train: 79.53%, Valid: 75.79% Test: 74.33%
# Run: 01, Epoch: 317, Loss: 0.6629, Train: 79.49%, Valid: 75.56% Test: 73.33%
# Run: 01, Epoch: 318, Loss: 0.6627, Train: 79.54%, Valid: 75.89% Test: 74.49%
# Run: 01, Epoch: 319, Loss: 0.6615, Train: 79.58%, Valid: 75.88% Test: 74.02%
# Run: 01, Epoch: 320, Loss: 0.6612, Train: 79.58%, Valid: 75.71% Test: 74.14%
# Run: 01, Epoch: 321, Loss: 0.6624, Train: 79.58%, Valid: 75.78% Test: 74.25%
# Run: 01, Epoch: 322, Loss: 0.6618, Train: 79.52%, Valid: 75.82% Test: 74.10%
# Run: 01, Epoch: 323, Loss: 0.6619, Train: 79.61%, Valid: 75.81% Test: 73.98%
# Run: 01, Epoch: 324, Loss: 0.6609, Train: 79.59%, Valid: 75.93% Test: 74.45%
# Run: 01, Epoch: 325, Loss: 0.6624, Train: 79.63%, Valid: 75.79% Test: 74.22%
# Run: 01, Epoch: 326, Loss: 0.6603, Train: 79.63%, Valid: 75.73% Test: 73.89%
# Run: 01, Epoch: 327, Loss: 0.6621, Train: 79.63%, Valid: 75.88% Test: 74.56%
# Run: 01, Epoch: 328, Loss: 0.6596, Train: 79.62%, Valid: 75.52% Test: 73.64%
# Run: 01, Epoch: 329, Loss: 0.6588, Train: 79.64%, Valid: 75.84% Test: 73.99%
# Run: 01, Epoch: 330, Loss: 0.6583, Train: 79.59%, Valid: 75.78% Test: 74.08%
# Run: 01, Epoch: 331, Loss: 0.6601, Train: 79.61%, Valid: 75.73% Test: 73.82%
# Run: 01, Epoch: 332, Loss: 0.6601, Train: 79.59%, Valid: 75.94% Test: 74.42%
# Run: 01, Epoch: 333, Loss: 0.6575, Train: 79.64%, Valid: 75.92% Test: 74.44%
# Run: 01, Epoch: 334, Loss: 0.6577, Train: 79.65%, Valid: 75.70% Test: 73.94%
# Run: 01, Epoch: 335, Loss: 0.6568, Train: 79.61%, Valid: 75.79% Test: 74.36%
# Run: 01, Epoch: 336, Loss: 0.6573, Train: 79.63%, Valid: 75.62% Test: 73.56%
# Run: 01, Epoch: 337, Loss: 0.6574, Train: 79.74%, Valid: 75.92% Test: 74.45%
# Run: 01, Epoch: 338, Loss: 0.6579, Train: 79.63%, Valid: 75.83% Test: 74.30%
# Run: 01, Epoch: 339, Loss: 0.6572, Train: 79.72%, Valid: 75.75% Test: 73.83%
# Run: 01, Epoch: 340, Loss: 0.6562, Train: 79.68%, Valid: 75.86% Test: 74.07%
# Run: 01, Epoch: 341, Loss: 0.6571, Train: 79.70%, Valid: 75.78% Test: 74.01%
# Run: 01, Epoch: 342, Loss: 0.6558, Train: 79.70%, Valid: 75.91% Test: 74.62%
# Run: 01, Epoch: 343, Loss: 0.6556, Train: 79.76%, Valid: 75.84% Test: 74.01%
# Run: 01, Epoch: 344, Loss: 0.6539, Train: 79.73%, Valid: 75.65% Test: 73.67%
# Run: 01, Epoch: 345, Loss: 0.6548, Train: 79.65%, Valid: 75.83% Test: 74.32%
# Run: 01, Epoch: 346, Loss: 0.6532, Train: 79.69%, Valid: 75.59% Test: 73.60%
# Run: 01, Epoch: 347, Loss: 0.6539, Train: 79.66%, Valid: 75.83% Test: 74.83%
# Run: 01, Epoch: 348, Loss: 0.6541, Train: 79.72%, Valid: 75.87% Test: 74.21%
# Run: 01, Epoch: 349, Loss: 0.6527, Train: 79.77%, Valid: 75.73% Test: 73.78%
# Run: 01, Epoch: 350, Loss: 0.6530, Train: 79.75%, Valid: 76.01% Test: 74.69%
# Run: 01, Epoch: 351, Loss: 0.6518, Train: 79.77%, Valid: 75.54% Test: 73.56%
# Run: 01, Epoch: 352, Loss: 0.6516, Train: 79.73%, Valid: 75.87% Test: 74.44%
# Run: 01, Epoch: 353, Loss: 0.6526, Train: 79.74%, Valid: 75.93% Test: 74.46%
# Run: 01, Epoch: 354, Loss: 0.6508, Train: 79.74%, Valid: 75.44% Test: 73.40%
# Run: 01, Epoch: 355, Loss: 0.6539, Train: 79.68%, Valid: 75.99% Test: 74.88%
# Run: 01, Epoch: 356, Loss: 0.6540, Train: 79.66%, Valid: 74.91% Test: 72.37%
# Run: 01, Epoch: 357, Loss: 0.6534, Train: 79.84%, Valid: 75.91% Test: 74.22%
# Run: 01, Epoch: 358, Loss: 0.6517, Train: 79.78%, Valid: 75.94% Test: 74.74%
# Run: 01, Epoch: 359, Loss: 0.6511, Train: 79.72%, Valid: 75.44% Test: 73.20%
# Run: 01, Epoch: 360, Loss: 0.6526, Train: 79.85%, Valid: 75.93% Test: 74.33%
# Run: 01, Epoch: 361, Loss: 0.6494, Train: 79.79%, Valid: 75.88% Test: 74.66%
# Run: 01, Epoch: 362, Loss: 0.6495, Train: 79.78%, Valid: 75.32% Test: 73.30%
# Run: 01, Epoch: 363, Loss: 0.6493, Train: 79.82%, Valid: 75.76% Test: 74.30%
# Run: 01, Epoch: 364, Loss: 0.6483, Train: 79.88%, Valid: 75.89% Test: 74.50%
# Run: 01, Epoch: 365, Loss: 0.6485, Train: 79.84%, Valid: 75.56% Test: 73.36%
# Run: 01, Epoch: 366, Loss: 0.6509, Train: 79.88%, Valid: 75.92% Test: 74.39%
# Run: 01, Epoch: 367, Loss: 0.6467, Train: 79.88%, Valid: 76.03% Test: 74.64%
# Run: 01, Epoch: 368, Loss: 0.6468, Train: 79.88%, Valid: 75.63% Test: 73.69%
# Run: 01, Epoch: 369, Loss: 0.6477, Train: 79.93%, Valid: 76.01% Test: 74.65%
# Run: 01, Epoch: 370, Loss: 0.6473, Train: 79.85%, Valid: 75.87% Test: 74.46%
# Run: 01, Epoch: 371, Loss: 0.6464, Train: 79.86%, Valid: 75.39% Test: 73.20%
# Run: 01, Epoch: 372, Loss: 0.6469, Train: 79.79%, Valid: 75.99% Test: 75.02%
# Run: 01, Epoch: 373, Loss: 0.6475, Train: 79.94%, Valid: 75.83% Test: 74.11%
# Run: 01, Epoch: 374, Loss: 0.6464, Train: 79.98%, Valid: 75.83% Test: 73.86%
# Run: 01, Epoch: 375, Loss: 0.6451, Train: 79.82%, Valid: 76.04% Test: 74.87%
# Run: 01, Epoch: 376, Loss: 0.6452, Train: 79.98%, Valid: 75.51% Test: 73.72%
# Run: 01, Epoch: 377, Loss: 0.6454, Train: 79.93%, Valid: 75.59% Test: 73.53%
# Run: 01, Epoch: 378, Loss: 0.6445, Train: 79.94%, Valid: 75.98% Test: 74.72%
# Run: 01, Epoch: 379, Loss: 0.6461, Train: 79.98%, Valid: 75.90% Test: 74.06%
# Run: 01, Epoch: 380, Loss: 0.6440, Train: 80.03%, Valid: 75.83% Test: 74.05%
# Run: 01, Epoch: 381, Loss: 0.6437, Train: 79.98%, Valid: 75.93% Test: 74.70%
# Run: 01, Epoch: 382, Loss: 0.6445, Train: 79.96%, Valid: 75.59% Test: 73.72%
# Run: 01, Epoch: 383, Loss: 0.6428, Train: 79.98%, Valid: 75.82% Test: 74.20%
# Run: 01, Epoch: 384, Loss: 0.6413, Train: 80.04%, Valid: 75.90% Test: 74.54%
# Run: 01, Epoch: 385, Loss: 0.6410, Train: 80.04%, Valid: 75.88% Test: 73.88%
# Run: 01, Epoch: 386, Loss: 0.6408, Train: 80.02%, Valid: 75.90% Test: 74.22%
# Run: 01, Epoch: 387, Loss: 0.6406, Train: 80.04%, Valid: 75.92% Test: 74.29%
# Run: 01, Epoch: 388, Loss: 0.6411, Train: 80.00%, Valid: 75.64% Test: 73.63%
# Run: 01, Epoch: 389, Loss: 0.6417, Train: 80.00%, Valid: 76.03% Test: 74.63%
# Run: 01, Epoch: 390, Loss: 0.6400, Train: 80.10%, Valid: 75.78% Test: 74.18%
# Run: 01, Epoch: 391, Loss: 0.6393, Train: 80.08%, Valid: 75.79% Test: 73.92%
# Run: 01, Epoch: 392, Loss: 0.6386, Train: 80.06%, Valid: 75.84% Test: 74.39%
# Run: 01, Epoch: 393, Loss: 0.6416, Train: 80.05%, Valid: 75.93% Test: 74.28%
# Run: 01, Epoch: 394, Loss: 0.6395, Train: 80.02%, Valid: 75.89% Test: 74.34%
# Run: 01, Epoch: 395, Loss: 0.6400, Train: 79.98%, Valid: 75.93% Test: 74.23%
# Run: 01, Epoch: 396, Loss: 0.6408, Train: 80.04%, Valid: 75.67% Test: 73.64%
# Run: 01, Epoch: 397, Loss: 0.6422, Train: 79.96%, Valid: 75.95% Test: 75.01%
# Run: 01, Epoch: 398, Loss: 0.6405, Train: 79.93%, Valid: 75.29% Test: 73.09%
# Run: 01, Epoch: 399, Loss: 0.6418, Train: 80.03%, Valid: 75.85% Test: 74.67%
# Run: 01, Epoch: 400, Loss: 0.6403, Train: 80.09%, Valid: 75.94% Test: 74.22%
# Run: 01, Epoch: 401, Loss: 0.6395, Train: 80.07%, Valid: 75.51% Test: 73.41%
# Run: 01, Epoch: 402, Loss: 0.6393, Train: 79.97%, Valid: 75.94% Test: 75.01%
# Run: 01, Epoch: 403, Loss: 0.6415, Train: 80.02%, Valid: 74.90% Test: 72.61%
# Run: 01, Epoch: 404, Loss: 0.6429, Train: 80.03%, Valid: 75.79% Test: 74.47%
# Run: 01, Epoch: 405, Loss: 0.6386, Train: 79.98%, Valid: 75.98% Test: 74.85%
# Run: 01, Epoch: 406, Loss: 0.6418, Train: 79.91%, Valid: 74.65% Test: 72.06%
# Run: 01, Epoch: 407, Loss: 0.6421, Train: 80.15%, Valid: 75.96% Test: 74.32%
# Run: 01, Epoch: 408, Loss: 0.6372, Train: 79.99%, Valid: 75.86% Test: 75.08%
# Run: 01, Epoch: 409, Loss: 0.6385, Train: 80.10%, Valid: 75.24% Test: 73.20%
# Run: 01, Epoch: 410, Loss: 0.6389, Train: 80.21%, Valid: 75.86% Test: 74.14%
# Run: 01, Epoch: 411, Loss: 0.6367, Train: 80.01%, Valid: 76.07% Test: 75.17%
# Run: 01, Epoch: 412, Loss: 0.6374, Train: 80.18%, Valid: 75.68% Test: 73.73%
# Run: 01, Epoch: 413, Loss: 0.6352, Train: 80.09%, Valid: 75.39% Test: 73.30%
# Run: 01, Epoch: 414, Loss: 0.6365, Train: 80.08%, Valid: 76.09% Test: 74.89%
# Run: 01, Epoch: 415, Loss: 0.6361, Train: 80.23%, Valid: 75.68% Test: 73.80%
# Run: 01, Epoch: 416, Loss: 0.6348, Train: 80.27%, Valid: 75.72% Test: 73.72%
# Run: 01, Epoch: 417, Loss: 0.6331, Train: 80.16%, Valid: 75.98% Test: 74.83%
# Run: 01, Epoch: 418, Loss: 0.6345, Train: 80.20%, Valid: 75.77% Test: 73.90%
# Run: 01, Epoch: 419, Loss: 0.6336, Train: 80.17%, Valid: 75.82% Test: 74.10%
# Run: 01, Epoch: 420, Loss: 0.6342, Train: 80.09%, Valid: 75.98% Test: 74.86%
# Run: 01, Epoch: 421, Loss: 0.6360, Train: 80.21%, Valid: 75.73% Test: 74.02%
# Run: 01, Epoch: 422, Loss: 0.6363, Train: 80.22%, Valid: 75.96% Test: 74.45%
# Run: 01, Epoch: 423, Loss: 0.6331, Train: 80.29%, Valid: 75.75% Test: 74.01%
# Run: 01, Epoch: 424, Loss: 0.6339, Train: 80.24%, Valid: 75.65% Test: 73.87%
# Run: 01, Epoch: 425, Loss: 0.6332, Train: 80.14%, Valid: 75.74% Test: 74.50%
# Run: 01, Epoch: 426, Loss: 0.6328, Train: 80.27%, Valid: 75.82% Test: 74.23%
# Run: 01, Epoch: 427, Loss: 0.6309, Train: 80.27%, Valid: 75.91% Test: 74.13%
# Run: 01, Epoch: 428, Loss: 0.6323, Train: 80.26%, Valid: 76.02% Test: 74.41%
# Run: 01, Epoch: 429, Loss: 0.6309, Train: 80.26%, Valid: 75.83% Test: 74.13%
# Run: 01, Epoch: 430, Loss: 0.6321, Train: 80.31%, Valid: 75.80% Test: 73.95%
# Run: 01, Epoch: 431, Loss: 0.6309, Train: 80.23%, Valid: 75.93% Test: 74.20%
# Run: 01, Epoch: 432, Loss: 0.6313, Train: 80.25%, Valid: 75.67% Test: 73.96%
# Run: 01, Epoch: 433, Loss: 0.6313, Train: 80.28%, Valid: 75.95% Test: 74.28%
# Run: 01, Epoch: 434, Loss: 0.6293, Train: 80.32%, Valid: 75.75% Test: 73.96%
# Run: 01, Epoch: 435, Loss: 0.6296, Train: 80.33%, Valid: 75.85% Test: 74.06%
# Run: 01, Epoch: 436, Loss: 0.6286, Train: 80.33%, Valid: 75.98% Test: 74.41%
# Run: 01, Epoch: 437, Loss: 0.6307, Train: 80.35%, Valid: 76.00% Test: 74.50%
# Run: 01, Epoch: 438, Loss: 0.6280, Train: 80.40%, Valid: 75.94% Test: 74.16%
# Run: 01, Epoch: 439, Loss: 0.6278, Train: 80.39%, Valid: 75.78% Test: 74.12%
# Run: 01, Epoch: 440, Loss: 0.6277, Train: 80.41%, Valid: 75.94% Test: 74.58%
# Run: 01, Epoch: 441, Loss: 0.6271, Train: 80.27%, Valid: 75.92% Test: 74.46%
# Run: 01, Epoch: 442, Loss: 0.6258, Train: 80.39%, Valid: 75.61% Test: 73.89%
# Run: 01, Epoch: 443, Loss: 0.6261, Train: 80.30%, Valid: 76.09% Test: 75.19%
# Run: 01, Epoch: 444, Loss: 0.6277, Train: 80.34%, Valid: 75.12% Test: 72.85%
# Run: 01, Epoch: 445, Loss: 0.6322, Train: 80.37%, Valid: 76.23% Test: 74.79%
# Run: 01, Epoch: 446, Loss: 0.6297, Train: 80.24%, Valid: 76.15% Test: 74.91%
# Run: 01, Epoch: 447, Loss: 0.6289, Train: 80.15%, Valid: 75.05% Test: 72.54%
# Run: 01, Epoch: 448, Loss: 0.6316, Train: 80.31%, Valid: 75.92% Test: 74.77%
# Run: 01, Epoch: 449, Loss: 0.6294, Train: 80.27%, Valid: 76.03% Test: 74.81%
# Run: 01, Epoch: 450, Loss: 0.6261, Train: 80.23%, Valid: 75.39% Test: 73.28%
# Run: 01, Epoch: 451, Loss: 0.6283, Train: 80.35%, Valid: 75.86% Test: 74.44%
# Run: 01, Epoch: 452, Loss: 0.6284, Train: 80.26%, Valid: 76.01% Test: 74.51%
# Run: 01, Epoch: 453, Loss: 0.6264, Train: 80.28%, Valid: 75.29% Test: 73.23%
# Run: 01, Epoch: 454, Loss: 0.6289, Train: 80.34%, Valid: 76.00% Test: 74.70%
# Run: 01, Epoch: 455, Loss: 0.6273, Train: 80.28%, Valid: 75.89% Test: 74.54%
# Run: 01, Epoch: 456, Loss: 0.6301, Train: 80.32%, Valid: 75.32% Test: 73.08%
# Run: 01, Epoch: 457, Loss: 0.6265, Train: 80.32%, Valid: 76.04% Test: 74.69%
# Run: 01, Epoch: 458, Loss: 0.6286, Train: 80.38%, Valid: 75.97% Test: 74.59%
# Run: 01, Epoch: 459, Loss: 0.6273, Train: 80.29%, Valid: 75.70% Test: 73.50%
# Run: 01, Epoch: 460, Loss: 0.6263, Train: 80.39%, Valid: 76.00% Test: 74.54%
# Run: 01, Epoch: 461, Loss: 0.6261, Train: 80.29%, Valid: 76.04% Test: 74.65%
# Run: 01, Epoch: 462, Loss: 0.6274, Train: 80.37%, Valid: 75.92% Test: 74.34%
# Run: 01, Epoch: 463, Loss: 0.6244, Train: 80.39%, Valid: 75.93% Test: 74.38%
# Run: 01, Epoch: 464, Loss: 0.6240, Train: 80.36%, Valid: 75.76% Test: 74.08%
# Run: 01, Epoch: 465, Loss: 0.6248, Train: 80.31%, Valid: 76.07% Test: 74.89%
# Run: 01, Epoch: 466, Loss: 0.6239, Train: 80.40%, Valid: 75.86% Test: 74.13%
# Run: 01, Epoch: 467, Loss: 0.6228, Train: 80.37%, Valid: 75.90% Test: 74.63%
# Run: 01, Epoch: 468, Loss: 0.6211, Train: 80.42%, Valid: 75.90% Test: 74.49%
# Run: 01, Epoch: 469, Loss: 0.6211, Train: 80.45%, Valid: 75.97% Test: 74.23%
# Run: 01, Epoch: 470, Loss: 0.6213, Train: 80.41%, Valid: 76.09% Test: 74.73%
# Run: 01, Epoch: 471, Loss: 0.6198, Train: 80.45%, Valid: 75.94% Test: 74.26%
# Run: 01, Epoch: 472, Loss: 0.6200, Train: 80.45%, Valid: 75.87% Test: 74.35%
# Run: 01, Epoch: 473, Loss: 0.6215, Train: 80.47%, Valid: 75.84% Test: 74.23%
# Run: 01, Epoch: 474, Loss: 0.6214, Train: 80.60%, Valid: 75.87% Test: 74.18%
# Run: 01, Epoch: 475, Loss: 0.6198, Train: 80.59%, Valid: 76.01% Test: 74.57%
# Run: 01, Epoch: 476, Loss: 0.6181, Train: 80.49%, Valid: 75.67% Test: 73.72%
# Run: 01, Epoch: 477, Loss: 0.6182, Train: 80.40%, Valid: 76.06% Test: 75.19%
# Run: 01, Epoch: 478, Loss: 0.6197, Train: 80.52%, Valid: 75.48% Test: 73.54%
# Run: 01, Epoch: 479, Loss: 0.6191, Train: 80.45%, Valid: 76.07% Test: 75.04%
# Run: 01, Epoch: 480, Loss: 0.6193, Train: 80.49%, Valid: 75.88% Test: 74.82%
# Run: 01, Epoch: 481, Loss: 0.6196, Train: 80.57%, Valid: 75.49% Test: 73.37%
# Run: 01, Epoch: 482, Loss: 0.6175, Train: 80.56%, Valid: 75.95% Test: 74.42%
# Run: 01, Epoch: 483, Loss: 0.6175, Train: 80.56%, Valid: 75.90% Test: 73.97%
# Run: 01, Epoch: 484, Loss: 0.6176, Train: 80.48%, Valid: 75.86% Test: 74.11%
# Run: 01, Epoch: 485, Loss: 0.6191, Train: 80.59%, Valid: 76.10% Test: 74.60%
# Run: 01, Epoch: 486, Loss: 0.6179, Train: 80.46%, Valid: 76.00% Test: 74.37%
# Run: 01, Epoch: 487, Loss: 0.6199, Train: 80.25%, Valid: 75.88% Test: 75.03%
# Run: 01, Epoch: 488, Loss: 0.6239, Train: 80.15%, Valid: 74.01% Test: 71.19%
# Run: 01, Epoch: 489, Loss: 0.6290, Train: 80.39%, Valid: 75.99% Test: 75.06%
# Run: 01, Epoch: 490, Loss: 0.6224, Train: 80.31%, Valid: 76.06% Test: 75.06%
# Run: 01, Epoch: 491, Loss: 0.6223, Train: 80.13%, Valid: 74.71% Test: 71.98%
# Run: 01, Epoch: 492, Loss: 0.6260, Train: 80.54%, Valid: 75.99% Test: 74.56%
# Run: 01, Epoch: 493, Loss: 0.6187, Train: 80.09%, Valid: 75.55% Test: 75.19%
# Run: 01, Epoch: 494, Loss: 0.6246, Train: 80.37%, Valid: 75.40% Test: 73.54%
# Run: 01, Epoch: 495, Loss: 0.6226, Train: 80.40%, Valid: 75.55% Test: 73.74%
# Run: 01, Epoch: 496, Loss: 0.6203, Train: 80.32%, Valid: 75.85% Test: 75.16%
# Run: 01, Epoch: 497, Loss: 0.6215, Train: 80.53%, Valid: 75.83% Test: 74.30%
# Run: 01, Epoch: 498, Loss: 0.6190, Train: 80.38%, Valid: 75.30% Test: 73.19%
# Run: 01, Epoch: 499, Loss: 0.6206, Train: 80.44%, Valid: 75.90% Test: 74.85%
# Run: 01, Epoch: 500, Loss: 0.6183, Train: 80.57%, Valid: 75.84% Test: 74.75%
# Run 01:
# Highest Train: 80.60
# Highest Valid: 76.23
#   Final Train: 80.37
#    Final Test: 74.79
# Run: 02, Epoch: 01, Loss: 4.1524, Train: 53.78%, Valid: 56.28% Test: 56.06%
# Run: 02, Epoch: 02, Loss: 1.8526, Train: 61.84%, Valid: 62.64% Test: 62.72%
# Run: 02, Epoch: 03, Loss: 1.3810, Train: 67.27%, Valid: 66.12% Test: 66.60%
# Run: 02, Epoch: 04, Loss: 1.2345, Train: 68.60%, Valid: 66.80% Test: 67.23%
# Run: 02, Epoch: 05, Loss: 1.1538, Train: 69.65%, Valid: 67.32% Test: 67.59%
# Run: 02, Epoch: 06, Loss: 1.0809, Train: 70.40%, Valid: 68.10% Test: 68.17%
# Run: 02, Epoch: 07, Loss: 1.0362, Train: 71.18%, Valid: 68.95% Test: 68.76%
# Run: 02, Epoch: 08, Loss: 1.0048, Train: 71.92%, Valid: 69.60% Test: 68.92%
# Run: 02, Epoch: 09, Loss: 0.9832, Train: 72.71%, Valid: 70.26% Test: 69.18%
# Run: 02, Epoch: 10, Loss: 0.9602, Train: 73.59%, Valid: 70.86% Test: 69.68%
# Run: 02, Epoch: 11, Loss: 0.9412, Train: 74.38%, Valid: 71.46% Test: 70.33%
# Run: 02, Epoch: 12, Loss: 0.9237, Train: 74.99%, Valid: 72.01% Test: 70.96%
# Run: 02, Epoch: 13, Loss: 0.9069, Train: 75.40%, Valid: 72.34% Test: 71.43%
# Run: 02, Epoch: 14, Loss: 0.8955, Train: 75.64%, Valid: 72.69% Test: 71.87%
# Run: 02, Epoch: 15, Loss: 0.8873, Train: 75.80%, Valid: 72.91% Test: 72.02%
# Run: 02, Epoch: 16, Loss: 0.8809, Train: 75.94%, Valid: 73.01% Test: 72.08%
# Run: 02, Epoch: 17, Loss: 0.8718, Train: 76.08%, Valid: 73.11% Test: 72.13%
# Run: 02, Epoch: 18, Loss: 0.8644, Train: 76.24%, Valid: 73.13% Test: 71.97%
# Run: 02, Epoch: 19, Loss: 0.8563, Train: 76.27%, Valid: 73.23% Test: 71.94%
# Run: 02, Epoch: 20, Loss: 0.8506, Train: 76.39%, Valid: 73.19% Test: 71.85%
# Run: 02, Epoch: 21, Loss: 0.8474, Train: 76.46%, Valid: 73.20% Test: 71.78%
# Run: 02, Epoch: 22, Loss: 0.8416, Train: 76.52%, Valid: 73.28% Test: 71.77%
# Run: 02, Epoch: 23, Loss: 0.8399, Train: 76.59%, Valid: 73.44% Test: 71.83%
# Run: 02, Epoch: 24, Loss: 0.8349, Train: 76.72%, Valid: 73.58% Test: 71.91%
# Run: 02, Epoch: 25, Loss: 0.8294, Train: 76.77%, Valid: 73.70% Test: 72.05%
# Run: 02, Epoch: 26, Loss: 0.8276, Train: 76.87%, Valid: 73.83% Test: 72.22%
# Run: 02, Epoch: 27, Loss: 0.8226, Train: 76.89%, Valid: 73.96% Test: 72.39%
# Run: 02, Epoch: 28, Loss: 0.8195, Train: 76.95%, Valid: 74.04% Test: 72.51%
# Run: 02, Epoch: 29, Loss: 0.8177, Train: 77.01%, Valid: 74.11% Test: 72.61%
# Run: 02, Epoch: 30, Loss: 0.8148, Train: 77.06%, Valid: 74.10% Test: 72.66%
# Run: 02, Epoch: 31, Loss: 0.8127, Train: 77.14%, Valid: 74.16% Test: 72.68%
# Run: 02, Epoch: 32, Loss: 0.8090, Train: 77.12%, Valid: 74.20% Test: 72.73%
# Run: 02, Epoch: 33, Loss: 0.8071, Train: 77.16%, Valid: 74.23% Test: 72.75%
# Run: 02, Epoch: 34, Loss: 0.8055, Train: 77.20%, Valid: 74.22% Test: 72.78%
# Run: 02, Epoch: 35, Loss: 0.8039, Train: 77.22%, Valid: 74.26% Test: 72.81%
# Run: 02, Epoch: 36, Loss: 0.8043, Train: 77.26%, Valid: 74.29% Test: 72.77%
# Run: 02, Epoch: 37, Loss: 0.8016, Train: 77.31%, Valid: 74.33% Test: 72.81%
# Run: 02, Epoch: 38, Loss: 0.7992, Train: 77.30%, Valid: 74.35% Test: 72.84%
# Run: 02, Epoch: 39, Loss: 0.7985, Train: 77.33%, Valid: 74.36% Test: 72.86%
# Run: 02, Epoch: 40, Loss: 0.7956, Train: 77.36%, Valid: 74.40% Test: 72.92%
# Run: 02, Epoch: 41, Loss: 0.7937, Train: 77.37%, Valid: 74.40% Test: 72.94%
# Run: 02, Epoch: 42, Loss: 0.7924, Train: 77.37%, Valid: 74.42% Test: 73.00%
# Run: 02, Epoch: 43, Loss: 0.7939, Train: 77.39%, Valid: 74.49% Test: 73.07%
# Run: 02, Epoch: 44, Loss: 0.7906, Train: 77.40%, Valid: 74.50% Test: 73.09%
# Run: 02, Epoch: 45, Loss: 0.7901, Train: 77.41%, Valid: 74.53% Test: 73.09%
# Run: 02, Epoch: 46, Loss: 0.7868, Train: 77.43%, Valid: 74.53% Test: 73.10%
# Run: 02, Epoch: 47, Loss: 0.7856, Train: 77.45%, Valid: 74.58% Test: 73.11%
# Run: 02, Epoch: 48, Loss: 0.7860, Train: 77.49%, Valid: 74.60% Test: 73.13%
# Run: 02, Epoch: 49, Loss: 0.7828, Train: 77.51%, Valid: 74.55% Test: 73.15%
# Run: 02, Epoch: 50, Loss: 0.7842, Train: 77.55%, Valid: 74.59% Test: 73.20%
# Run: 02, Epoch: 51, Loss: 0.7833, Train: 77.58%, Valid: 74.60% Test: 73.31%
# Run: 02, Epoch: 52, Loss: 0.7809, Train: 77.60%, Valid: 74.69% Test: 73.34%
# Run: 02, Epoch: 53, Loss: 0.7802, Train: 77.59%, Valid: 74.67% Test: 73.41%
# Run: 02, Epoch: 54, Loss: 0.7787, Train: 77.63%, Valid: 74.64% Test: 73.39%
# Run: 02, Epoch: 55, Loss: 0.7796, Train: 77.63%, Valid: 74.65% Test: 73.35%
# Run: 02, Epoch: 56, Loss: 0.7785, Train: 77.63%, Valid: 74.67% Test: 73.24%
# Run: 02, Epoch: 57, Loss: 0.7761, Train: 77.63%, Valid: 74.66% Test: 73.17%
# Run: 02, Epoch: 58, Loss: 0.7738, Train: 77.67%, Valid: 74.71% Test: 73.24%
# Run: 02, Epoch: 59, Loss: 0.7750, Train: 77.67%, Valid: 74.73% Test: 73.31%
# Run: 02, Epoch: 60, Loss: 0.7733, Train: 77.70%, Valid: 74.75% Test: 73.45%
# Run: 02, Epoch: 61, Loss: 0.7732, Train: 77.71%, Valid: 74.71% Test: 73.48%
# Run: 02, Epoch: 62, Loss: 0.7713, Train: 77.71%, Valid: 74.75% Test: 73.45%
# Run: 02, Epoch: 63, Loss: 0.7710, Train: 77.71%, Valid: 74.77% Test: 73.38%
# Run: 02, Epoch: 64, Loss: 0.7709, Train: 77.73%, Valid: 74.80% Test: 73.32%
# Run: 02, Epoch: 65, Loss: 0.7685, Train: 77.74%, Valid: 74.84% Test: 73.31%
# Run: 02, Epoch: 66, Loss: 0.7689, Train: 77.75%, Valid: 74.85% Test: 73.31%
# Run: 02, Epoch: 67, Loss: 0.7661, Train: 77.77%, Valid: 74.89% Test: 73.35%
# Run: 02, Epoch: 68, Loss: 0.7645, Train: 77.79%, Valid: 74.87% Test: 73.43%
# Run: 02, Epoch: 69, Loss: 0.7650, Train: 77.79%, Valid: 74.92% Test: 73.51%
# Run: 02, Epoch: 70, Loss: 0.7665, Train: 77.80%, Valid: 74.96% Test: 73.57%
# Run: 02, Epoch: 71, Loss: 0.7640, Train: 77.81%, Valid: 74.95% Test: 73.60%
# Run: 02, Epoch: 72, Loss: 0.7642, Train: 77.85%, Valid: 74.99% Test: 73.56%
# Run: 02, Epoch: 73, Loss: 0.7635, Train: 77.85%, Valid: 74.95% Test: 73.52%
# Run: 02, Epoch: 74, Loss: 0.7619, Train: 77.88%, Valid: 74.95% Test: 73.43%
# Run: 02, Epoch: 75, Loss: 0.7616, Train: 77.90%, Valid: 74.96% Test: 73.48%
# Run: 02, Epoch: 76, Loss: 0.7623, Train: 77.89%, Valid: 74.95% Test: 73.52%
# Run: 02, Epoch: 77, Loss: 0.7615, Train: 77.90%, Valid: 74.98% Test: 73.57%
# Run: 02, Epoch: 78, Loss: 0.7595, Train: 77.91%, Valid: 75.00% Test: 73.57%
# Run: 02, Epoch: 79, Loss: 0.7597, Train: 77.92%, Valid: 75.00% Test: 73.54%
# Run: 02, Epoch: 80, Loss: 0.7582, Train: 77.93%, Valid: 74.98% Test: 73.49%
# Run: 02, Epoch: 81, Loss: 0.7594, Train: 77.97%, Valid: 74.92% Test: 73.44%
# Run: 02, Epoch: 82, Loss: 0.7584, Train: 77.99%, Valid: 74.96% Test: 73.43%
# Run: 02, Epoch: 83, Loss: 0.7565, Train: 77.99%, Valid: 75.02% Test: 73.48%
# Run: 02, Epoch: 84, Loss: 0.7565, Train: 78.00%, Valid: 75.09% Test: 73.55%
# Run: 02, Epoch: 85, Loss: 0.7562, Train: 78.00%, Valid: 75.11% Test: 73.59%
# Run: 02, Epoch: 86, Loss: 0.7544, Train: 78.00%, Valid: 75.13% Test: 73.66%
# Run: 02, Epoch: 87, Loss: 0.7546, Train: 78.02%, Valid: 75.14% Test: 73.68%
# Run: 02, Epoch: 88, Loss: 0.7530, Train: 78.01%, Valid: 75.17% Test: 73.67%
# Run: 02, Epoch: 89, Loss: 0.7529, Train: 78.03%, Valid: 75.15% Test: 73.58%
# Run: 02, Epoch: 90, Loss: 0.7519, Train: 78.04%, Valid: 75.09% Test: 73.50%
# Run: 02, Epoch: 91, Loss: 0.7514, Train: 78.06%, Valid: 75.07% Test: 73.45%
# Run: 02, Epoch: 92, Loss: 0.7530, Train: 78.09%, Valid: 75.08% Test: 73.46%
# Run: 02, Epoch: 93, Loss: 0.7488, Train: 78.07%, Valid: 75.15% Test: 73.56%
# Run: 02, Epoch: 94, Loss: 0.7510, Train: 78.05%, Valid: 75.20% Test: 73.65%
# Run: 02, Epoch: 95, Loss: 0.7513, Train: 78.08%, Valid: 75.17% Test: 73.73%
# Run: 02, Epoch: 96, Loss: 0.7503, Train: 78.09%, Valid: 75.17% Test: 73.74%
# Run: 02, Epoch: 97, Loss: 0.7483, Train: 78.07%, Valid: 75.18% Test: 73.70%
# Run: 02, Epoch: 98, Loss: 0.7500, Train: 78.10%, Valid: 75.14% Test: 73.59%
# Run: 02, Epoch: 99, Loss: 0.7475, Train: 78.10%, Valid: 75.11% Test: 73.54%
# Run: 02, Epoch: 100, Loss: 0.7474, Train: 78.13%, Valid: 75.17% Test: 73.50%
# Run: 02, Epoch: 101, Loss: 0.7467, Train: 78.13%, Valid: 75.22% Test: 73.60%
# Run: 02, Epoch: 102, Loss: 0.7443, Train: 78.16%, Valid: 75.30% Test: 73.73%
# Run: 02, Epoch: 103, Loss: 0.7449, Train: 78.15%, Valid: 75.27% Test: 73.79%
# Run: 02, Epoch: 104, Loss: 0.7440, Train: 78.14%, Valid: 75.25% Test: 73.77%
# Run: 02, Epoch: 105, Loss: 0.7446, Train: 78.16%, Valid: 75.23% Test: 73.68%
# Run: 02, Epoch: 106, Loss: 0.7434, Train: 78.18%, Valid: 75.19% Test: 73.63%
# Run: 02, Epoch: 107, Loss: 0.7435, Train: 78.18%, Valid: 75.17% Test: 73.56%
# Run: 02, Epoch: 108, Loss: 0.7446, Train: 78.16%, Valid: 75.18% Test: 73.53%
# Run: 02, Epoch: 109, Loss: 0.7428, Train: 78.17%, Valid: 75.25% Test: 73.60%
# Run: 02, Epoch: 110, Loss: 0.7414, Train: 78.21%, Valid: 75.31% Test: 73.72%
# Run: 02, Epoch: 111, Loss: 0.7412, Train: 78.20%, Valid: 75.29% Test: 73.78%
# Run: 02, Epoch: 112, Loss: 0.7414, Train: 78.18%, Valid: 75.28% Test: 73.80%
# Run: 02, Epoch: 113, Loss: 0.7413, Train: 78.20%, Valid: 75.26% Test: 73.69%
# Run: 02, Epoch: 114, Loss: 0.7409, Train: 78.21%, Valid: 75.27% Test: 73.62%
# Run: 02, Epoch: 115, Loss: 0.7390, Train: 78.23%, Valid: 75.25% Test: 73.61%
# Run: 02, Epoch: 116, Loss: 0.7388, Train: 78.23%, Valid: 75.23% Test: 73.61%
# Run: 02, Epoch: 117, Loss: 0.7372, Train: 78.26%, Valid: 75.28% Test: 73.71%
# Run: 02, Epoch: 118, Loss: 0.7377, Train: 78.27%, Valid: 75.28% Test: 73.72%
# Run: 02, Epoch: 119, Loss: 0.7372, Train: 78.25%, Valid: 75.26% Test: 73.76%
# Run: 02, Epoch: 120, Loss: 0.7362, Train: 78.24%, Valid: 75.28% Test: 73.78%
# Run: 02, Epoch: 121, Loss: 0.7373, Train: 78.26%, Valid: 75.32% Test: 73.84%
# Run: 02, Epoch: 122, Loss: 0.7344, Train: 78.27%, Valid: 75.31% Test: 73.82%
# Run: 02, Epoch: 123, Loss: 0.7337, Train: 78.26%, Valid: 75.30% Test: 73.82%
# Run: 02, Epoch: 124, Loss: 0.7345, Train: 78.27%, Valid: 75.30% Test: 73.77%
# Run: 02, Epoch: 125, Loss: 0.7336, Train: 78.30%, Valid: 75.32% Test: 73.76%
# Run: 02, Epoch: 126, Loss: 0.7323, Train: 78.28%, Valid: 75.29% Test: 73.75%
# Run: 02, Epoch: 127, Loss: 0.7331, Train: 78.28%, Valid: 75.33% Test: 73.80%
# Run: 02, Epoch: 128, Loss: 0.7318, Train: 78.27%, Valid: 75.36% Test: 73.83%
# Run: 02, Epoch: 129, Loss: 0.7322, Train: 78.31%, Valid: 75.36% Test: 73.90%
# Run: 02, Epoch: 130, Loss: 0.7325, Train: 78.31%, Valid: 75.32% Test: 73.88%
# Run: 02, Epoch: 131, Loss: 0.7311, Train: 78.31%, Valid: 75.31% Test: 73.79%
# Run: 02, Epoch: 132, Loss: 0.7324, Train: 78.32%, Valid: 75.30% Test: 73.74%
# Run: 02, Epoch: 133, Loss: 0.7307, Train: 78.36%, Valid: 75.35% Test: 73.72%
# Run: 02, Epoch: 134, Loss: 0.7298, Train: 78.36%, Valid: 75.34% Test: 73.73%
# Run: 02, Epoch: 135, Loss: 0.7298, Train: 78.37%, Valid: 75.33% Test: 73.80%
# Run: 02, Epoch: 136, Loss: 0.7280, Train: 78.37%, Valid: 75.34% Test: 73.84%
# Run: 02, Epoch: 137, Loss: 0.7292, Train: 78.37%, Valid: 75.33% Test: 73.78%
# Run: 02, Epoch: 138, Loss: 0.7277, Train: 78.36%, Valid: 75.32% Test: 73.73%
# Run: 02, Epoch: 139, Loss: 0.7282, Train: 78.36%, Valid: 75.34% Test: 73.72%
# Run: 02, Epoch: 140, Loss: 0.7271, Train: 78.37%, Valid: 75.41% Test: 73.77%
# Run: 02, Epoch: 141, Loss: 0.7260, Train: 78.38%, Valid: 75.45% Test: 73.82%
# Run: 02, Epoch: 142, Loss: 0.7258, Train: 78.41%, Valid: 75.45% Test: 73.83%
# Run: 02, Epoch: 143, Loss: 0.7262, Train: 78.43%, Valid: 75.43% Test: 73.80%
# Run: 02, Epoch: 144, Loss: 0.7250, Train: 78.42%, Valid: 75.40% Test: 73.75%
# Run: 02, Epoch: 145, Loss: 0.7257, Train: 78.43%, Valid: 75.38% Test: 73.75%
# Run: 02, Epoch: 146, Loss: 0.7249, Train: 78.42%, Valid: 75.39% Test: 73.76%
# Run: 02, Epoch: 147, Loss: 0.7232, Train: 78.41%, Valid: 75.44% Test: 73.80%
# Run: 02, Epoch: 148, Loss: 0.7238, Train: 78.41%, Valid: 75.40% Test: 73.88%
# Run: 02, Epoch: 149, Loss: 0.7253, Train: 78.40%, Valid: 75.43% Test: 73.89%
# Run: 02, Epoch: 150, Loss: 0.7227, Train: 78.41%, Valid: 75.42% Test: 73.85%
# Run: 02, Epoch: 151, Loss: 0.7227, Train: 78.41%, Valid: 75.43% Test: 73.78%
# Run: 02, Epoch: 152, Loss: 0.7232, Train: 78.43%, Valid: 75.43% Test: 73.75%
# Run: 02, Epoch: 153, Loss: 0.7220, Train: 78.46%, Valid: 75.40% Test: 73.77%
# Run: 02, Epoch: 154, Loss: 0.7209, Train: 78.47%, Valid: 75.42% Test: 73.83%
# Run: 02, Epoch: 155, Loss: 0.7224, Train: 78.48%, Valid: 75.44% Test: 73.84%
# Run: 02, Epoch: 156, Loss: 0.7208, Train: 78.47%, Valid: 75.45% Test: 73.89%
# Run: 02, Epoch: 157, Loss: 0.7192, Train: 78.46%, Valid: 75.43% Test: 73.87%
# Run: 02, Epoch: 158, Loss: 0.7202, Train: 78.46%, Valid: 75.46% Test: 73.81%
# Run: 02, Epoch: 159, Loss: 0.7192, Train: 78.45%, Valid: 75.45% Test: 73.78%
# Run: 02, Epoch: 160, Loss: 0.7190, Train: 78.47%, Valid: 75.42% Test: 73.72%
# Run: 02, Epoch: 161, Loss: 0.7179, Train: 78.49%, Valid: 75.45% Test: 73.75%
# Run: 02, Epoch: 162, Loss: 0.7181, Train: 78.48%, Valid: 75.46% Test: 73.77%
# Run: 02, Epoch: 163, Loss: 0.7168, Train: 78.51%, Valid: 75.45% Test: 73.74%
# Run: 02, Epoch: 164, Loss: 0.7174, Train: 78.52%, Valid: 75.45% Test: 73.76%
# Run: 02, Epoch: 165, Loss: 0.7162, Train: 78.52%, Valid: 75.45% Test: 73.81%
# Run: 02, Epoch: 166, Loss: 0.7167, Train: 78.53%, Valid: 75.48% Test: 73.85%
# Run: 02, Epoch: 167, Loss: 0.7159, Train: 78.51%, Valid: 75.47% Test: 73.82%
# Run: 02, Epoch: 168, Loss: 0.7163, Train: 78.52%, Valid: 75.48% Test: 73.81%
# Run: 02, Epoch: 169, Loss: 0.7146, Train: 78.52%, Valid: 75.50% Test: 73.79%
# Run: 02, Epoch: 170, Loss: 0.7144, Train: 78.52%, Valid: 75.50% Test: 73.79%
# Run: 02, Epoch: 171, Loss: 0.7140, Train: 78.52%, Valid: 75.49% Test: 73.81%
# Run: 02, Epoch: 172, Loss: 0.7142, Train: 78.52%, Valid: 75.52% Test: 73.87%
# Run: 02, Epoch: 173, Loss: 0.7127, Train: 78.56%, Valid: 75.51% Test: 73.95%
# Run: 02, Epoch: 174, Loss: 0.7136, Train: 78.58%, Valid: 75.51% Test: 73.94%
# Run: 02, Epoch: 175, Loss: 0.7135, Train: 78.59%, Valid: 75.55% Test: 73.88%
# Run: 02, Epoch: 176, Loss: 0.7126, Train: 78.59%, Valid: 75.50% Test: 73.76%
# Run: 02, Epoch: 177, Loss: 0.7124, Train: 78.58%, Valid: 75.51% Test: 73.80%
# Run: 02, Epoch: 178, Loss: 0.7107, Train: 78.57%, Valid: 75.48% Test: 73.85%
# ...
# Run: 10, Epoch: 296, Loss: 0.6690, Train: 79.44%, Valid: 75.74% Test: 74.07%
# Run: 10, Epoch: 297, Loss: 0.6678, Train: 79.41%, Valid: 75.61% Test: 73.67%
# Run: 10, Epoch: 298, Loss: 0.6689, Train: 79.43%, Valid: 75.76% Test: 74.05%
# Run: 10, Epoch: 299, Loss: 0.6664, Train: 79.42%, Valid: 75.87% Test: 74.41%
# Run: 10, Epoch: 300, Loss: 0.6654, Train: 79.45%, Valid: 75.60% Test: 73.58%
# Run: 10, Epoch: 301, Loss: 0.6661, Train: 79.40%, Valid: 75.73% Test: 74.06%
# Run: 10, Epoch: 302, Loss: 0.6662, Train: 79.46%, Valid: 75.77% Test: 74.42%
# Run: 10, Epoch: 303, Loss: 0.6665, Train: 79.49%, Valid: 75.62% Test: 73.71%
# Run: 10, Epoch: 304, Loss: 0.6643, Train: 79.49%, Valid: 75.70% Test: 73.84%
# Run: 10, Epoch: 305, Loss: 0.6651, Train: 79.44%, Valid: 75.81% Test: 74.40%
# Run: 10, Epoch: 306, Loss: 0.6650, Train: 79.54%, Valid: 75.81% Test: 74.04%
# Run: 10, Epoch: 307, Loss: 0.6641, Train: 79.54%, Valid: 75.77% Test: 74.04%
# Run: 10, Epoch: 308, Loss: 0.6633, Train: 79.54%, Valid: 75.84% Test: 74.19%
# Run: 10, Epoch: 309, Loss: 0.6622, Train: 79.50%, Valid: 75.72% Test: 73.79%
# Run: 10, Epoch: 310, Loss: 0.6614, Train: 79.54%, Valid: 75.80% Test: 74.19%
# Run: 10, Epoch: 311, Loss: 0.6634, Train: 79.57%, Valid: 75.78% Test: 74.11%
# Run: 10, Epoch: 312, Loss: 0.6632, Train: 79.56%, Valid: 75.75% Test: 73.85%
# Run: 10, Epoch: 313, Loss: 0.6625, Train: 79.52%, Valid: 75.83% Test: 74.37%
# Run: 10, Epoch: 314, Loss: 0.6616, Train: 79.59%, Valid: 75.71% Test: 73.65%
# Run: 10, Epoch: 315, Loss: 0.6604, Train: 79.49%, Valid: 76.06% Test: 74.46%
# Run: 10, Epoch: 316, Loss: 0.6615, Train: 79.58%, Valid: 75.57% Test: 73.73%
# Run: 10, Epoch: 317, Loss: 0.6604, Train: 79.55%, Valid: 75.79% Test: 74.02%
# Run: 10, Epoch: 318, Loss: 0.6612, Train: 79.49%, Valid: 75.78% Test: 73.95%
# Run: 10, Epoch: 319, Loss: 0.6628, Train: 79.55%, Valid: 75.87% Test: 74.36%
# Run: 10, Epoch: 320, Loss: 0.6609, Train: 79.62%, Valid: 75.70% Test: 73.63%
# Run: 10, Epoch: 321, Loss: 0.6585, Train: 79.52%, Valid: 75.94% Test: 74.33%
# Run: 10, Epoch: 322, Loss: 0.6604, Train: 79.60%, Valid: 75.70% Test: 73.78%
# Run: 10, Epoch: 323, Loss: 0.6593, Train: 79.63%, Valid: 75.79% Test: 74.16%
# Run: 10, Epoch: 324, Loss: 0.6579, Train: 79.58%, Valid: 75.93% Test: 74.79%
# Run: 10, Epoch: 325, Loss: 0.6597, Train: 79.66%, Valid: 75.65% Test: 73.73%
# Run: 10, Epoch: 326, Loss: 0.6582, Train: 79.61%, Valid: 75.88% Test: 74.33%
# Run: 10, Epoch: 327, Loss: 0.6568, Train: 79.52%, Valid: 75.73% Test: 73.95%
# Run: 10, Epoch: 328, Loss: 0.6581, Train: 79.65%, Valid: 75.70% Test: 73.78%
# Run: 10, Epoch: 329, Loss: 0.6572, Train: 79.65%, Valid: 75.87% Test: 74.37%
# Run: 10, Epoch: 330, Loss: 0.6572, Train: 79.66%, Valid: 75.76% Test: 73.90%
# Run: 10, Epoch: 331, Loss: 0.6563, Train: 79.73%, Valid: 75.78% Test: 74.10%
# Run: 10, Epoch: 332, Loss: 0.6550, Train: 79.66%, Valid: 75.79% Test: 74.07%
# Run: 10, Epoch: 333, Loss: 0.6553, Train: 79.75%, Valid: 75.81% Test: 73.98%
# Run: 10, Epoch: 334, Loss: 0.6570, Train: 79.73%, Valid: 75.85% Test: 74.22%
# Run: 10, Epoch: 335, Loss: 0.6546, Train: 79.72%, Valid: 75.69% Test: 73.75%
# Run: 10, Epoch: 336, Loss: 0.6534, Train: 79.75%, Valid: 75.83% Test: 74.10%
# Run: 10, Epoch: 337, Loss: 0.6538, Train: 79.82%, Valid: 75.81% Test: 73.97%
# Run: 10, Epoch: 338, Loss: 0.6548, Train: 79.70%, Valid: 75.96% Test: 74.62%
# Run: 10, Epoch: 339, Loss: 0.6545, Train: 79.71%, Valid: 75.38% Test: 73.09%
# Run: 10, Epoch: 340, Loss: 0.6537, Train: 79.55%, Valid: 75.80% Test: 74.93%
# Run: 10, Epoch: 341, Loss: 0.6541, Train: 79.68%, Valid: 75.27% Test: 73.17%
# Run: 10, Epoch: 342, Loss: 0.6574, Train: 79.77%, Valid: 75.93% Test: 74.40%
# Run: 10, Epoch: 343, Loss: 0.6523, Train: 79.79%, Valid: 75.88% Test: 74.34%
# Run: 10, Epoch: 344, Loss: 0.6526, Train: 79.69%, Valid: 75.18% Test: 73.01%
# Run: 10, Epoch: 345, Loss: 0.6531, Train: 79.73%, Valid: 75.95% Test: 74.70%
# Run: 10, Epoch: 346, Loss: 0.6515, Train: 79.75%, Valid: 75.89% Test: 74.16%
# Run: 10, Epoch: 347, Loss: 0.6516, Train: 79.78%, Valid: 75.53% Test: 73.60%
# Run: 10, Epoch: 348, Loss: 0.6529, Train: 79.72%, Valid: 75.69% Test: 74.01%
# Run: 10, Epoch: 349, Loss: 0.6520, Train: 79.78%, Valid: 75.85% Test: 74.19%
# Run: 10, Epoch: 350, Loss: 0.6512, Train: 79.78%, Valid: 75.57% Test: 73.70%
# Run: 10, Epoch: 351, Loss: 0.6498, Train: 79.83%, Valid: 75.99% Test: 74.11%
# Run: 10, Epoch: 352, Loss: 0.6489, Train: 79.78%, Valid: 76.05% Test: 74.48%
# Run: 10, Epoch: 353, Loss: 0.6495, Train: 79.81%, Valid: 75.79% Test: 73.76%
# Run: 10, Epoch: 354, Loss: 0.6502, Train: 79.85%, Valid: 75.96% Test: 74.34%
# Run: 10, Epoch: 355, Loss: 0.6498, Train: 79.88%, Valid: 75.80% Test: 73.82%
# Run: 10, Epoch: 356, Loss: 0.6480, Train: 79.86%, Valid: 75.78% Test: 73.92%
# Run: 10, Epoch: 357, Loss: 0.6473, Train: 79.85%, Valid: 75.89% Test: 74.25%
# Run: 10, Epoch: 358, Loss: 0.6484, Train: 79.89%, Valid: 75.98% Test: 74.13%
# Run: 10, Epoch: 359, Loss: 0.6485, Train: 79.92%, Valid: 75.84% Test: 74.13%
# Run: 10, Epoch: 360, Loss: 0.6470, Train: 79.83%, Valid: 76.05% Test: 74.56%
# Run: 10, Epoch: 361, Loss: 0.6474, Train: 79.88%, Valid: 75.81% Test: 74.01%
# Run: 10, Epoch: 362, Loss: 0.6475, Train: 79.85%, Valid: 75.86% Test: 74.09%
# Run: 10, Epoch: 363, Loss: 0.6468, Train: 79.91%, Valid: 75.90% Test: 74.25%
# Run: 10, Epoch: 364, Loss: 0.6455, Train: 79.90%, Valid: 75.81% Test: 73.98%
# Run: 10, Epoch: 365, Loss: 0.6475, Train: 79.83%, Valid: 75.97% Test: 74.52%
# Run: 10, Epoch: 366, Loss: 0.6469, Train: 79.87%, Valid: 75.66% Test: 73.50%
# Run: 10, Epoch: 367, Loss: 0.6460, Train: 79.82%, Valid: 75.97% Test: 74.70%
# Run: 10, Epoch: 368, Loss: 0.6488, Train: 79.75%, Valid: 75.57% Test: 73.59%
# Run: 10, Epoch: 369, Loss: 0.6482, Train: 79.77%, Valid: 75.92% Test: 74.57%
# Run: 10, Epoch: 370, Loss: 0.6488, Train: 79.86%, Valid: 75.76% Test: 73.93%
# Run: 10, Epoch: 371, Loss: 0.6488, Train: 79.89%, Valid: 76.00% Test: 74.58%
# Run: 10, Epoch: 372, Loss: 0.6482, Train: 79.91%, Valid: 75.75% Test: 73.81%
# Run: 10, Epoch: 373, Loss: 0.6470, Train: 79.78%, Valid: 75.86% Test: 74.45%
# Run: 10, Epoch: 374, Loss: 0.6475, Train: 79.85%, Valid: 75.89% Test: 74.16%
# Run: 10, Epoch: 375, Loss: 0.6465, Train: 79.92%, Valid: 75.42% Test: 73.22%
# Run: 10, Epoch: 376, Loss: 0.6454, Train: 79.92%, Valid: 75.89% Test: 74.40%
# Run: 10, Epoch: 377, Loss: 0.6461, Train: 79.94%, Valid: 75.66% Test: 73.83%
# Run: 10, Epoch: 378, Loss: 0.6459, Train: 79.75%, Valid: 75.78% Test: 74.77%
# Run: 10, Epoch: 379, Loss: 0.6444, Train: 79.77%, Valid: 74.87% Test: 72.27%
# Run: 10, Epoch: 380, Loss: 0.6472, Train: 79.89%, Valid: 75.79% Test: 74.36%
# Run: 10, Epoch: 381, Loss: 0.6450, Train: 79.94%, Valid: 75.92% Test: 74.42%
# Run: 10, Epoch: 382, Loss: 0.6445, Train: 79.98%, Valid: 75.71% Test: 73.57%
# Run: 10, Epoch: 383, Loss: 0.6433, Train: 79.81%, Valid: 76.05% Test: 74.81%
# Run: 10, Epoch: 384, Loss: 0.6433, Train: 79.89%, Valid: 75.66% Test: 73.78%
# Run: 10, Epoch: 385, Loss: 0.6449, Train: 79.96%, Valid: 75.72% Test: 73.74%
# Run: 10, Epoch: 386, Loss: 0.6445, Train: 79.96%, Valid: 75.81% Test: 74.34%
# Run: 10, Epoch: 387, Loss: 0.6409, Train: 79.87%, Valid: 75.34% Test: 73.05%
# Run: 10, Epoch: 388, Loss: 0.6430, Train: 79.97%, Valid: 76.05% Test: 74.45%
# Run: 10, Epoch: 389, Loss: 0.6424, Train: 80.05%, Valid: 75.69% Test: 73.71%
# Run: 10, Epoch: 390, Loss: 0.6411, Train: 80.03%, Valid: 75.78% Test: 73.94%
# Run: 10, Epoch: 391, Loss: 0.6409, Train: 79.99%, Valid: 75.84% Test: 74.30%
# Run: 10, Epoch: 392, Loss: 0.6379, Train: 80.09%, Valid: 75.89% Test: 73.77%
# Run: 10, Epoch: 393, Loss: 0.6388, Train: 80.05%, Valid: 76.09% Test: 74.58%
# Run: 10, Epoch: 394, Loss: 0.6386, Train: 80.06%, Valid: 75.84% Test: 74.08%
# Run: 10, Epoch: 395, Loss: 0.6372, Train: 80.08%, Valid: 75.94% Test: 74.45%
# Run: 10, Epoch: 396, Loss: 0.6372, Train: 80.06%, Valid: 75.86% Test: 74.15%
# Run: 10, Epoch: 397, Loss: 0.6366, Train: 80.10%, Valid: 76.03% Test: 74.26%
# Run: 10, Epoch: 398, Loss: 0.6364, Train: 80.15%, Valid: 75.96% Test: 74.23%
# Run: 10, Epoch: 399, Loss: 0.6360, Train: 80.14%, Valid: 76.03% Test: 74.63%
# Run: 10, Epoch: 400, Loss: 0.6371, Train: 80.16%, Valid: 75.68% Test: 73.74%
# Run: 10, Epoch: 401, Loss: 0.6366, Train: 80.07%, Valid: 75.95% Test: 74.48%
# Run: 10, Epoch: 402, Loss: 0.6368, Train: 80.17%, Valid: 75.73% Test: 73.81%
# Run: 10, Epoch: 403, Loss: 0.6364, Train: 80.03%, Valid: 76.08% Test: 74.86%
# Run: 10, Epoch: 404, Loss: 0.6366, Train: 80.08%, Valid: 75.50% Test: 73.34%
# Run: 10, Epoch: 405, Loss: 0.6347, Train: 80.14%, Valid: 75.96% Test: 74.47%
# Run: 10, Epoch: 406, Loss: 0.6366, Train: 80.23%, Valid: 75.79% Test: 73.88%
# Run: 10, Epoch: 407, Loss: 0.6345, Train: 80.17%, Valid: 75.95% Test: 74.67%
# Run: 10, Epoch: 408, Loss: 0.6342, Train: 80.20%, Valid: 75.91% Test: 74.11%
# Run: 10, Epoch: 409, Loss: 0.6337, Train: 80.21%, Valid: 75.89% Test: 73.99%
# Run: 10, Epoch: 410, Loss: 0.6326, Train: 80.15%, Valid: 75.63% Test: 73.59%
# Run: 10, Epoch: 411, Loss: 0.6328, Train: 80.14%, Valid: 75.97% Test: 74.25%
# Run: 10, Epoch: 412, Loss: 0.6318, Train: 80.22%, Valid: 75.96% Test: 74.07%
# Run: 10, Epoch: 413, Loss: 0.6317, Train: 80.24%, Valid: 75.99% Test: 74.35%
# Run: 10, Epoch: 414, Loss: 0.6317, Train: 80.25%, Valid: 75.84% Test: 73.92%
# Run: 10, Epoch: 415, Loss: 0.6309, Train: 80.08%, Valid: 75.81% Test: 74.46%
# Run: 10, Epoch: 416, Loss: 0.6331, Train: 80.21%, Valid: 76.03% Test: 74.39%
# Run: 10, Epoch: 417, Loss: 0.6317, Train: 80.14%, Valid: 75.80% Test: 74.22%
# Run: 10, Epoch: 418, Loss: 0.6348, Train: 80.16%, Valid: 75.94% Test: 74.06%
# Run: 10, Epoch: 419, Loss: 0.6335, Train: 80.30%, Valid: 75.79% Test: 73.85%
# Run: 10, Epoch: 420, Loss: 0.6325, Train: 80.27%, Valid: 76.01% Test: 74.44%
# Run: 10, Epoch: 421, Loss: 0.6316, Train: 80.16%, Valid: 75.68% Test: 73.65%
# Run: 10, Epoch: 422, Loss: 0.6337, Train: 79.93%, Valid: 75.77% Test: 75.18%
# Run: 10, Epoch: 423, Loss: 0.6380, Train: 79.69%, Valid: 73.52% Test: 69.99%
# Run: 10, Epoch: 424, Loss: 0.6490, Train: 79.99%, Valid: 75.98% Test: 74.46%
# Run: 10, Epoch: 425, Loss: 0.6379, Train: 79.68%, Valid: 75.36% Test: 74.93%
# Run: 10, Epoch: 426, Loss: 0.6454, Train: 79.75%, Valid: 73.95% Test: 70.94%
# Run: 10, Epoch: 427, Loss: 0.6403, Train: 80.05%, Valid: 74.93% Test: 72.54%
# Run: 10, Epoch: 428, Loss: 0.6409, Train: 79.72%, Valid: 75.60% Test: 75.02%
# Run: 10, Epoch: 429, Loss: 0.6384, Train: 80.01%, Valid: 75.75% Test: 74.90%
# Run: 10, Epoch: 430, Loss: 0.6347, Train: 79.96%, Valid: 74.91% Test: 72.29%
# Run: 10, Epoch: 431, Loss: 0.6369, Train: 80.19%, Valid: 75.69% Test: 73.66%
# Run: 10, Epoch: 432, Loss: 0.6329, Train: 80.05%, Valid: 75.98% Test: 74.89%
# Run: 10, Epoch: 433, Loss: 0.6331, Train: 80.11%, Valid: 75.86% Test: 74.11%
# Run: 10, Epoch: 434, Loss: 0.6322, Train: 80.09%, Valid: 75.19% Test: 72.84%
# Run: 10, Epoch: 435, Loss: 0.6316, Train: 80.20%, Valid: 76.01% Test: 74.06%
# Run: 10, Epoch: 436, Loss: 0.6298, Train: 80.22%, Valid: 76.20% Test: 74.56%
# Run: 10, Epoch: 437, Loss: 0.6304, Train: 80.21%, Valid: 75.79% Test: 73.93%
# Run: 10, Epoch: 438, Loss: 0.6299, Train: 80.28%, Valid: 75.76% Test: 73.60%
# Run: 10, Epoch: 439, Loss: 0.6285, Train: 80.27%, Valid: 75.94% Test: 74.21%
# Run: 10, Epoch: 440, Loss: 0.6257, Train: 80.34%, Valid: 75.79% Test: 73.76%
# Run: 10, Epoch: 441, Loss: 0.6277, Train: 80.31%, Valid: 76.00% Test: 74.35%
# Run: 10, Epoch: 442, Loss: 0.6273, Train: 80.25%, Valid: 75.88% Test: 74.72%
# Run: 10, Epoch: 443, Loss: 0.6259, Train: 80.40%, Valid: 75.81% Test: 73.96%
# Run: 10, Epoch: 444, Loss: 0.6271, Train: 80.34%, Valid: 76.06% Test: 74.40%
# Run: 10, Epoch: 445, Loss: 0.6266, Train: 80.37%, Valid: 76.00% Test: 74.37%
# Run: 10, Epoch: 446, Loss: 0.6244, Train: 80.41%, Valid: 75.85% Test: 74.07%
# Run: 10, Epoch: 447, Loss: 0.6230, Train: 80.40%, Valid: 75.97% Test: 74.13%
# Run: 10, Epoch: 448, Loss: 0.6244, Train: 80.38%, Valid: 76.09% Test: 74.37%
# Run: 10, Epoch: 449, Loss: 0.6251, Train: 80.29%, Valid: 75.92% Test: 73.96%
# Run: 10, Epoch: 450, Loss: 0.6278, Train: 80.22%, Valid: 76.05% Test: 74.32%
# Run: 10, Epoch: 451, Loss: 0.6279, Train: 80.16%, Valid: 75.66% Test: 73.76%
# Run: 10, Epoch: 452, Loss: 0.6301, Train: 80.35%, Valid: 76.06% Test: 74.44%
# Run: 10, Epoch: 453, Loss: 0.6264, Train: 80.31%, Valid: 75.74% Test: 74.14%
# Run: 10, Epoch: 454, Loss: 0.6280, Train: 80.22%, Valid: 75.52% Test: 73.48%
# Run: 10, Epoch: 455, Loss: 0.6293, Train: 80.24%, Valid: 75.93% Test: 74.43%
# Run: 10, Epoch: 456, Loss: 0.6265, Train: 80.18%, Valid: 75.85% Test: 74.57%
# Run: 10, Epoch: 457, Loss: 0.6292, Train: 80.23%, Valid: 75.28% Test: 73.05%
# Run: 10, Epoch: 458, Loss: 0.6270, Train: 80.19%, Valid: 75.91% Test: 74.37%
# Run: 10, Epoch: 459, Loss: 0.6263, Train: 80.26%, Valid: 75.92% Test: 74.42%
# Run: 10, Epoch: 460, Loss: 0.6273, Train: 80.35%, Valid: 75.95% Test: 74.32%
# Run: 10, Epoch: 461, Loss: 0.6247, Train: 80.33%, Valid: 75.82% Test: 73.83%
# Run: 10, Epoch: 462, Loss: 0.6244, Train: 80.34%, Valid: 75.92% Test: 74.33%
# Run: 10, Epoch: 463, Loss: 0.6251, Train: 80.38%, Valid: 76.00% Test: 74.67%
# Run: 10, Epoch: 464, Loss: 0.6235, Train: 80.40%, Valid: 75.59% Test: 73.34%
# Run: 10, Epoch: 465, Loss: 0.6234, Train: 80.40%, Valid: 76.05% Test: 74.64%
# Run: 10, Epoch: 466, Loss: 0.6221, Train: 80.35%, Valid: 75.66% Test: 73.70%
# Run: 10, Epoch: 467, Loss: 0.6210, Train: 80.36%, Valid: 75.99% Test: 74.53%
# Run: 10, Epoch: 468, Loss: 0.6215, Train: 80.44%, Valid: 76.03% Test: 74.29%
# Run: 10, Epoch: 469, Loss: 0.6203, Train: 80.45%, Valid: 75.71% Test: 73.74%
# Run: 10, Epoch: 470, Loss: 0.6203, Train: 80.43%, Valid: 75.92% Test: 74.69%
# Run: 10, Epoch: 471, Loss: 0.6209, Train: 80.44%, Valid: 75.36% Test: 73.30%
# Run: 10, Epoch: 472, Loss: 0.6194, Train: 80.48%, Valid: 76.10% Test: 74.57%
# Run: 10, Epoch: 473, Loss: 0.6191, Train: 80.48%, Valid: 76.04% Test: 74.59%
# Run: 10, Epoch: 474, Loss: 0.6187, Train: 80.40%, Valid: 75.64% Test: 73.41%
# Run: 10, Epoch: 475, Loss: 0.6196, Train: 80.36%, Valid: 76.08% Test: 75.03%
# Run: 10, Epoch: 476, Loss: 0.6196, Train: 80.49%, Valid: 75.42% Test: 73.41%
# Run: 10, Epoch: 477, Loss: 0.6210, Train: 80.43%, Valid: 75.88% Test: 74.63%
# Run: 10, Epoch: 478, Loss: 0.6215, Train: 80.38%, Valid: 75.86% Test: 74.67%
# Run: 10, Epoch: 479, Loss: 0.6198, Train: 80.28%, Valid: 75.69% Test: 73.46%
# Run: 10, Epoch: 480, Loss: 0.6206, Train: 80.40%, Valid: 75.98% Test: 74.63%
# Run: 10, Epoch: 481, Loss: 0.6182, Train: 80.43%, Valid: 75.84% Test: 74.24%
# Run: 10, Epoch: 482, Loss: 0.6194, Train: 80.51%, Valid: 75.70% Test: 73.71%
# Run: 10, Epoch: 483, Loss: 0.6183, Train: 80.52%, Valid: 76.04% Test: 74.37%
# Run: 10, Epoch: 484, Loss: 0.6164, Train: 80.51%, Valid: 75.67% Test: 73.58%
# Run: 10, Epoch: 485, Loss: 0.6161, Train: 80.45%, Valid: 75.93% Test: 74.24%
# Run: 10, Epoch: 486, Loss: 0.6180, Train: 80.52%, Valid: 76.05% Test: 74.29%
# Run: 10, Epoch: 487, Loss: 0.6183, Train: 80.65%, Valid: 76.09% Test: 74.44%
# Run: 10, Epoch: 488, Loss: 0.6176, Train: 80.57%, Valid: 75.97% Test: 74.25%
# Run: 10, Epoch: 489, Loss: 0.6150, Train: 80.52%, Valid: 75.87% Test: 74.00%
# Run: 10, Epoch: 490, Loss: 0.6161, Train: 80.36%, Valid: 76.04% Test: 74.92%
# Run: 10, Epoch: 491, Loss: 0.6163, Train: 80.58%, Valid: 75.83% Test: 73.80%
# Run: 10, Epoch: 492, Loss: 0.6156, Train: 80.54%, Valid: 75.99% Test: 74.38%
# Run: 10, Epoch: 493, Loss: 0.6154, Train: 80.56%, Valid: 75.91% Test: 74.51%
# Run: 10, Epoch: 494, Loss: 0.6154, Train: 80.50%, Valid: 75.92% Test: 74.11%
# Run: 10, Epoch: 495, Loss: 0.6175, Train: 80.50%, Valid: 75.89% Test: 74.34%
# Run: 10, Epoch: 496, Loss: 0.6168, Train: 80.57%, Valid: 75.63% Test: 73.65%
# Run: 10, Epoch: 497, Loss: 0.6161, Train: 80.21%, Valid: 75.85% Test: 75.28%
# Run: 10, Epoch: 498, Loss: 0.6214, Train: 80.10%, Valid: 74.04% Test: 71.12%
# Run: 10, Epoch: 499, Loss: 0.6350, Train: 80.39%, Valid: 75.94% Test: 75.21%
# Run: 10, Epoch: 500, Loss: 0.6225, Train: 80.35%, Valid: 75.98% Test: 74.62%
# Run 10:
# Highest Train: 80.65
# Highest Valid: 76.20
#   Final Train: 80.22
#    Final Test: 74.56
# All runs:
# Highest Train: 80.60 ± 0.05
# Highest Valid: 76.17 ± 0.07
#   Final Train: 80.40 ± 0.13
#    Final Test: 74.70 ± 0.16

# %% [markdown]
# The proposed gcn model, which using fine-tuned BERT to encode node features, has about 3% higher accuracy(**74.94%**) than the gcn model which used original node features (72.09%) and the fine-tuned BERT without citation graph data (72.13%).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have demonstrated the use of fine-tuned BERT, how to encode node features, and train GNN for multi-class classification on [Open Graph Benchmark](https://ogb.stanford.edu/) - [ogbn-arxiv](https://ogb.stanford.edu/docs/nodeprop/#ogbn-arxiv) dataset. The result shows that pretrained transformer architechture (BERT) can really bring its advantage on natural language understanding to Graph Neural Networks (GNN) and we are excited that the test accuracy by **our proposed method beats the 1st place** in [Open Graph Benchmark Leaderboard](https://ogb.stanford.edu/docs/leader_nodeprop/#ogbn-arxiv) (**74.94%** v.s. 74.16%)!!!
#
# In this work, we only use the base method and architecture in transformer (BERT) and graph neural network (GCN). We encourage users to experiment further by trying different architechture to encode the node features and designing advanced training procedure in graph neural networks (GNN) for multi-class node classification.
